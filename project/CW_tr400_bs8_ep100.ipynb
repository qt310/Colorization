# %%
from keras.layers import Conv2D, UpSampling2D, InputLayer, Conv2DTranspose
from keras.layers import Activation, Dense, Dropout, Flatten
from keras.layers.normalization import BatchNormalization
from keras.models import Sequential
from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img
from skimage.color import rgb2lab, lab2rgb, rgb2gray, xyz2lab
from skimage.io import imsave
import numpy as np
import os
import random
import tensorflow as tf
from time import time
# Out:
# /home/tking/.local/lib/python3.5/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
import cv2

from scipy.misc import imresize
from skimage.transform import resize

import glob

import matplotlib.pyplot as plt
# %matplotlib inline

from keras.callbacks import EarlyStopping
from keras.utils import to_categorical
import random
from keras import optimizers

# %%
# remove invaild images(only run once) 
# for img in glob.glob(r"../../images/plant/*.jpg"):
#     n= cv2.imread(img)#BGR
#     if  n is None or np.mean(n)>250 or np.mean(np.std(n,axis=2))<2:
#         os.remove(img)

# %%
def generator(batch_size, dir_path, H, W):
    while True:
#         img_all = []
        X = []
        Y = []
        img_batch = random.sample(glob.glob(dir_path), batch_size)
        for img in img_batch:
            # choose random index in features
            n= cv2.imread(img)#BGR
            m = imresize(n,(H,W,3))
            img_lab = cv2.cvtColor(m.astype(np.uint8), cv2.COLOR_BGR2LAB)
            L = img_lab[:,:,0].reshape(1,H,W,1)
#             img_all.append(m)
            y = np.floor(img_lab[:,:,1:]/16)

            # to_categorical
            y0=y[:,:,0].flatten()
            y1=y[:,:,1].flatten()
            Yc2d0 = to_categorical(y0, num_classes = 16 )
            Yc3d0 = Yc2d0.reshape(H,W,16)
            Yc2d1 = to_categorical(y1, num_classes = 16 )
            Yc3d1 = Yc2d1.reshape(H,W,16)
            Yc3d = np.zeros((H,W,32))
            Yc3d[:,:,:16] = Yc3d0
            Yc3d[:,:,16:] = Yc3d1

            Y.append(Yc3d)
            X.append(L)
        X=np.array(X)
        Y=np.array(Y)
        X=np.reshape(X, (batch_size, H, W, 1))
        Y=np.reshape(Y, (batch_size, H, W, 32))
        yield X, Y

# %%
def XY2img(X,Y):
    H, W, _ = X.shape
    img_lab = np.zeros((H,W,3))
    img_lab[:,:,0] = X[:,:,0]
    img_lab[:,:,1] = np.argmax(Y[:,:,:16],axis=2)*16+8
    img_lab[:,:,2] = np.argmax(Y[:,:,16:],axis=2)*16+8
    img = cv2.cvtColor(img_lab.astype(np.uint8), cv2.COLOR_LAB2RGB)
    return img

# %%
# test if generator and XY2img work
X,Y = generator(1, r"../../images/flower/*.jpg", 400, 400).__next__()
img = XY2img(X[0],Y[0])
plt.imshow(img)
plt.axis('off')
# Out:
# /home/tking/.local/lib/python3.5/site-packages/ipykernel_launcher.py:10: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.
#   # Remove the CWD from sys.path while we load stuff.
# (-0.5, 399.5, 399.5, -0.5)

# %%
H = 64
W = 64
train_dir = r"../../images/flower/train/*.jpg"
test_dir = r"../../images/flower/test*.jpg"

# %%
# read images to compute class_weight
# img_all = []
# X = []
Y = []
for img in glob.glob(train_dir):
    n= cv2.imread(img)#BGR
    m = imresize(n,(H,W,3))
    img_lab = cv2.cvtColor(m.astype(np.uint8), cv2.COLOR_BGR2LAB)
#     L = img_lab[:,:,0].reshape(1,H,W,1)
#     img_all.append(m)
    y = np.floor(img_lab[:,:,1:]/16)
    
    # to_categorical
    y0=y[:,:,0].flatten()
    y1=y[:,:,1].flatten()
    yc2d0 = to_categorical(y0, num_classes = 16 )
    yc3d0 = yc2d0.reshape(H,W,16)
    yc2d1 = to_categorical(y1, num_classes = 16 )
    yc3d1 = yc2d1.reshape(H,W,16)
    yc3d = np.zeros((H,W,32))
    yc3d[:,:,:16] = yc3d0
    yc3d[:,:,16:] = yc3d1

    Y.append(yc3d)
#     X.append(L)
#     if len(Y)==num:
#         break
# Out:
# /home/tking/.local/lib/python3.5/site-packages/ipykernel_launcher.py:7: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.
#   import sys

# %%
num = len(Y)
Y=np.array(Y)
Y=np.reshape(Y, (num, H, W, 32))

# %%
# compute class_weight
from sklearn.utils import class_weight
Yflat16A = Y[:,:,:,:16].reshape(num*H*W,16)
YflatA = np.argmax(Yflat16A,axis=1)
YclassA = np.unique(YflatA)
class_weight_A = class_weight.compute_class_weight('balanced',
                                                 YclassA,
                                                 YflatA)
Yflat16B = Y[:,:,:,16:].reshape(num*H*W,16)
YflatB = np.argmax(Yflat16B,axis=1)
YclassB = np.unique(YflatB)
class_weight_B = class_weight.compute_class_weight('balanced',
                                                 YclassB,
                                                 YflatB)

class_weight = np.zeros(32)# ones or zeros?
for i in range(len(YclassA)):
    class_weight[YclassA[i]]=class_weight_A[i]
for i in range(len(YclassB)):
    class_weight[YclassB[i]+16]=class_weight_B[i]

print(class_weight)
# Out:
# [0.00000000e+00 0.00000000e+00 4.20102564e+04 1.33932805e+02
#  2.39283784e+01 1.98824335e+00 4.56828533e-01 2.06168106e-01
#  2.55026992e-01 1.44831323e+00 2.79925303e+00 3.45611718e+00
#  7.22736376e+00 8.50410049e+01 3.15076923e+04 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 4.55111111e+04 1.05921903e+02
#  1.80838852e+01 6.32655268e+00 2.67722917e+00 8.74149007e-01
#  2.43799946e-01 3.16529306e-01 5.71936836e-01 1.24170880e+00
#  2.88727232e+00 1.01458968e+01 0.00000000e+00 0.00000000e+00]

# %%
# Building the neural network
import keras.backend as K
K.clear_session()
model = Sequential()
model.add(InputLayer(input_shape=(None, None, 1)))
model.add(Conv2D(8, (3, 3), activation='relu', padding='same', strides=2))
model.add(Conv2D(8, (3, 3), activation='relu', padding='same'))
model.add(Conv2D(16, (3, 3), activation='relu', padding='same'))
model.add(Conv2D(16, (3, 3), activation='relu', padding='same', strides=2))
model.add(Conv2D(32, (3, 3), activation='relu', padding='same'))
model.add(Conv2D(32, (3, 3), activation='relu', padding='same', strides=2))
model.add(UpSampling2D((2, 2)))
model.add(Conv2D(32, (3, 3), activation='relu', padding='same'))
model.add(UpSampling2D((2, 2)))
model.add(Conv2D(16, (3, 3), activation='relu', padding='same'))
model.add(UpSampling2D((2, 2)))
model.add(Conv2D(32, (3, 3), activation='sigmoid', padding='same'))#TODO
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, None, None, 1)     0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, None, None, 8)     80
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, None, None, 8)     584
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, None, None, 16)    1168
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, None, None, 16)    2320
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, None, None, 32)    4640
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, None, None, 32)    9248
# _________________________________________________________________
# up_sampling2d_1 (UpSampling2 (None, None, None, 32)    0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, None, None, 32)    9248
# _________________________________________________________________
# up_sampling2d_2 (UpSampling2 (None, None, None, 32)    0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, None, None, 16)    4624
# _________________________________________________________________
# up_sampling2d_3 (UpSampling2 (None, None, None, 16)    0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, None, None, 32)    4640
# =================================================================
# Total params: 36,552
# Trainable params: 36,552
# Non-trainable params: 0
# _________________________________________________________________

# %%
# compile model
opt = optimizers.Adam(lr=0.001)
model.compile(optimizer=opt,
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %%
batch_size = 8
train_dir = r"../../images/flower/train/*.jpg"
test_dir = r"../../images/flower/test/*.jpg"

train_generator = generator(batch_size, train_dir, H, W)
test_generator = generator(batch_size, test_dir, H, W)
tr_size = len(glob.glob(train_dir))
ts_size = len(glob.glob(test_dir))
steps_per_epoch = tr_size// batch_size
validation_steps = ts_size // batch_size
print(tr_size,ts_size,steps_per_epoch,validation_steps)
# Out:
# 400 200 50 25

# %%
# TODO change to fit_generator
t0 = time()
hist = model.fit_generator(train_generator,
                            steps_per_epoch=steps_per_epoch,
                            epochs=100,
                            validation_data=test_generator,
                            validation_steps=validation_steps,
                            class_weight=class_weight)
                            #callbacks=[EarlyStopping(patience=5)])
print('Train time: %.fm'%((time()-t0)/60))
# Out:
# Epoch 1/100
# /home/tking/.local/lib/python3.5/site-packages/ipykernel_launcher.py:10: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.
#   # Remove the CWD from sys.path while we load stuff.
# 50/50 [==============================] - 4s 86ms/step - loss: 5.3786 - acc: 0.2906 - val_loss: 4.9972 - val_acc: 0.2479
# Epoch 2/100
# 50/50 [==============================] - 3s 63ms/step - loss: 4.8106 - acc: 0.2246 - val_loss: 4.7827 - val_acc: 0.2288
# Epoch 3/100
# 50/50 [==============================] - 3s 63ms/step - loss: 4.7606 - acc: 0.1982 - val_loss: 4.8276 - val_acc: 0.1632
# Epoch 4/100
# 50/50 [==============================] - 3s 63ms/step - loss: 4.6893 - acc: 0.1743 - val_loss: 4.7880 - val_acc: 0.2246
# Epoch 5/100
# 50/50 [==============================] - 3s 62ms/step - loss: 4.6309 - acc: 0.1314 - val_loss: 4.5946 - val_acc: 0.1078
# Epoch 6/100
# 50/50 [==============================] - 3s 63ms/step - loss: 4.6414 - acc: 0.2194 - val_loss: 4.6727 - val_acc: 0.2862
# Epoch 7/100
# 50/50 [==============================] - 3s 63ms/step - loss: 4.6744 - acc: 0.3327 - val_loss: 4.6654 - val_acc: 0.3876
# Epoch 8/100
# 50/50 [==============================] - 3s 63ms/step - loss: 4.7006 - acc: 0.3514 - val_loss: 4.5982 - val_acc: 0.3859
# Epoch 9/100
# 50/50 [==============================] - 3s 63ms/step - loss: 4.5818 - acc: 0.3739 - val_loss: 4.6065 - val_acc: 0.3733
# Epoch 10/100
# 50/50 [==============================] - 3s 62ms/step - loss: 4.5494 - acc: 0.3678 - val_loss: 4.5811 - val_acc: 0.3768
# Epoch 11/100
# 50/50 [==============================] - 3s 62ms/step - loss: 4.6138 - acc: 0.3712 - val_loss: 4.6037 - val_acc: 0.4001
# Epoch 12/100
# 50/50 [==============================] - 3s 63ms/step - loss: 4.6522 - acc: 0.3730 - val_loss: 4.6445 - val_acc: 0.4027
# Epoch 13/100
# 50/50 [==============================] - 3s 63ms/step - loss: 4.5495 - acc: 0.3620 - val_loss: 4.6903 - val_acc: 0.4005
# Epoch 14/100
# 50/50 [==============================] - 3s 62ms/step - loss: 4.5886 - acc: 0.3646 - val_loss: 4.6638 - val_acc: 0.3946
# Epoch 15/100
# 50/50 [==============================] - 3s 63ms/step - loss: 4.5130 - acc: 0.3742 - val_loss: 4.6688 - val_acc: 0.3968
# Epoch 16/100
# 50/50 [==============================] - 3s 63ms/step - loss: 4.4637 - acc: 0.3854 - val_loss: 4.6893 - val_acc: 0.3524
# Epoch 17/100
# 50/50 [==============================] - 3s 63ms/step - loss: 4.5527 - acc: 0.3731 - val_loss: 4.6757 - val_acc: 0.4149
# Epoch 18/100
# 50/50 [==============================] - 3s 63ms/step - loss: 4.5441 - acc: 0.3678 - val_loss: 4.6376 - val_acc: 0.4199
# Epoch 19/100
# 50/50 [==============================] - 3s 63ms/step - loss: 4.4499 - acc: 0.3666 - val_loss: 4.6429 - val_acc: 0.3866
# Epoch 20/100
# 50/50 [==============================] - 3s 63ms/step - loss: 4.4802 - acc: 0.3722 - val_loss: 4.6657 - val_acc: 0.3812
# Epoch 21/100
# 50/50 [==============================] - 3s 63ms/step - loss: 4.5195 - acc: 0.3725 - val_loss: 4.7639 - val_acc: 0.3900
# Epoch 22/100
# 50/50 [==============================] - 3s 63ms/step - loss: 4.4133 - acc: 0.3980 - val_loss: 4.7173 - val_acc: 0.3744
# Epoch 23/100
# 50/50 [==============================] - 3s 63ms/step - loss: 4.4499 - acc: 0.3785 - val_loss: 4.7650 - val_acc: 0.3671
# Epoch 24/100
# 50/50 [==============================] - 3s 64ms/step - loss: 4.4458 - acc: 0.3784 - val_loss: 4.6373 - val_acc: 0.3877
# Epoch 25/100
# 50/50 [==============================] - 3s 64ms/step - loss: 4.4068 - acc: 0.3915 - val_loss: 4.7227 - val_acc: 0.4057
# Epoch 26/100
# 50/50 [==============================] - 3s 64ms/step - loss: 4.4629 - acc: 0.3587 - val_loss: 4.7205 - val_acc: 0.3689
# Epoch 27/100
# 50/50 [==============================] - 3s 64ms/step - loss: 4.3410 - acc: 0.3736 - val_loss: 4.8431 - val_acc: 0.2652
# Epoch 28/100
# 50/50 [==============================] - 3s 63ms/step - loss: 4.3494 - acc: 0.2255 - val_loss: 4.8382 - val_acc: 0.2469
# Epoch 29/100
# 50/50 [==============================] - 3s 63ms/step - loss: 4.3513 - acc: 0.2993 - val_loss: 4.7719 - val_acc: 0.2963
# Epoch 30/100
# 50/50 [==============================] - 3s 63ms/step - loss: 4.3289 - acc: 0.2712 - val_loss: 4.8640 - val_acc: 0.2719
# Epoch 31/100
# 50/50 [==============================] - 3s 63ms/step - loss: 4.2846 - acc: 0.2772 - val_loss: 4.8357 - val_acc: 0.3053
# Epoch 32/100
# 50/50 [==============================] - 3s 63ms/step - loss: 4.2961 - acc: 0.2613 - val_loss: 4.8007 - val_acc: 0.2411
# Epoch 33/100
# 50/50 [==============================] - 3s 63ms/step - loss: 4.2736 - acc: 0.2350 - val_loss: 4.7411 - val_acc: 0.2271
# Epoch 34/100
# 50/50 [==============================] - 3s 63ms/step - loss: 4.1360 - acc: 0.2679 - val_loss: 4.8305 - val_acc: 0.2613
# Epoch 35/100
# 50/50 [==============================] - 3s 63ms/step - loss: 4.2233 - acc: 0.2325 - val_loss: 5.0183 - val_acc: 0.2526
# Epoch 36/100
# 50/50 [==============================] - 3s 63ms/step - loss: 4.1380 - acc: 0.2458 - val_loss: 4.9606 - val_acc: 0.1578
# Epoch 37/100
# 50/50 [==============================] - 3s 63ms/step - loss: 4.1423 - acc: 0.2725 - val_loss: 4.8650 - val_acc: 0.1929
# Epoch 38/100
# 50/50 [==============================] - 3s 64ms/step - loss: 4.1379 - acc: 0.2527 - val_loss: 5.0132 - val_acc: 0.2633
# Epoch 39/100
# 50/50 [==============================] - 3s 64ms/step - loss: 4.1539 - acc: 0.2586 - val_loss: 4.9065 - val_acc: 0.2058
# Epoch 40/100
# 50/50 [==============================] - 3s 63ms/step - loss: 4.0462 - acc: 0.2808 - val_loss: 4.9673 - val_acc: 0.2482
# Epoch 41/100
# 50/50 [==============================] - 3s 62ms/step - loss: 4.1053 - acc: 0.2763 - val_loss: 5.1107 - val_acc: 0.1785
# Epoch 42/100
# 50/50 [==============================] - 3s 62ms/step - loss: 4.0899 - acc: 0.2760 - val_loss: 4.9587 - val_acc: 0.2733
# Epoch 43/100
# 50/50 [==============================] - 3s 63ms/step - loss: 3.9507 - acc: 0.2856 - val_loss: 4.9924 - val_acc: 0.2049
# Epoch 44/100
# 50/50 [==============================] - 3s 64ms/step - loss: 4.0472 - acc: 0.2797 - val_loss: 5.1615 - val_acc: 0.1640
# Epoch 45/100
# 50/50 [==============================] - 3s 63ms/step - loss: 3.9576 - acc: 0.3095 - val_loss: 5.4170 - val_acc: 0.1369
# Epoch 46/100
# 50/50 [==============================] - 3s 62ms/step - loss: 3.9601 - acc: 0.3092 - val_loss: 5.2913 - val_acc: 0.2444
# Epoch 47/100
# 50/50 [==============================] - 3s 63ms/step - loss: 3.9780 - acc: 0.3330 - val_loss: 5.3056 - val_acc: 0.1507
# Epoch 48/100
# 50/50 [==============================] - 3s 63ms/step - loss: 3.9012 - acc: 0.2887 - val_loss: 5.2263 - val_acc: 0.1761
# Epoch 49/100
# 50/50 [==============================] - 3s 63ms/step - loss: 3.8584 - acc: 0.3139 - val_loss: 5.2472 - val_acc: 0.2458
# Epoch 50/100
# 50/50 [==============================] - 3s 63ms/step - loss: 3.8950 - acc: 0.3130 - val_loss: 5.1992 - val_acc: 0.1320
# Epoch 51/100
# 50/50 [==============================] - 3s 63ms/step - loss: 3.8804 - acc: 0.3182 - val_loss: 5.0850 - val_acc: 0.2250
# Epoch 52/100
# 50/50 [==============================] - 3s 63ms/step - loss: 3.8726 - acc: 0.3290 - val_loss: 5.3766 - val_acc: 0.1942
# Epoch 53/100
# 50/50 [==============================] - 3s 63ms/step - loss: 3.8502 - acc: 0.3010 - val_loss: 5.4757 - val_acc: 0.1419
# Epoch 54/100
# 50/50 [==============================] - 3s 63ms/step - loss: 3.8071 - acc: 0.3056 - val_loss: 5.2892 - val_acc: 0.1966
# Epoch 55/100
# 50/50 [==============================] - 3s 64ms/step - loss: 3.8072 - acc: 0.3348 - val_loss: 5.4864 - val_acc: 0.1658
# Epoch 56/100
# 50/50 [==============================] - 3s 63ms/step - loss: 3.7774 - acc: 0.3268 - val_loss: 5.6159 - val_acc: 0.1361
# Epoch 57/100
# 50/50 [==============================] - 3s 62ms/step - loss: 3.7599 - acc: 0.3461 - val_loss: 5.5280 - val_acc: 0.2190
# Epoch 58/100
# 50/50 [==============================] - 3s 63ms/step - loss: 3.7473 - acc: 0.3554 - val_loss: 5.5608 - val_acc: 0.1943
# Epoch 59/100
# 50/50 [==============================] - 3s 63ms/step - loss: 3.7828 - acc: 0.3388 - val_loss: 5.5245 - val_acc: 0.1795
# Epoch 60/100
# 50/50 [==============================] - 3s 62ms/step - loss: 3.7739 - acc: 0.3208 - val_loss: 5.3997 - val_acc: 0.2320
# Epoch 61/100
# 50/50 [==============================] - 3s 64ms/step - loss: 3.8029 - acc: 0.3066 - val_loss: 5.6245 - val_acc: 0.1518
# Epoch 62/100
# 50/50 [==============================] - 3s 63ms/step - loss: 3.7189 - acc: 0.3145 - val_loss: 5.6138 - val_acc: 0.2334
# Epoch 63/100
# 50/50 [==============================] - 3s 62ms/step - loss: 3.7142 - acc: 0.3281 - val_loss: 5.5252 - val_acc: 0.1807
# Epoch 64/100
# 50/50 [==============================] - 3s 62ms/step - loss: 3.7407 - acc: 0.3422 - val_loss: 5.6743 - val_acc: 0.2004
# Epoch 65/100
# 50/50 [==============================] - 3s 62ms/step - loss: 3.7187 - acc: 0.3604 - val_loss: 5.3921 - val_acc: 0.2740
# Epoch 66/100
# 50/50 [==============================] - 3s 62ms/step - loss: 3.6856 - acc: 0.3364 - val_loss: 5.6456 - val_acc: 0.2279
# Epoch 67/100
# 50/50 [==============================] - 3s 63ms/step - loss: 3.7479 - acc: 0.3390 - val_loss: 5.7654 - val_acc: 0.1777
# Epoch 68/100
# 50/50 [==============================] - 3s 63ms/step - loss: 3.6781 - acc: 0.3459 - val_loss: 5.4524 - val_acc: 0.1983
# Epoch 69/100
# 50/50 [==============================] - 3s 62ms/step - loss: 3.7012 - acc: 0.3514 - val_loss: 5.7554 - val_acc: 0.2274
# Epoch 70/100
# 50/50 [==============================] - 3s 62ms/step - loss: 3.6469 - acc: 0.3531 - val_loss: 5.6010 - val_acc: 0.1809
# Epoch 71/100
# 50/50 [==============================] - 3s 63ms/step - loss: 3.7423 - acc: 0.2978 - val_loss: 5.8725 - val_acc: 0.1492
# Epoch 72/100
# 50/50 [==============================] - 3s 62ms/step - loss: 3.6673 - acc: 0.3377 - val_loss: 5.7525 - val_acc: 0.2135
# Epoch 73/100
# 50/50 [==============================] - 3s 62ms/step - loss: 3.7132 - acc: 0.3137 - val_loss: 5.6479 - val_acc: 0.1805
# Epoch 74/100
# 50/50 [==============================] - 3s 64ms/step - loss: 3.6226 - acc: 0.3386 - val_loss: 5.6158 - val_acc: 0.2063
# Epoch 75/100
# 50/50 [==============================] - 3s 63ms/step - loss: 3.6718 - acc: 0.3190 - val_loss: 5.7239 - val_acc: 0.1631
# Epoch 76/100
# 50/50 [==============================] - 3s 63ms/step - loss: 3.6437 - acc: 0.3180 - val_loss: 5.9123 - val_acc: 0.1810
# Epoch 77/100
# 50/50 [==============================] - 3s 63ms/step - loss: 3.6521 - acc: 0.3217 - val_loss: 5.6561 - val_acc: 0.2055
# Epoch 78/100
# 50/50 [==============================] - 3s 63ms/step - loss: 3.6706 - acc: 0.3217 - val_loss: 6.0402 - val_acc: 0.2083
# Epoch 79/100
# 50/50 [==============================] - 3s 64ms/step - loss: 3.6455 - acc: 0.3383 - val_loss: 5.8131 - val_acc: 0.2105
# Epoch 80/100
# 50/50 [==============================] - 3s 66ms/step - loss: 3.6660 - acc: 0.3464 - val_loss: 5.8581 - val_acc: 0.1628
# Epoch 81/100
# 50/50 [==============================] - 3s 67ms/step - loss: 3.6369 - acc: 0.3364 - val_loss: 5.8311 - val_acc: 0.2034
# Epoch 82/100
# 50/50 [==============================] - 3s 67ms/step - loss: 3.5702 - acc: 0.3565 - val_loss: 5.9028 - val_acc: 0.1859
# Epoch 83/100
# 50/50 [==============================] - 3s 66ms/step - loss: 3.5976 - acc: 0.3476 - val_loss: 6.0780 - val_acc: 0.1639
# Epoch 84/100
# 50/50 [==============================] - 3s 67ms/step - loss: 3.5958 - acc: 0.3546 - val_loss: 5.7909 - val_acc: 0.1964
# Epoch 85/100
# 50/50 [==============================] - 3s 67ms/step - loss: 3.6230 - acc: 0.3409 - val_loss: 5.7289 - val_acc: 0.2093
# Epoch 86/100
# 50/50 [==============================] - 3s 66ms/step - loss: 3.5842 - acc: 0.3308 - val_loss: 5.6346 - val_acc: 0.2042
# Epoch 87/100
# 50/50 [==============================] - 3s 66ms/step - loss: 3.5924 - acc: 0.3509 - val_loss: 5.9751 - val_acc: 0.2124
# Epoch 88/100
# 50/50 [==============================] - 3s 66ms/step - loss: 3.5944 - acc: 0.3235 - val_loss: 6.2304 - val_acc: 0.1884
# Epoch 89/100
# 50/50 [==============================] - 3s 65ms/step - loss: 3.5924 - acc: 0.3373 - val_loss: 5.8899 - val_acc: 0.1614
# Epoch 90/100
# 50/50 [==============================] - 3s 66ms/step - loss: 3.6135 - acc: 0.3322 - val_loss: 6.0646 - val_acc: 0.1779
# Epoch 91/100
# 50/50 [==============================] - 3s 66ms/step - loss: 3.5312 - acc: 0.3578 - val_loss: 5.9314 - val_acc: 0.2076
# Epoch 92/100
# 50/50 [==============================] - 3s 65ms/step - loss: 3.5361 - acc: 0.3575 - val_loss: 5.9774 - val_acc: 0.1630
# Epoch 93/100
# 50/50 [==============================] - 3s 67ms/step - loss: 3.6368 - acc: 0.3306 - val_loss: 5.8696 - val_acc: 0.1578
# Epoch 94/100
# 50/50 [==============================] - 3s 66ms/step - loss: 3.5644 - acc: 0.3334 - val_loss: 5.8526 - val_acc: 0.2052
# Epoch 95/100
# 50/50 [==============================] - 3s 67ms/step - loss: 3.6307 - acc: 0.3299 - val_loss: 5.6668 - val_acc: 0.1606
# Epoch 96/100
# 50/50 [==============================] - 3s 66ms/step - loss: 3.5637 - acc: 0.3670 - val_loss: 5.5851 - val_acc: 0.2192
# Epoch 97/100
# 50/50 [==============================] - 3s 67ms/step - loss: 3.5040 - acc: 0.3555 - val_loss: 5.7808 - val_acc: 0.1565
# Epoch 98/100
# 50/50 [==============================] - 3s 66ms/step - loss: 3.5423 - acc: 0.3358 - val_loss: 6.0955 - val_acc: 0.1779
# Epoch 99/100
# 50/50 [==============================] - 3s 66ms/step - loss: 3.5485 - acc: 0.3342 - val_loss: 6.1047 - val_acc: 0.1910
# Epoch 100/100
# 50/50 [==============================] - 3s 67ms/step - loss: 3.4882 - acc: 0.3358 - val_loss: 6.0143 - val_acc: 0.1842
# Train time: 5m

# %%
plt.figure(figsize=(15,5))
plt.subplot(1,2,1)
plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.legend(['loss','val_loss'])
plt.grid()
plt.subplot(1,2,2)
plt.plot(hist.history['acc'])
plt.plot(hist.history['val_acc'])
plt.legend(['acc','val_acc'])
plt.grid()

# %%
model_json = model.to_json()
with open("model_CW_flower_tr400_bs8_ep100.json", "w") as json_file:
    json_file.write(model_json)
model.save_weights("model_CW_flower_tr400_bs8_ep100.h5")

# %%
from keras.models import model_from_json

# %%
json_file = open('model_CW_flower_tr400_bs8_ep100.json', 'r')
loaded_model_json = json_file.read()
json_file.close()
loaded_model = model_from_json(loaded_model_json)
# load weights into new model
loaded_model.load_weights("model_CW_flower_tr400_bs8_ep100.h5")

# %%
# result on train images
X,Y = generator(batch_size, train_dir, H, W).__next__()
Yhat = loaded_model.predict(X)
j =1
plt.figure(figsize=(15,15))
for i in range(batch_size):
    # original
    plt.subplot(6,6,j)
    j+=1
    img = XY2img(X[i],Y[i])
    plt.imshow(img)
    plt.axis('OFF')
    # grayscale
    plt.subplot(6,6,j)
    j+=1
    plt.imshow(X[i,:,:,0],'gray')
    plt.axis('OFF')
    # predict
    plt.subplot(6,6,j)
    j += 1
    img = XY2img(X[i],Yhat[i])
    plt.imshow(img)
    plt.axis('OFF')
# Out:
# /home/tking/.local/lib/python3.5/site-packages/ipykernel_launcher.py:10: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.
#   # Remove the CWD from sys.path while we load stuff.

# %%
# result on test images
X,Y = generator(batch_size, test_dir, H, W).__next__()
Yhat = loaded_model.predict(X)
j =1
plt.figure(figsize=(15,15))
for i in range(batch_size):
    # original
    plt.subplot(6,6,j)
    j+=1
    img = XY2img(X[i],Y[i])
    plt.imshow(img)
    plt.axis('OFF')
    # grayscale
    plt.subplot(6,6,j)
    j+=1
    plt.imshow(X[i,:,:,0],'gray')
    plt.axis('OFF')
    # predict
    plt.subplot(6,6,j)
    j += 1
    img = XY2img(X[i],Yhat[i])
    plt.imshow(img)
    plt.axis('OFF')
# Out:
# /home/tking/.local/lib/python3.5/site-packages/ipykernel_launcher.py:10: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.
#   # Remove the CWD from sys.path while we load stuff.

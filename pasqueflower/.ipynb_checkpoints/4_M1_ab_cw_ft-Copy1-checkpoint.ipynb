# %%
from keras.layers import Conv2D, UpSampling2D, InputLayer, Conv2DTranspose
from keras.layers import Activation, Dense, Dropout, Flatten
from keras.layers.normalization import BatchNormalization
from keras.models import Sequential
from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img
from skimage.color import rgb2lab, lab2rgb, rgb2gray, xyz2lab
from skimage.io import imsave
import numpy as np
import os
import random
import tensorflow as tf
from time import time

import cv2

from scipy.misc import imresize
from skimage.transform import resize

import glob

import matplotlib.pyplot as plt
# %matplotlib inline

from keras.callbacks import EarlyStopping
from keras.utils import to_categorical
import random
from keras import optimizers
from scipy.ndimage import filters
# Out:
# /home/tking/.local/lib/python3.5/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
#define parameters:
dir_name = "Pasqueflower" # Variable
model_name = "4_M1_ab_cw_ft"# Variable

train_dir = r"../../images/"+dir_name+"/train/*.jpg"
test_dir = r"../../images/"+dir_name+"/test/*.jpg"
H = 64
W = 64
batch_size = 32

# %%
# select vaild images and put into train and test dir (only run once) 
# i = 0
# num_tr = 2000
# num_ts = 500
# for img in glob.glob(r"../../images/"+dir_name+"/*.jpg"):
#     try:
#         n= cv2.imread(img)#BGR
#         if  n is None or np.mean(n)>250 or np.mean(np.std(n,axis=2))<2:
#             os.remove(img)
#         else:
#             if i<num_tr:
#                 i+=1
#                 os.rename(img,r"../../images/"+dir_name+"/train/"+str(i)+".jpg")
#             elif i>=num_tr and i<num_tr+num_ts:
#                 i+=1
#                 os.rename(img,r"../../images/"+dir_name+"/test/"+str(i)+".jpg")
#             else:
#                 break
#     except:
#         pass
print('tr_size = ',len(glob.glob(train_dir)))
print('ts_size = ',len(glob.glob(test_dir)))
# Out:
# tr_size =  400
# ts_size =  200

# %%
def generator(batch_size, dir_path, H, W):
    while True:
        X = []
        Y = []
        img_batch = random.sample(glob.glob(dir_path), batch_size)
        for img in img_batch:
            # choose random index in features
            n= cv2.imread(img)#BGR
            m = imresize(n,(H,W,3))
            img_lab = cv2.cvtColor(m.astype(np.uint8), cv2.COLOR_BGR2LAB)
            L = img_lab[:,:,0].reshape(1,H,W,1)
            y = np.floor(img_lab[:,:,1:]/16)

            # to_categorical
            y0=y[:,:,0].flatten()
            y1=y[:,:,1].flatten()
            Yc2d0 = to_categorical(y0, num_classes = 16 )
            Yc3d0 = Yc2d0.reshape(H,W,16)
            Yc2d1 = to_categorical(y1, num_classes = 16 )
            Yc3d1 = Yc2d1.reshape(H,W,16)
            Yc3d = np.zeros((H,W,32))
            Yc3d[:,:,:16] = Yc3d0
            Yc3d[:,:,16:] = Yc3d1

            Y.append(Yc3d)
            X.append(L)
        X=np.array(X)
        Y=np.array(Y)
        X=np.reshape(X, (batch_size, H, W, 1))
        Y=np.reshape(Y, (batch_size, H, W, 32))
        yield X, Y

# %%
def XY2img(X,Y):
    H, W, _ = X.shape
    img_lab = np.zeros((H,W,3))
    img_lab[:,:,0] = X[:,:,0]
    img_lab[:,:,1] = np.argmax(Y[:,:,:16],axis=2)*16+8
    img_lab[:,:,2] = np.argmax(Y[:,:,16:],axis=2)*16+8
    img = cv2.cvtColor(img_lab.astype(np.uint8), cv2.COLOR_LAB2RGB)
    return img

# %%
def XY2imgf(X,Y):
    H, W, _ = X.shape
    img_lab = np.zeros((H,W,3))
    img_lab[:,:,0] = X[:,:,0]
    img_lab[:,:,1] = filters.gaussian_filter(np.argmax(Y[:,:,:16],axis=2)*16+8,5)
    img_lab[:,:,2] = filters.gaussian_filter(np.argmax(Y[:,:,16:],axis=2)*16+8,5)
    img = cv2.cvtColor(img_lab.astype(np.uint8), cv2.COLOR_LAB2RGB)
    return img

# %%
# show some images
plt.figure(figsize=(15,5))
X,Y = generator(batch_size, train_dir, H, W).__next__()    
for i in range(8):
    plt.subplot(1,8,i+1)
    img = XY2img(X[i],Y[i])
    plt.imshow(img)
    plt.axis('off')
# Out:
# /home/tking/.local/lib/python3.5/site-packages/ipykernel_launcher.py:9: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.
#   if __name__ == '__main__':

# %%
# read images to compute class_weight
Y = []
img_sample = random.sample(glob.glob(train_dir), 400)#save memory
for img in img_sample:
    n= cv2.imread(img)#BGR
    m = imresize(n,(H,W,3))
    img_lab = cv2.cvtColor(m.astype(np.uint8), cv2.COLOR_BGR2LAB)
    y = np.floor(img_lab[:,:,1:]/16)
    
    # to_categorical
    y0=y[:,:,0].flatten()
    y1=y[:,:,1].flatten()
    yc2d0 = to_categorical(y0, num_classes = 16 )
    yc3d0 = yc2d0.reshape(H,W,16)
    yc2d1 = to_categorical(y1, num_classes = 16 )
    yc3d1 = yc2d1.reshape(H,W,16)
    yc3d = np.zeros((H,W,32))
    yc3d[:,:,:16] = yc3d0
    yc3d[:,:,16:] = yc3d1
    Y.append(yc3d)
num = len(Y)
Y=np.array(Y)
Y=np.reshape(Y, (num, H, W, 32))
# Out:
# /home/tking/.local/lib/python3.5/site-packages/ipykernel_launcher.py:6: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.

# %%
# compute class_weight
from sklearn.utils import class_weight
Yflat16A = Y[:,:,:,:16].reshape(num*H*W,16)
YflatA = np.argmax(Yflat16A,axis=1)
YclassA = np.unique(YflatA)
class_weight_A = class_weight.compute_class_weight('balanced',
                                                 YclassA,
                                                 YflatA)
Yflat16B = Y[:,:,:,16:].reshape(num*H*W,16)
YflatB = np.argmax(Yflat16B,axis=1)
YclassB = np.unique(YflatB)
class_weight_B = class_weight.compute_class_weight('balanced',
                                                 YclassB,
                                                 YflatB)

class_weight = np.zeros(32)
for i in range(len(YclassA)):
    class_weight[YclassA[i]]=class_weight_A[i]
for i in range(len(YclassB)):
    class_weight[YclassB[i]+16]=class_weight_B[i]

plt.stem(class_weight)
plt.yscale('log')
plt.ylabel('class_weight')
plt.xlabel('classes')
# Out:
# Text(0.5,0,'classes')

# %%
# Building the neural network
import keras.backend as K
K.clear_session()
model = Sequential()
model.add(InputLayer(input_shape=(None, None, 1)))
model.add(Conv2D(8, (3, 3), activation='relu', padding='same', strides=2))
model.add(Conv2D(8, (3, 3), activation='relu', padding='same'))
model.add(Conv2D(16, (3, 3), activation='relu', padding='same'))
model.add(Conv2D(16, (3, 3), activation='relu', padding='same', strides=2))
model.add(Conv2D(32, (3, 3), activation='relu', padding='same'))
model.add(Conv2D(32, (3, 3), activation='relu', padding='same', strides=2))
model.add(Conv2DTranspose(32, (2,2), strides=2, padding='same', activation='relu'))
model.add(Conv2D(32, (3, 3), activation='relu', padding='same'))
model.add(Conv2DTranspose(32, (2,2), strides=2, padding='same', activation='relu'))
model.add(Conv2D(16, (3, 3), activation='relu', padding='same'))
model.add(Conv2DTranspose(32, (2,2), strides=2, padding='same', activation='relu'))
model.add(Conv2D(32, (3, 3), activation='sigmoid', padding='same'))#TODO
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, None, None, 1)     0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, None, None, 8)     80
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, None, None, 8)     584
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, None, None, 16)    1168
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, None, None, 16)    2320
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, None, None, 32)    4640
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, None, None, 32)    9248
# _________________________________________________________________
# conv2d_transpose_1 (Conv2DTr (None, None, None, 32)    4128
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, None, None, 32)    9248
# _________________________________________________________________
# conv2d_transpose_2 (Conv2DTr (None, None, None, 32)    4128
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, None, None, 16)    4624
# _________________________________________________________________
# conv2d_transpose_3 (Conv2DTr (None, None, None, 32)    2080
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, None, None, 32)    9248
# =================================================================
# Total params: 51,496
# Trainable params: 51,496
# Non-trainable params: 0
# _________________________________________________________________

# %%
# compile model
opt = optimizers.Adam(lr=0.001)
model.compile(optimizer=opt,
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %%
train_generator = generator(batch_size, train_dir, H, W)
test_generator = generator(batch_size, test_dir, H, W)
tr_size = len(glob.glob(train_dir))
ts_size = len(glob.glob(test_dir))
steps_per_epoch = tr_size// batch_size
validation_steps = ts_size // batch_size
print(tr_size,ts_size,steps_per_epoch,validation_steps)
# Out:
# 400 200 12 6

# %%
t0 = time()
hist = model.fit_generator(train_generator,
                            steps_per_epoch=steps_per_epoch,
                            epochs=100,
                            validation_data=test_generator,
                            validation_steps=validation_steps,
                            class_weight=class_weight,
                            verbose=1)
print('Train time: %.fm'%((time()-t0)/60))
# Out:
# Epoch 1/100
# /home/tking/.local/lib/python3.5/site-packages/ipykernel_launcher.py:9: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.
#   if __name__ == '__main__':
# 12/12 [==============================] - 5s 377ms/step - loss: 6.3548 - acc: 0.0502 - val_loss: 5.3431 - val_acc: 0.1181
# Epoch 2/100
# 12/12 [==============================] - 3s 242ms/step - loss: 5.2308 - acc: 0.1094 - val_loss: 4.9869 - val_acc: 0.1142
# Epoch 3/100
# 12/12 [==============================] - 3s 210ms/step - loss: 4.8624 - acc: 0.1446 - val_loss: 4.7669 - val_acc: 0.1701
# Epoch 4/100
# 12/12 [==============================] - 3s 223ms/step - loss: 4.7804 - acc: 0.2214 - val_loss: 4.7393 - val_acc: 0.2308
# Epoch 5/100
# 12/12 [==============================] - 3s 241ms/step - loss: 4.7673 - acc: 0.2394 - val_loss: 4.6399 - val_acc: 0.2585
# Epoch 6/100
# 12/12 [==============================] - 3s 235ms/step - loss: 4.6466 - acc: 0.2919 - val_loss: 4.6308 - val_acc: 0.2895
# Epoch 7/100
# 12/12 [==============================] - 3s 212ms/step - loss: 4.6823 - acc: 0.2739 - val_loss: 4.6533 - val_acc: 0.2589
# Epoch 8/100
# 12/12 [==============================] - 3s 214ms/step - loss: 4.6808 - acc: 0.2415 - val_loss: 4.6297 - val_acc: 0.2410
# Epoch 9/100
# 12/12 [==============================] - 3s 221ms/step - loss: 4.6842 - acc: 0.2419 - val_loss: 4.6069 - val_acc: 0.2275
# Epoch 10/100
# 12/12 [==============================] - 2s 208ms/step - loss: 4.7174 - acc: 0.2099 - val_loss: 4.5775 - val_acc: 0.2007
# Epoch 11/100
# 12/12 [==============================] - 2s 203ms/step - loss: 4.6432 - acc: 0.1944 - val_loss: 4.5678 - val_acc: 0.1974
# Epoch 12/100
# 12/12 [==============================] - 3s 235ms/step - loss: 4.6349 - acc: 0.1871 - val_loss: 4.5043 - val_acc: 0.1943
# Epoch 13/100
# 12/12 [==============================] - 3s 247ms/step - loss: 4.5965 - acc: 0.1863 - val_loss: 4.6346 - val_acc: 0.1724
# Epoch 14/100
# 12/12 [==============================] - 2s 203ms/step - loss: 4.6088 - acc: 0.1669 - val_loss: 4.5685 - val_acc: 0.1761
# Epoch 15/100
# 12/12 [==============================] - 2s 208ms/step - loss: 4.6209 - acc: 0.1701 - val_loss: 4.5428 - val_acc: 0.1813
# Epoch 16/100
# 12/12 [==============================] - 3s 219ms/step - loss: 4.6788 - acc: 0.1569 - val_loss: 4.4909 - val_acc: 0.1574
# Epoch 17/100
# 12/12 [==============================] - 3s 235ms/step - loss: 4.5727 - acc: 0.1594 - val_loss: 4.5583 - val_acc: 0.1594
# Epoch 18/100
# 12/12 [==============================] - 3s 222ms/step - loss: 4.5176 - acc: 0.1399 - val_loss: 4.4498 - val_acc: 0.1369
# Epoch 19/100
# 12/12 [==============================] - 3s 226ms/step - loss: 4.5874 - acc: 0.1350 - val_loss: 4.4585 - val_acc: 0.1311
# Epoch 20/100
# 12/12 [==============================] - 2s 205ms/step - loss: 4.5463 - acc: 0.1236 - val_loss: 4.5336 - val_acc: 0.1171
# Epoch 21/100
# 12/12 [==============================] - 3s 235ms/step - loss: 4.5916 - acc: 0.1087 - val_loss: 4.4418 - val_acc: 0.1142
# Epoch 22/100
# 12/12 [==============================] - 3s 245ms/step - loss: 4.4869 - acc: 0.1033 - val_loss: 4.4448 - val_acc: 0.0991
# Epoch 23/100
# 12/12 [==============================] - 3s 249ms/step - loss: 4.5035 - acc: 0.0944 - val_loss: 4.3829 - val_acc: 0.1430
# Epoch 24/100
# 12/12 [==============================] - 2s 203ms/step - loss: 4.5058 - acc: 0.1232 - val_loss: 4.5055 - val_acc: 0.1451
# Epoch 25/100
# 12/12 [==============================] - 2s 207ms/step - loss: 4.5572 - acc: 0.1333 - val_loss: 4.4776 - val_acc: 0.1231
# Epoch 26/100
# 12/12 [==============================] - 3s 261ms/step - loss: 4.5262 - acc: 0.1401 - val_loss: 4.4895 - val_acc: 0.1590
# Epoch 27/100
# 12/12 [==============================] - 3s 266ms/step - loss: 4.4815 - acc: 0.1413 - val_loss: 4.4317 - val_acc: 0.1599
# Epoch 28/100
# 12/12 [==============================] - 3s 241ms/step - loss: 4.5163 - acc: 0.1586 - val_loss: 4.4565 - val_acc: 0.1478
# Epoch 29/100
# 12/12 [==============================] - 2s 191ms/step - loss: 4.5548 - acc: 0.1383 - val_loss: 4.4962 - val_acc: 0.1532
# Epoch 30/100
# 12/12 [==============================] - 3s 270ms/step - loss: 4.4894 - acc: 0.1653 - val_loss: 4.4823 - val_acc: 0.1257
# Epoch 31/100
# 12/12 [==============================] - 3s 236ms/step - loss: 4.4801 - acc: 0.1596 - val_loss: 4.4443 - val_acc: 0.1778
# Epoch 32/100
# 12/12 [==============================] - 3s 243ms/step - loss: 4.5287 - acc: 0.1455 - val_loss: 4.4950 - val_acc: 0.1923
# Epoch 33/100
# 12/12 [==============================] - 3s 216ms/step - loss: 4.5153 - acc: 0.1597 - val_loss: 4.4785 - val_acc: 0.1925
# Epoch 34/100
# 12/12 [==============================] - 2s 202ms/step - loss: 4.5085 - acc: 0.1708 - val_loss: 4.4783 - val_acc: 0.2204
# Epoch 35/100
# 12/12 [==============================] - 3s 222ms/step - loss: 4.4435 - acc: 0.1914 - val_loss: 4.4725 - val_acc: 0.2205
# Epoch 36/100
# 12/12 [==============================] - 3s 249ms/step - loss: 4.4842 - acc: 0.1926 - val_loss: 4.3896 - val_acc: 0.2353
# Epoch 37/100
# 12/12 [==============================] - 3s 219ms/step - loss: 4.4903 - acc: 0.2060 - val_loss: 4.4586 - val_acc: 0.2705
# Epoch 38/100
# 12/12 [==============================] - 3s 287ms/step - loss: 4.5179 - acc: 0.2340 - val_loss: 4.4411 - val_acc: 0.2551
# Epoch 39/100
# 12/12 [==============================] - 3s 226ms/step - loss: 4.5075 - acc: 0.2318 - val_loss: 4.4036 - val_acc: 0.3082
# Epoch 40/100
# 12/12 [==============================] - 3s 211ms/step - loss: 4.4211 - acc: 0.2566 - val_loss: 4.4469 - val_acc: 0.3416
# Epoch 41/100
# 12/12 [==============================] - 3s 242ms/step - loss: 4.4091 - acc: 0.2818 - val_loss: 4.4295 - val_acc: 0.3349
# Epoch 42/100
# 12/12 [==============================] - 3s 235ms/step - loss: 4.4589 - acc: 0.3262 - val_loss: 4.4875 - val_acc: 0.3496
# Epoch 43/100
# 12/12 [==============================] - 3s 213ms/step - loss: 4.4638 - acc: 0.3264 - val_loss: 4.4706 - val_acc: 0.3810
# Epoch 44/100
# 12/12 [==============================] - 2s 200ms/step - loss: 4.4405 - acc: 0.3467 - val_loss: 4.3748 - val_acc: 0.4236
# Epoch 45/100
# 12/12 [==============================] - 2s 201ms/step - loss: 4.4415 - acc: 0.3630 - val_loss: 4.3618 - val_acc: 0.4142
# Epoch 46/100
# 12/12 [==============================] - 2s 207ms/step - loss: 4.4243 - acc: 0.3814 - val_loss: 4.4895 - val_acc: 0.3756
# Epoch 47/100
# 12/12 [==============================] - 3s 220ms/step - loss: 4.3993 - acc: 0.3645 - val_loss: 4.4133 - val_acc: 0.3856
# Epoch 48/100
# 12/12 [==============================] - 2s 200ms/step - loss: 4.3804 - acc: 0.3323 - val_loss: 4.3221 - val_acc: 0.2695
# Epoch 49/100
# 12/12 [==============================] - 3s 248ms/step - loss: 4.3886 - acc: 0.1471 - val_loss: 4.2894 - val_acc: 0.1172
# Epoch 50/100
# 12/12 [==============================] - 3s 212ms/step - loss: 4.4358 - acc: 0.1585 - val_loss: 4.4093 - val_acc: 0.2385
# Epoch 51/100
# 12/12 [==============================] - 2s 191ms/step - loss: 4.3448 - acc: 0.1415 - val_loss: 4.4483 - val_acc: 0.0552
# Epoch 52/100
# 12/12 [==============================] - 3s 229ms/step - loss: 4.4540 - acc: 0.0508 - val_loss: 4.4735 - val_acc: 0.1481
# Epoch 53/100
# 12/12 [==============================] - 3s 263ms/step - loss: 4.3774 - acc: 0.1365 - val_loss: 4.5333 - val_acc: 0.1690
# Epoch 54/100
# 12/12 [==============================] - 3s 221ms/step - loss: 4.3438 - acc: 0.1793 - val_loss: 4.3855 - val_acc: 0.1736
# Epoch 55/100
# 12/12 [==============================] - 3s 220ms/step - loss: 4.3432 - acc: 0.1847 - val_loss: 4.5249 - val_acc: 0.1833
# Epoch 56/100
# 12/12 [==============================] - 3s 210ms/step - loss: 4.4462 - acc: 0.1436 - val_loss: 4.4505 - val_acc: 0.0759
# Epoch 57/100
# 12/12 [==============================] - 2s 196ms/step - loss: 4.3754 - acc: 0.1197 - val_loss: 4.3386 - val_acc: 0.2580
# Epoch 58/100
# 12/12 [==============================] - 3s 210ms/step - loss: 4.4087 - acc: 0.2294 - val_loss: 4.4208 - val_acc: 0.1539
# Epoch 59/100
# 12/12 [==============================] - 3s 213ms/step - loss: 4.3395 - acc: 0.1373 - val_loss: 4.4813 - val_acc: 0.0927
# Epoch 60/100
# 12/12 [==============================] - 3s 210ms/step - loss: 4.3300 - acc: 0.1043 - val_loss: 4.2672 - val_acc: 0.1749
# Epoch 61/100
# 12/12 [==============================] - 3s 248ms/step - loss: 4.3070 - acc: 0.2190 - val_loss: 4.4598 - val_acc: 0.1844
# Epoch 62/100
# 12/12 [==============================] - 3s 231ms/step - loss: 4.3223 - acc: 0.1634 - val_loss: 4.4399 - val_acc: 0.0645
# Epoch 63/100
# 12/12 [==============================] - 2s 200ms/step - loss: 4.4126 - acc: 0.1242 - val_loss: 4.4804 - val_acc: 0.1594
# Epoch 64/100
# 12/12 [==============================] - 3s 243ms/step - loss: 4.3145 - acc: 0.2115 - val_loss: 4.5003 - val_acc: 0.2286
# Epoch 65/100
# 12/12 [==============================] - 3s 234ms/step - loss: 4.3389 - acc: 0.1541 - val_loss: 4.4843 - val_acc: 0.0378
# Epoch 66/100
# 12/12 [==============================] - 3s 246ms/step - loss: 4.3009 - acc: 0.0937 - val_loss: 4.4885 - val_acc: 0.1392
# Epoch 67/100
# 12/12 [==============================] - 3s 229ms/step - loss: 4.2771 - acc: 0.1582 - val_loss: 4.4155 - val_acc: 0.1304
# Epoch 68/100
# 12/12 [==============================] - 3s 227ms/step - loss: 4.2599 - acc: 0.1626 - val_loss: 4.5318 - val_acc: 0.2563
# Epoch 69/100
# 12/12 [==============================] - 3s 221ms/step - loss: 4.2241 - acc: 0.3250 - val_loss: 4.5243 - val_acc: 0.3081
# Epoch 70/100
# 12/12 [==============================] - 3s 225ms/step - loss: 4.1949 - acc: 0.1586 - val_loss: 4.4518 - val_acc: 0.0780
# Epoch 71/100
# 12/12 [==============================] - 3s 222ms/step - loss: 4.2328 - acc: 0.1532 - val_loss: 4.5668 - val_acc: 0.3085
# Epoch 72/100
# 12/12 [==============================] - 2s 205ms/step - loss: 4.3103 - acc: 0.2176 - val_loss: 4.5087 - val_acc: 0.1139
# Epoch 73/100
# 12/12 [==============================] - 3s 268ms/step - loss: 4.2699 - acc: 0.0962 - val_loss: 4.4719 - val_acc: 0.1642
# Epoch 74/100
# 12/12 [==============================] - 3s 222ms/step - loss: 4.2250 - acc: 0.2326 - val_loss: 4.6100 - val_acc: 0.1777
# Epoch 75/100
# 12/12 [==============================] - 3s 244ms/step - loss: 4.1515 - acc: 0.1865 - val_loss: 4.6670 - val_acc: 0.2212
# Epoch 76/100
# 12/12 [==============================] - 3s 238ms/step - loss: 4.2318 - acc: 0.1651 - val_loss: 4.4936 - val_acc: 0.1283
# Epoch 77/100
# 12/12 [==============================] - 3s 228ms/step - loss: 4.2491 - acc: 0.1634 - val_loss: 4.5897 - val_acc: 0.1334
# Epoch 78/100
# 12/12 [==============================] - 2s 199ms/step - loss: 4.3095 - acc: 0.2003 - val_loss: 4.5108 - val_acc: 0.2462
# Epoch 79/100
# 12/12 [==============================] - 3s 267ms/step - loss: 4.1684 - acc: 0.2723 - val_loss: 4.4864 - val_acc: 0.2951
# Epoch 80/100
# 12/12 [==============================] - 3s 237ms/step - loss: 4.1377 - acc: 0.2591 - val_loss: 4.5978 - val_acc: 0.1973
# Epoch 81/100
# 12/12 [==============================] - 3s 217ms/step - loss: 4.2267 - acc: 0.1841 - val_loss: 4.5519 - val_acc: 0.2044
# Epoch 82/100
# 12/12 [==============================] - 2s 195ms/step - loss: 4.1797 - acc: 0.2237 - val_loss: 4.4771 - val_acc: 0.2917
# Epoch 83/100
# 12/12 [==============================] - 3s 255ms/step - loss: 4.1938 - acc: 0.2444 - val_loss: 4.4845 - val_acc: 0.1720
# Epoch 84/100
# 12/12 [==============================] - 3s 245ms/step - loss: 4.1565 - acc: 0.1751 - val_loss: 4.4902 - val_acc: 0.2995
# Epoch 85/100
# 12/12 [==============================] - 3s 276ms/step - loss: 4.1936 - acc: 0.2352 - val_loss: 4.6395 - val_acc: 0.1265
# Epoch 86/100
# 12/12 [==============================] - 3s 234ms/step - loss: 4.1375 - acc: 0.2539 - val_loss: 4.6870 - val_acc: 0.2998
# Epoch 87/100
# 12/12 [==============================] - 3s 221ms/step - loss: 4.0931 - acc: 0.1985 - val_loss: 4.5022 - val_acc: 0.1982
# Epoch 88/100
# 12/12 [==============================] - 3s 222ms/step - loss: 4.0914 - acc: 0.2409 - val_loss: 4.5164 - val_acc: 0.1897
# Epoch 89/100
# 12/12 [==============================] - 3s 253ms/step - loss: 4.0557 - acc: 0.2148 - val_loss: 4.6991 - val_acc: 0.2793
# Epoch 90/100
# 12/12 [==============================] - 2s 204ms/step - loss: 4.0580 - acc: 0.2187 - val_loss: 4.6968 - val_acc: 0.2031
# Epoch 91/100
# 12/12 [==============================] - 2s 203ms/step - loss: 4.0679 - acc: 0.2503 - val_loss: 4.8057 - val_acc: 0.1560
# Epoch 92/100
# 12/12 [==============================] - 3s 235ms/step - loss: 4.1028 - acc: 0.2477 - val_loss: 4.6391 - val_acc: 0.2114
# Epoch 93/100
# 12/12 [==============================] - 2s 202ms/step - loss: 4.1041 - acc: 0.2517 - val_loss: 4.7034 - val_acc: 0.1888
# Epoch 94/100
# 12/12 [==============================] - 3s 227ms/step - loss: 4.0565 - acc: 0.2587 - val_loss: 4.9183 - val_acc: 0.1835
# Epoch 95/100
# 12/12 [==============================] - 2s 203ms/step - loss: 3.9947 - acc: 0.2540 - val_loss: 4.6677 - val_acc: 0.2425
# Epoch 96/100
# 12/12 [==============================] - 3s 209ms/step - loss: 4.0539 - acc: 0.2782 - val_loss: 4.7541 - val_acc: 0.1931
# Epoch 97/100
# 12/12 [==============================] - 3s 238ms/step - loss: 4.0249 - acc: 0.2405 - val_loss: 4.7707 - val_acc: 0.2379
# Epoch 98/100
# 12/12 [==============================] - 3s 210ms/step - loss: 4.0258 - acc: 0.2472 - val_loss: 4.7176 - val_acc: 0.2604
# Epoch 99/100
# 12/12 [==============================] - 3s 260ms/step - loss: 4.0294 - acc: 0.2887 - val_loss: 4.5330 - val_acc: 0.1716
# Epoch 100/100
# 12/12 [==============================] - 3s 257ms/step - loss: 4.0211 - acc: 0.2456 - val_loss: 4.6159 - val_acc: 0.2469
# Train time: 5m

# %%
plt.figure(figsize=(15,5))
plt.subplot(1,2,1)
plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.legend(['loss','val_loss'])
plt.grid()
plt.subplot(1,2,2)
plt.plot(hist.history['acc'])
plt.plot(hist.history['val_acc'])
plt.legend(['acc','val_acc'])
plt.grid()

# %%
history = []
history.append(hist.history['loss'])
history.append(hist.history['val_loss'])
history.append(hist.history['acc'])
history.append(hist.history['val_acc'])
history = np.array(history)
np.savetxt(model_name+"_"+dir_name+"_history.txt", history, delimiter=",")

# %%
model_json = model.to_json()
with open(model_name+"_"+dir_name+".json", "w") as json_file:
    json_file.write(model_json)
model.save_weights(model_name+"_"+dir_name+".h5")

# %%
from keras.models import model_from_json

# %%
json_file = open(model_name+"_"+dir_name+".json", "r")
loaded_model_json = json_file.read()
json_file.close()
loaded_model = model_from_json(loaded_model_json)
# load weights into new model
loaded_model.load_weights(model_name+"_"+dir_name+".h5")

# %%
# result on train images
X,Y = generator(batch_size, train_dir, H, W).__next__()
Yhat = model.predict(X)
j =1
plt.figure(figsize=(20,20))
for i in range(12):
    # original
    plt.subplot(6,8,j)
    j+=1
    img = XY2img(X[i],Y[i])
    plt.imshow(img)
    plt.axis('OFF')
    # grayscale
    plt.subplot(6,8,j)
    j+=1
    plt.imshow(X[i,:,:,0],'gray')
    plt.axis('OFF')
    # predict
    plt.subplot(6,8,j)
    j += 1
    img = XY2img(X[i],Yhat[i])
    plt.imshow(img)
    plt.axis('OFF')
    # predict
    plt.subplot(6,8,j)
    j += 1
    img = XY2imgf(X[i],Yhat[i])
    plt.imshow(img)
    plt.axis('OFF')
# Out:
# /home/tking/.local/lib/python3.5/site-packages/ipykernel_launcher.py:9: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.
#   if __name__ == '__main__':

# %%
# result on test images
X,Y = generator(batch_size, test_dir, H, W).__next__()
Yhat = model.predict(X)
j =1
plt.figure(figsize=(20,20))
for i in range(12):
    # original
    plt.subplot(6,8,j)
    j+=1
    img = XY2img(X[i],Y[i])
    plt.imshow(img)
    plt.axis('OFF')
    # grayscale
    plt.subplot(6,8,j)
    j+=1
    plt.imshow(X[i,:,:,0],'gray')
    plt.axis('OFF')
    # predict
    plt.subplot(6,8,j)
    j += 1
    img = XY2img(X[i],Yhat[i])
    plt.imshow(img)
    plt.axis('OFF')
    # predict
    plt.subplot(6,8,j)
    j += 1
    img = XY2imgf(X[i],Yhat[i])
    plt.imshow(img)
    plt.axis('OFF')
# Out:
# /home/tking/.local/lib/python3.5/site-packages/ipykernel_launcher.py:9: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.
#   if __name__ == '__main__':

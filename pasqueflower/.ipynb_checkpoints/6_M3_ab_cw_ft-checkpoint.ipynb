# %%
from keras.layers import Conv2D, UpSampling2D, InputLayer, Conv2DTranspose
from keras.layers import Activation, Dense, Dropout, Flatten
from keras.layers.normalization import BatchNormalization
from keras.models import Sequential
from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img
from skimage.color import rgb2lab, lab2rgb, rgb2gray, xyz2lab
from skimage.io import imsave
import numpy as np
import os
import random
import tensorflow as tf
from time import time

import cv2

from scipy.misc import imresize
from skimage.transform import resize

import glob

import matplotlib.pyplot as plt
# %matplotlib inline

from keras.callbacks import EarlyStopping
from keras.utils import to_categorical
import random
from keras import optimizers
from scipy.ndimage import filters
# Out:
# /home/tking/.local/lib/python3.5/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
#define parameters:
dir_name = "Pasqueflower" # Variable
model_name = "6_M3_ab_cw_ft"# Variable

train_dir = r"../../images/"+dir_name+"/train/*.jpg"
test_dir = r"../../images/"+dir_name+"/test/*.jpg"
H = 64
W = 64
batch_size = 32

# %%
# select vaild images and put into train and test dir (only run once) 
# i = 0
# num_tr = 2000
# num_ts = 500
# for img in glob.glob(r"../../images/"+dir_name+"/*.jpg"):
#     try:
#         n= cv2.imread(img)#BGR
#         if  n is None or np.mean(n)>250 or np.mean(np.std(n,axis=2))<2:
#             os.remove(img)
#         else:
#             if i<num_tr:
#                 i+=1
#                 os.rename(img,r"../../images/"+dir_name+"/train/"+str(i)+".jpg")
#             elif i>=num_tr and i<num_tr+num_ts:
#                 i+=1
#                 os.rename(img,r"../../images/"+dir_name+"/test/"+str(i)+".jpg")
#             else:
#                 break
#     except:
#         pass
print('tr_size = ',len(glob.glob(train_dir)))
print('ts_size = ',len(glob.glob(test_dir)))
# Out:
# tr_size =  400
# ts_size =  200

# %%
def generator(batch_size, dir_path, H, W):
    while True:
        X = []
        Y = []
        img_batch = random.sample(glob.glob(dir_path), batch_size)
        for img in img_batch:
            # choose random index in features
            n= cv2.imread(img)#BGR
            m = imresize(n,(H,W,3))
            img_lab = cv2.cvtColor(m.astype(np.uint8), cv2.COLOR_BGR2LAB)
            L = img_lab[:,:,0].reshape(1,H,W,1)
            y = np.floor(img_lab[:,:,1:]/16)

            # to_categorical
            y0=y[:,:,0].flatten()
            y1=y[:,:,1].flatten()
            Yc2d0 = to_categorical(y0, num_classes = 16 )
            Yc3d0 = Yc2d0.reshape(H,W,16)
            Yc2d1 = to_categorical(y1, num_classes = 16 )
            Yc3d1 = Yc2d1.reshape(H,W,16)
            Yc3d = np.zeros((H,W,32))
            Yc3d[:,:,:16] = Yc3d0
            Yc3d[:,:,16:] = Yc3d1

            Y.append(Yc3d)
            X.append(L)
        X=np.array(X)
        Y=np.array(Y)
        X=np.reshape(X, (batch_size, H, W, 1))
        Y=np.reshape(Y, (batch_size, H, W, 32))
        yield X, Y

# %%
def XY2img(X,Y):
    H, W, _ = X.shape
    img_lab = np.zeros((H,W,3))
    img_lab[:,:,0] = X[:,:,0]
    img_lab[:,:,1] = np.argmax(Y[:,:,:16],axis=2)*16+8
    img_lab[:,:,2] = np.argmax(Y[:,:,16:],axis=2)*16+8
    img = cv2.cvtColor(img_lab.astype(np.uint8), cv2.COLOR_LAB2RGB)
    return img

# %%
def XY2imgf(X,Y):
    H, W, _ = X.shape
    img_lab = np.zeros((H,W,3))
    img_lab[:,:,0] = X[:,:,0]
    img_lab[:,:,1] = filters.gaussian_filter(np.argmax(Y[:,:,:16],axis=2)*16+8,5)
    img_lab[:,:,2] = filters.gaussian_filter(np.argmax(Y[:,:,16:],axis=2)*16+8,5)
    img = cv2.cvtColor(img_lab.astype(np.uint8), cv2.COLOR_LAB2RGB)
    return img

# %%
# show some images
plt.figure(figsize=(15,5))
X,Y = generator(batch_size, train_dir, H, W).__next__()    
for i in range(8):
    plt.subplot(1,8,i+1)
    img = XY2img(X[i],Y[i])
    plt.imshow(img)
    plt.axis('off')
# Out:
# /home/tking/.local/lib/python3.5/site-packages/ipykernel_launcher.py:9: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.
#   if __name__ == '__main__':

# %%
# read images to compute class_weight
Y = []
img_sample = random.sample(glob.glob(train_dir), 400)#save memory
for img in img_sample:
    n= cv2.imread(img)#BGR
    m = imresize(n,(H,W,3))
    img_lab = cv2.cvtColor(m.astype(np.uint8), cv2.COLOR_BGR2LAB)
    y = np.floor(img_lab[:,:,1:]/16)
    
    # to_categorical
    y0=y[:,:,0].flatten()
    y1=y[:,:,1].flatten()
    yc2d0 = to_categorical(y0, num_classes = 16 )
    yc3d0 = yc2d0.reshape(H,W,16)
    yc2d1 = to_categorical(y1, num_classes = 16 )
    yc3d1 = yc2d1.reshape(H,W,16)
    yc3d = np.zeros((H,W,32))
    yc3d[:,:,:16] = yc3d0
    yc3d[:,:,16:] = yc3d1
    Y.append(yc3d)
num = len(Y)
Y=np.array(Y)
Y=np.reshape(Y, (num, H, W, 32))
# Out:
# /home/tking/.local/lib/python3.5/site-packages/ipykernel_launcher.py:6: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.

# %%
# compute class_weight
from sklearn.utils import class_weight
Yflat16A = Y[:,:,:,:16].reshape(num*H*W,16)
YflatA = np.argmax(Yflat16A,axis=1)
YclassA = np.unique(YflatA)
class_weight_A = class_weight.compute_class_weight('balanced',
                                                 YclassA,
                                                 YflatA)
Yflat16B = Y[:,:,:,16:].reshape(num*H*W,16)
YflatB = np.argmax(Yflat16B,axis=1)
YclassB = np.unique(YflatB)
class_weight_B = class_weight.compute_class_weight('balanced',
                                                 YclassB,
                                                 YflatB)

class_weight = np.zeros(32)
for i in range(len(YclassA)):
    class_weight[YclassA[i]]=class_weight_A[i]
for i in range(len(YclassB)):
    class_weight[YclassB[i]+16]=class_weight_B[i]

plt.stem(class_weight)
plt.yscale('log')
plt.ylabel('class_weight')
plt.xlabel('classes')
# Out:
# Text(0.5,0,'classes')

# %%
# Building the neural network
import keras.backend as K
K.clear_session()
model = Sequential()
model.add(InputLayer(input_shape=(None, None, 1)))
model.add(Conv2D(8, (3, 3), activation='relu', padding='same', strides=2))
model.add(BatchNormalization(axis=-1))
model.add(Dropout(0.25))
model.add(Conv2D(8, (3, 3), activation='relu', padding='same'))
model.add(BatchNormalization(axis=-1))
model.add(Dropout(0.25))
model.add(Conv2D(16, (3, 3), activation='relu', padding='same'))
model.add(BatchNormalization(axis=-1))
model.add(Dropout(0.25))
model.add(Conv2D(16, (3, 3), activation='relu', padding='same', strides=2))
model.add(BatchNormalization(axis=-1))
model.add(Dropout(0.25))
model.add(Conv2D(32, (3, 3), activation='relu', padding='same'))
model.add(BatchNormalization(axis=-1))
model.add(Dropout(0.25))
model.add(Conv2D(32, (3, 3), activation='relu', padding='same', strides=2))
model.add(Conv2DTranspose(32, (2,2), strides=2, padding='same', activation='relu'))
model.add(BatchNormalization(axis=-1))
model.add(Dropout(0.25))
model.add(Conv2D(32, (3, 3), activation='relu', padding='same'))
model.add(Conv2DTranspose(32, (2,2), strides=2, padding='same', activation='relu'))
model.add(BatchNormalization(axis=-1))
model.add(Dropout(0.25))
model.add(Conv2D(16, (3, 3), activation='relu', padding='same'))
model.add(Conv2DTranspose(32, (2,2), strides=2, padding='same', activation='relu'))
model.add(BatchNormalization(axis=-1))
model.add(Dropout(0.25))
model.add(Conv2D(32, (3, 3), activation='sigmoid', padding='same'))#TODO
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, None, None, 1)     0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, None, None, 8)     80
# _________________________________________________________________
# batch_normalization_1 (Batch (None, None, None, 8)     32
# _________________________________________________________________
# dropout_1 (Dropout)          (None, None, None, 8)     0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, None, None, 8)     584
# _________________________________________________________________
# batch_normalization_2 (Batch (None, None, None, 8)     32
# _________________________________________________________________
# dropout_2 (Dropout)          (None, None, None, 8)     0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, None, None, 16)    1168
# _________________________________________________________________
# batch_normalization_3 (Batch (None, None, None, 16)    64
# _________________________________________________________________
# dropout_3 (Dropout)          (None, None, None, 16)    0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, None, None, 16)    2320
# _________________________________________________________________
# batch_normalization_4 (Batch (None, None, None, 16)    64
# _________________________________________________________________
# dropout_4 (Dropout)          (None, None, None, 16)    0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, None, None, 32)    4640
# _________________________________________________________________
# batch_normalization_5 (Batch (None, None, None, 32)    128
# _________________________________________________________________
# dropout_5 (Dropout)          (None, None, None, 32)    0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, None, None, 32)    9248
# _________________________________________________________________
# conv2d_transpose_1 (Conv2DTr (None, None, None, 32)    4128
# _________________________________________________________________
# batch_normalization_6 (Batch (None, None, None, 32)    128
# _________________________________________________________________
# dropout_6 (Dropout)          (None, None, None, 32)    0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, None, None, 32)    9248
# _________________________________________________________________
# conv2d_transpose_2 (Conv2DTr (None, None, None, 32)    4128
# _________________________________________________________________
# batch_normalization_7 (Batch (None, None, None, 32)    128
# _________________________________________________________________
# dropout_7 (Dropout)          (None, None, None, 32)    0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, None, None, 16)    4624
# _________________________________________________________________
# conv2d_transpose_3 (Conv2DTr (None, None, None, 32)    2080
# _________________________________________________________________
# batch_normalization_8 (Batch (None, None, None, 32)    128
# _________________________________________________________________
# dropout_8 (Dropout)          (None, None, None, 32)    0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, None, None, 32)    9248
# =================================================================
# Total params: 52,200
# Trainable params: 51,848
# Non-trainable params: 352
# _________________________________________________________________

# %%
# compile model
opt = optimizers.Adam(lr=0.001)
model.compile(optimizer=opt,
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %%
train_generator = generator(batch_size, train_dir, H, W)
test_generator = generator(batch_size, test_dir, H, W)
tr_size = len(glob.glob(train_dir))
ts_size = len(glob.glob(test_dir))
steps_per_epoch = tr_size// batch_size
validation_steps = ts_size // batch_size
print(tr_size,ts_size,steps_per_epoch,validation_steps)
# Out:
# 400 200 12 6

# %%
t0 = time()
hist = model.fit_generator(train_generator,
                            steps_per_epoch=steps_per_epoch,
                            epochs=100,
                            validation_data=test_generator,
                            validation_steps=validation_steps,
                            class_weight=class_weight,
                            verbose=1)
print('Train time: %.fm'%((time()-t0)/60))
# Out:
# Epoch 1/100
# /home/tking/.local/lib/python3.5/site-packages/ipykernel_launcher.py:9: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.
#   if __name__ == '__main__':
# 12/12 [==============================] - 4s 353ms/step - loss: 6.9585 - acc: 0.0370 - val_loss: 6.6296 - val_acc: 0.0013
# Epoch 2/100
# 12/12 [==============================] - 3s 241ms/step - loss: 6.6003 - acc: 0.0641 - val_loss: 6.2182 - val_acc: 0.0093
# Epoch 3/100
# 12/12 [==============================] - 3s 267ms/step - loss: 5.9319 - acc: 0.1368 - val_loss: 5.7050 - val_acc: 0.2978
# Epoch 4/100
# 12/12 [==============================] - 3s 251ms/step - loss: 5.3539 - acc: 0.1922 - val_loss: 5.3224 - val_acc: 0.0189
# Epoch 5/100
# 12/12 [==============================] - 3s 242ms/step - loss: 5.1164 - acc: 0.1548 - val_loss: 5.1266 - val_acc: 0.2040
# Epoch 6/100
# 12/12 [==============================] - 3s 239ms/step - loss: 4.9765 - acc: 0.1303 - val_loss: 5.0038 - val_acc: 0.0820
# Epoch 7/100
# 12/12 [==============================] - 3s 210ms/step - loss: 4.9202 - acc: 0.1948 - val_loss: 5.1000 - val_acc: 0.3332
# Epoch 8/100
# 12/12 [==============================] - 2s 201ms/step - loss: 4.9089 - acc: 0.1467 - val_loss: 6.4149 - val_acc: 0.0193
# Epoch 9/100
# 12/12 [==============================] - 3s 232ms/step - loss: 4.8513 - acc: 0.1246 - val_loss: 6.3016 - val_acc: 0.1119
# Epoch 10/100
# 12/12 [==============================] - 2s 196ms/step - loss: 4.8466 - acc: 0.1474 - val_loss: 6.0974 - val_acc: 0.0243
# Epoch 11/100
# 12/12 [==============================] - 3s 225ms/step - loss: 4.7815 - acc: 0.1357 - val_loss: 5.7026 - val_acc: 0.1967
# Epoch 12/100
# 12/12 [==============================] - 3s 252ms/step - loss: 4.7441 - acc: 0.1628 - val_loss: 4.9135 - val_acc: 0.0298
# Epoch 13/100
# 12/12 [==============================] - 3s 250ms/step - loss: 4.7226 - acc: 0.1398 - val_loss: 5.8381 - val_acc: 0.0740
# Epoch 14/100
# 12/12 [==============================] - 3s 221ms/step - loss: 4.6941 - acc: 0.1322 - val_loss: 4.8701 - val_acc: 0.0446
# Epoch 15/100
# 12/12 [==============================] - 3s 229ms/step - loss: 4.7219 - acc: 0.1216 - val_loss: 5.7430 - val_acc: 0.0277
# Epoch 16/100
# 12/12 [==============================] - 3s 217ms/step - loss: 4.6232 - acc: 0.1274 - val_loss: 4.8886 - val_acc: 0.1145
# Epoch 17/100
# 12/12 [==============================] - 3s 227ms/step - loss: 4.7271 - acc: 0.1637 - val_loss: 4.7767 - val_acc: 0.1248
# Epoch 18/100
# 12/12 [==============================] - 3s 250ms/step - loss: 4.6468 - acc: 0.1670 - val_loss: 4.7250 - val_acc: 0.1896
# Epoch 19/100
# 12/12 [==============================] - 3s 223ms/step - loss: 4.6476 - acc: 0.1819 - val_loss: 4.5630 - val_acc: 0.2053
# Epoch 20/100
# 12/12 [==============================] - 3s 218ms/step - loss: 4.6755 - acc: 0.1374 - val_loss: 4.5184 - val_acc: 0.2279
# Epoch 21/100
# 12/12 [==============================] - 2s 201ms/step - loss: 4.5732 - acc: 0.1596 - val_loss: 4.5299 - val_acc: 0.1000
# Epoch 22/100
# 12/12 [==============================] - 3s 289ms/step - loss: 4.5636 - acc: 0.1349 - val_loss: 4.6505 - val_acc: 0.1948
# Epoch 23/100
# 12/12 [==============================] - 3s 226ms/step - loss: 4.6782 - acc: 0.1533 - val_loss: 4.6611 - val_acc: 0.2429
# Epoch 24/100
# 12/12 [==============================] - 3s 222ms/step - loss: 4.5990 - acc: 0.1391 - val_loss: 4.7925 - val_acc: 0.1775
# Epoch 25/100
# 12/12 [==============================] - 3s 209ms/step - loss: 4.6557 - acc: 0.1747 - val_loss: 5.0154 - val_acc: 0.2201
# Epoch 26/100
# 12/12 [==============================] - 2s 201ms/step - loss: 4.5796 - acc: 0.1294 - val_loss: 5.2217 - val_acc: 0.1340
# Epoch 27/100
# 12/12 [==============================] - 3s 217ms/step - loss: 4.5968 - acc: 0.1682 - val_loss: 5.0383 - val_acc: 0.2246
# Epoch 28/100
# 12/12 [==============================] - 3s 247ms/step - loss: 4.5819 - acc: 0.1771 - val_loss: 4.7832 - val_acc: 0.2048
# Epoch 29/100
# 12/12 [==============================] - 2s 201ms/step - loss: 4.6393 - acc: 0.1268 - val_loss: 4.6524 - val_acc: 0.2508
# Epoch 30/100
# 12/12 [==============================] - 3s 260ms/step - loss: 4.5002 - acc: 0.1630 - val_loss: 4.5994 - val_acc: 0.2885
# Epoch 31/100
# 12/12 [==============================] - 2s 195ms/step - loss: 4.5916 - acc: 0.1534 - val_loss: 4.5372 - val_acc: 0.2264
# Epoch 32/100
# 12/12 [==============================] - 3s 224ms/step - loss: 4.5684 - acc: 0.0962 - val_loss: 4.6468 - val_acc: 0.2097
# Epoch 33/100
# 12/12 [==============================] - 3s 233ms/step - loss: 4.5452 - acc: 0.1146 - val_loss: 4.5047 - val_acc: 0.3095
# Epoch 34/100
# 12/12 [==============================] - 3s 221ms/step - loss: 4.5784 - acc: 0.1355 - val_loss: 4.5808 - val_acc: 0.3005
# Epoch 35/100
# 12/12 [==============================] - 2s 204ms/step - loss: 4.4790 - acc: 0.1418 - val_loss: 4.5960 - val_acc: 0.2884
# Epoch 36/100
# 12/12 [==============================] - 3s 248ms/step - loss: 4.5107 - acc: 0.1306 - val_loss: 4.5798 - val_acc: 0.2917
# Epoch 37/100
# 12/12 [==============================] - 3s 281ms/step - loss: 4.5722 - acc: 0.1383 - val_loss: 4.5374 - val_acc: 0.2874
# Epoch 38/100
# 12/12 [==============================] - 3s 229ms/step - loss: 4.5543 - acc: 0.1278 - val_loss: 4.5792 - val_acc: 0.3134
# Epoch 39/100
# 12/12 [==============================] - 3s 233ms/step - loss: 4.6229 - acc: 0.1034 - val_loss: 4.4504 - val_acc: 0.2166
# Epoch 40/100
# 12/12 [==============================] - 3s 214ms/step - loss: 4.5253 - acc: 0.1339 - val_loss: 4.5948 - val_acc: 0.2715
# Epoch 41/100
# 12/12 [==============================] - 3s 228ms/step - loss: 4.4877 - acc: 0.1397 - val_loss: 4.4284 - val_acc: 0.2237
# Epoch 42/100
# 12/12 [==============================] - 3s 276ms/step - loss: 4.4405 - acc: 0.1426 - val_loss: 4.5232 - val_acc: 0.2622
# Epoch 43/100
# 12/12 [==============================] - 3s 222ms/step - loss: 4.5528 - acc: 0.1294 - val_loss: 4.4261 - val_acc: 0.2527
# Epoch 44/100
# 12/12 [==============================] - 3s 214ms/step - loss: 4.5540 - acc: 0.1162 - val_loss: 4.5046 - val_acc: 0.2295
# Epoch 45/100
# 12/12 [==============================] - 3s 215ms/step - loss: 4.5065 - acc: 0.1566 - val_loss: 4.4078 - val_acc: 0.2740
# Epoch 46/100
# 12/12 [==============================] - 3s 237ms/step - loss: 4.4896 - acc: 0.1503 - val_loss: 4.5108 - val_acc: 0.2518
# Epoch 47/100
# 12/12 [==============================] - 3s 209ms/step - loss: 4.5556 - acc: 0.1274 - val_loss: 4.5396 - val_acc: 0.2605
# Epoch 48/100
# 12/12 [==============================] - 3s 209ms/step - loss: 4.5277 - acc: 0.1382 - val_loss: 4.4300 - val_acc: 0.2314
# Epoch 49/100
# 12/12 [==============================] - 3s 213ms/step - loss: 4.5132 - acc: 0.1203 - val_loss: 4.4222 - val_acc: 0.2685
# Epoch 50/100
# 12/12 [==============================] - 3s 232ms/step - loss: 4.5424 - acc: 0.1213 - val_loss: 4.4526 - val_acc: 0.3015
# Epoch 51/100
# 12/12 [==============================] - 3s 215ms/step - loss: 4.5181 - acc: 0.1387 - val_loss: 4.5208 - val_acc: 0.3152
# Epoch 52/100
# 12/12 [==============================] - 2s 205ms/step - loss: 4.4617 - acc: 0.1535 - val_loss: 4.5090 - val_acc: 0.2917
# Epoch 53/100
# 12/12 [==============================] - 3s 212ms/step - loss: 4.4845 - acc: 0.1462 - val_loss: 4.5344 - val_acc: 0.2580
# Epoch 54/100
# 12/12 [==============================] - 3s 258ms/step - loss: 4.4913 - acc: 0.1481 - val_loss: 4.4258 - val_acc: 0.2941
# Epoch 55/100
# 12/12 [==============================] - 3s 219ms/step - loss: 4.4871 - acc: 0.1449 - val_loss: 4.5824 - val_acc: 0.2317
# Epoch 56/100
# 12/12 [==============================] - 3s 214ms/step - loss: 4.4835 - acc: 0.1451 - val_loss: 4.5010 - val_acc: 0.2797
# Epoch 57/100
# 12/12 [==============================] - 2s 204ms/step - loss: 4.4798 - acc: 0.1738 - val_loss: 4.4270 - val_acc: 0.2784
# Epoch 58/100
# 12/12 [==============================] - 3s 257ms/step - loss: 4.4772 - acc: 0.1598 - val_loss: 4.3671 - val_acc: 0.1981
# Epoch 59/100
# 12/12 [==============================] - 3s 222ms/step - loss: 4.5767 - acc: 0.1209 - val_loss: 4.5120 - val_acc: 0.1863
# Epoch 60/100
# 12/12 [==============================] - 2s 199ms/step - loss: 4.5040 - acc: 0.1070 - val_loss: 4.5559 - val_acc: 0.1163
# Epoch 61/100
# 12/12 [==============================] - 3s 222ms/step - loss: 4.4565 - acc: 0.0906 - val_loss: 4.4893 - val_acc: 0.2014
# Epoch 62/100
# 12/12 [==============================] - 2s 196ms/step - loss: 4.5573 - acc: 0.0995 - val_loss: 4.5616 - val_acc: 0.2129
# Epoch 63/100
# 12/12 [==============================] - 3s 249ms/step - loss: 4.4685 - acc: 0.1245 - val_loss: 4.4364 - val_acc: 0.1604
# Epoch 64/100
# 12/12 [==============================] - 3s 213ms/step - loss: 4.4087 - acc: 0.1002 - val_loss: 4.4107 - val_acc: 0.1194
# Epoch 65/100
# 12/12 [==============================] - 2s 202ms/step - loss: 4.5132 - acc: 0.1144 - val_loss: 4.4982 - val_acc: 0.2434
# Epoch 66/100
# 12/12 [==============================] - 3s 223ms/step - loss: 4.3917 - acc: 0.1486 - val_loss: 4.4452 - val_acc: 0.1918
# Epoch 67/100
# 12/12 [==============================] - 3s 239ms/step - loss: 4.4168 - acc: 0.1522 - val_loss: 4.5682 - val_acc: 0.2162
# Epoch 68/100
# 12/12 [==============================] - 2s 200ms/step - loss: 4.4665 - acc: 0.1567 - val_loss: 4.5627 - val_acc: 0.2359
# Epoch 69/100
# 12/12 [==============================] - 2s 207ms/step - loss: 4.5250 - acc: 0.1569 - val_loss: 4.6649 - val_acc: 0.2478
# Epoch 70/100
# 12/12 [==============================] - 3s 244ms/step - loss: 4.5206 - acc: 0.1532 - val_loss: 4.5241 - val_acc: 0.2573
# Epoch 71/100
# 12/12 [==============================] - 3s 269ms/step - loss: 4.4045 - acc: 0.1507 - val_loss: 4.4694 - val_acc: 0.1842
# Epoch 72/100
# 12/12 [==============================] - 3s 239ms/step - loss: 4.4458 - acc: 0.1292 - val_loss: 4.5495 - val_acc: 0.2905
# Epoch 73/100
# 12/12 [==============================] - 3s 223ms/step - loss: 4.4196 - acc: 0.1748 - val_loss: 4.5086 - val_acc: 0.2551
# Epoch 74/100
# 12/12 [==============================] - 2s 195ms/step - loss: 4.4196 - acc: 0.1639 - val_loss: 4.4455 - val_acc: 0.2697
# Epoch 75/100
# 12/12 [==============================] - 3s 257ms/step - loss: 4.4529 - acc: 0.1468 - val_loss: 4.4869 - val_acc: 0.2256
# Epoch 76/100
# 12/12 [==============================] - 3s 229ms/step - loss: 4.4405 - acc: 0.1383 - val_loss: 4.5004 - val_acc: 0.1728
# Epoch 77/100
# 12/12 [==============================] - 3s 248ms/step - loss: 4.5041 - acc: 0.1189 - val_loss: 4.4305 - val_acc: 0.2278
# Epoch 78/100
# 12/12 [==============================] - 3s 235ms/step - loss: 4.4126 - acc: 0.1925 - val_loss: 4.4503 - val_acc: 0.2508
# Epoch 79/100
# 12/12 [==============================] - 3s 273ms/step - loss: 4.4461 - acc: 0.1885 - val_loss: 4.6125 - val_acc: 0.2620
# Epoch 80/100
# 12/12 [==============================] - 3s 237ms/step - loss: 4.4830 - acc: 0.1469 - val_loss: 4.4694 - val_acc: 0.2441
# Epoch 81/100
# 12/12 [==============================] - 3s 218ms/step - loss: 4.4735 - acc: 0.1278 - val_loss: 4.4964 - val_acc: 0.2643
# Epoch 82/100
# 12/12 [==============================] - 3s 233ms/step - loss: 4.4815 - acc: 0.1429 - val_loss: 4.4548 - val_acc: 0.2547
# Epoch 83/100
# 12/12 [==============================] - 2s 201ms/step - loss: 4.4264 - acc: 0.1823 - val_loss: 4.5365 - val_acc: 0.2591
# Epoch 84/100
# 12/12 [==============================] - 3s 239ms/step - loss: 4.4329 - acc: 0.1850 - val_loss: 4.4599 - val_acc: 0.2469
# Epoch 85/100
# 12/12 [==============================] - 3s 272ms/step - loss: 4.5007 - acc: 0.1634 - val_loss: 4.4544 - val_acc: 0.2381
# Epoch 86/100
# 12/12 [==============================] - 3s 244ms/step - loss: 4.5557 - acc: 0.1787 - val_loss: 4.5332 - val_acc: 0.2560
# Epoch 87/100
# 12/12 [==============================] - 3s 243ms/step - loss: 4.4202 - acc: 0.1657 - val_loss: 4.4916 - val_acc: 0.2613
# Epoch 88/100
# 12/12 [==============================] - 3s 217ms/step - loss: 4.4072 - acc: 0.1981 - val_loss: 4.4212 - val_acc: 0.2713
# Epoch 89/100
# 12/12 [==============================] - 2s 206ms/step - loss: 4.4624 - acc: 0.1748 - val_loss: 4.4190 - val_acc: 0.2458
# Epoch 90/100
# 12/12 [==============================] - 3s 228ms/step - loss: 4.4099 - acc: 0.1539 - val_loss: 4.4552 - val_acc: 0.2155
# Epoch 91/100
# 12/12 [==============================] - 2s 207ms/step - loss: 4.5187 - acc: 0.1450 - val_loss: 4.4548 - val_acc: 0.2816
# Epoch 92/100
# 12/12 [==============================] - 3s 217ms/step - loss: 4.4610 - acc: 0.1634 - val_loss: 4.4700 - val_acc: 0.3189
# Epoch 93/100
# 12/12 [==============================] - 3s 244ms/step - loss: 4.4677 - acc: 0.1629 - val_loss: 4.5539 - val_acc: 0.2741
# Epoch 94/100
# 12/12 [==============================] - 3s 233ms/step - loss: 4.4855 - acc: 0.1296 - val_loss: 4.5145 - val_acc: 0.1889
# Epoch 95/100
# 12/12 [==============================] - 3s 233ms/step - loss: 4.3756 - acc: 0.1298 - val_loss: 4.4406 - val_acc: 0.2187
# Epoch 96/100
# 12/12 [==============================] - 3s 239ms/step - loss: 4.4417 - acc: 0.1629 - val_loss: 4.5048 - val_acc: 0.2817
# Epoch 97/100
# 12/12 [==============================] - 3s 225ms/step - loss: 4.4205 - acc: 0.1642 - val_loss: 4.5772 - val_acc: 0.2511
# Epoch 98/100
# 12/12 [==============================] - 3s 268ms/step - loss: 4.4384 - acc: 0.1659 - val_loss: 4.5134 - val_acc: 0.2523
# Epoch 99/100
# 12/12 [==============================] - 3s 224ms/step - loss: 4.4157 - acc: 0.1576 - val_loss: 4.4453 - val_acc: 0.2557
# Epoch 100/100
# 12/12 [==============================] - 3s 217ms/step - loss: 4.3734 - acc: 0.1461 - val_loss: 4.3869 - val_acc: 0.2050
# Train time: 5m

# %%
plt.figure(figsize=(15,5))
plt.subplot(1,2,1)
plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.legend(['loss','val_loss'])
plt.grid()
plt.subplot(1,2,2)
plt.plot(hist.history['acc'])
plt.plot(hist.history['val_acc'])
plt.legend(['acc','val_acc'])
plt.grid()

# %%
history = []
history.append(hist.history['loss'])
history.append(hist.history['val_loss'])
history.append(hist.history['acc'])
history.append(hist.history['val_acc'])
history = np.array(history)
np.savetxt(model_name+"_"+dir_name+"_history.txt", history, delimiter=",")

# %%
model_json = model.to_json()
with open(model_name+"_"+dir_name+".json", "w") as json_file:
    json_file.write(model_json)
model.save_weights(model_name+"_"+dir_name+".h5")

# %%
from keras.models import model_from_json

# %%
json_file = open(model_name+"_"+dir_name+".json", "r")
loaded_model_json = json_file.read()
json_file.close()
loaded_model = model_from_json(loaded_model_json)
# load weights into new model
loaded_model.load_weights(model_name+"_"+dir_name+".h5")

# %%
# result on train images
X,Y = generator(batch_size, train_dir, H, W).__next__()
Yhat = model.predict(X)
j =1
plt.figure(figsize=(20,20))
for i in range(12):
    # original
    plt.subplot(6,8,j)
    j+=1
    img = XY2img(X[i],Y[i])
    plt.imshow(img)
    plt.axis('OFF')
    # grayscale
    plt.subplot(6,8,j)
    j+=1
    plt.imshow(X[i,:,:,0],'gray')
    plt.axis('OFF')
    # predict
    plt.subplot(6,8,j)
    j += 1
    img = XY2img(X[i],Yhat[i])
    plt.imshow(img)
    plt.axis('OFF')
    # predict
    plt.subplot(6,8,j)
    j += 1
    img = XY2imgf(X[i],Yhat[i])
    plt.imshow(img)
    plt.axis('OFF')
# Out:
# /home/tking/.local/lib/python3.5/site-packages/ipykernel_launcher.py:9: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.
#   if __name__ == '__main__':

# %%
# result on test images
X,Y = generator(batch_size, test_dir, H, W).__next__()
Yhat = model.predict(X)
j =1
plt.figure(figsize=(20,20))
for i in range(12):
    # original
    plt.subplot(6,8,j)
    j+=1
    img = XY2img(X[i],Y[i])
    plt.imshow(img)
    plt.axis('OFF')
    # grayscale
    plt.subplot(6,8,j)
    j+=1
    plt.imshow(X[i,:,:,0],'gray')
    plt.axis('OFF')
    # predict
    plt.subplot(6,8,j)
    j += 1
    img = XY2img(X[i],Yhat[i])
    plt.imshow(img)
    plt.axis('OFF')
    # predict
    plt.subplot(6,8,j)
    j += 1
    img = XY2imgf(X[i],Yhat[i])
    plt.imshow(img)
    plt.axis('OFF')
# Out:
# /home/tking/.local/lib/python3.5/site-packages/ipykernel_launcher.py:9: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.
#   if __name__ == '__main__':

# %%
from keras.layers import Conv2D, UpSampling2D, InputLayer, Conv2DTranspose
from keras.layers import Activation, Dense, Dropout, Flatten
from keras.layers.normalization import BatchNormalization
from keras.models import Sequential
from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img
from skimage.color import rgb2lab, lab2rgb, rgb2gray, xyz2lab
from skimage.io import imsave
import numpy as np
import os
import random
import tensorflow as tf
from time import time

import cv2

from scipy.misc import imresize
from skimage.transform import resize

import glob

import matplotlib.pyplot as plt
# %matplotlib inline

from keras.callbacks import EarlyStopping
from keras.utils import to_categorical
import random
from keras import optimizers
from scipy.ndimage import filters
# Out:
# /home/tking/.local/lib/python3.5/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
#define parameters:
dir_name = "Pasqueflower" # Variable
model_name = "6_M3_ab_cw_ft_ep200"# Variable

train_dir = r"../../images/"+dir_name+"/train/*.jpg"
test_dir = r"../../images/"+dir_name+"/test/*.jpg"
H = 64
W = 64
batch_size = 32

# %%
# select vaild images and put into train and test dir (only run once) 
# i = 0
# num_tr = 2000
# num_ts = 500
# for img in glob.glob(r"../../images/"+dir_name+"/*.jpg"):
#     try:
#         n= cv2.imread(img)#BGR
#         if  n is None or np.mean(n)>250 or np.mean(np.std(n,axis=2))<2:
#             os.remove(img)
#         else:
#             if i<num_tr:
#                 i+=1
#                 os.rename(img,r"../../images/"+dir_name+"/train/"+str(i)+".jpg")
#             elif i>=num_tr and i<num_tr+num_ts:
#                 i+=1
#                 os.rename(img,r"../../images/"+dir_name+"/test/"+str(i)+".jpg")
#             else:
#                 break
#     except:
#         pass
print('tr_size = ',len(glob.glob(train_dir)))
print('ts_size = ',len(glob.glob(test_dir)))
# Out:
# tr_size =  400
# ts_size =  200

# %%
def generator(batch_size, dir_path, H, W):
    while True:
        X = []
        Y = []
        img_batch = random.sample(glob.glob(dir_path), batch_size)
        for img in img_batch:
            # choose random index in features
            n= cv2.imread(img)#BGR
            m = imresize(n,(H,W,3))
            img_lab = cv2.cvtColor(m.astype(np.uint8), cv2.COLOR_BGR2LAB)
            L = img_lab[:,:,0].reshape(1,H,W,1)
            y = np.floor(img_lab[:,:,1:]/16)

            # to_categorical
            y0=y[:,:,0].flatten()
            y1=y[:,:,1].flatten()
            Yc2d0 = to_categorical(y0, num_classes = 16 )
            Yc3d0 = Yc2d0.reshape(H,W,16)
            Yc2d1 = to_categorical(y1, num_classes = 16 )
            Yc3d1 = Yc2d1.reshape(H,W,16)
            Yc3d = np.zeros((H,W,32))
            Yc3d[:,:,:16] = Yc3d0
            Yc3d[:,:,16:] = Yc3d1

            Y.append(Yc3d)
            X.append(L)
        X=np.array(X)
        Y=np.array(Y)
        X=np.reshape(X, (batch_size, H, W, 1))
        Y=np.reshape(Y, (batch_size, H, W, 32))
        yield X, Y

# %%
def XY2img(X,Y):
    H, W, _ = X.shape
    img_lab = np.zeros((H,W,3))
    img_lab[:,:,0] = X[:,:,0]
    img_lab[:,:,1] = np.argmax(Y[:,:,:16],axis=2)*16+8
    img_lab[:,:,2] = np.argmax(Y[:,:,16:],axis=2)*16+8
    img = cv2.cvtColor(img_lab.astype(np.uint8), cv2.COLOR_LAB2RGB)
    return img

# %%
def XY2imgf(X,Y):
    H, W, _ = X.shape
    img_lab = np.zeros((H,W,3))
    img_lab[:,:,0] = X[:,:,0]
    img_lab[:,:,1] = filters.gaussian_filter(np.argmax(Y[:,:,:16],axis=2)*16+8,5)
    img_lab[:,:,2] = filters.gaussian_filter(np.argmax(Y[:,:,16:],axis=2)*16+8,5)
    img = cv2.cvtColor(img_lab.astype(np.uint8), cv2.COLOR_LAB2RGB)
    return img

# %%
# show some images
plt.figure(figsize=(15,5))
X,Y = generator(batch_size, train_dir, H, W).__next__()    
for i in range(8):
    plt.subplot(1,8,i+1)
    img = XY2img(X[i],Y[i])
    plt.imshow(img)
    plt.axis('off')
# Out:
# /home/tking/.local/lib/python3.5/site-packages/ipykernel_launcher.py:9: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.
#   if __name__ == '__main__':

# %%
# read images to compute class_weight
Y = []
img_sample = random.sample(glob.glob(train_dir), 400)#save memory
for img in img_sample:
    n= cv2.imread(img)#BGR
    m = imresize(n,(H,W,3))
    img_lab = cv2.cvtColor(m.astype(np.uint8), cv2.COLOR_BGR2LAB)
    y = np.floor(img_lab[:,:,1:]/16)
    
    # to_categorical
    y0=y[:,:,0].flatten()
    y1=y[:,:,1].flatten()
    yc2d0 = to_categorical(y0, num_classes = 16 )
    yc3d0 = yc2d0.reshape(H,W,16)
    yc2d1 = to_categorical(y1, num_classes = 16 )
    yc3d1 = yc2d1.reshape(H,W,16)
    yc3d = np.zeros((H,W,32))
    yc3d[:,:,:16] = yc3d0
    yc3d[:,:,16:] = yc3d1
    Y.append(yc3d)
num = len(Y)
Y=np.array(Y)
Y=np.reshape(Y, (num, H, W, 32))
# Out:
# /home/tking/.local/lib/python3.5/site-packages/ipykernel_launcher.py:6: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.

# %%
# compute class_weight
from sklearn.utils import class_weight
Yflat16A = Y[:,:,:,:16].reshape(num*H*W,16)
YflatA = np.argmax(Yflat16A,axis=1)
YclassA = np.unique(YflatA)
class_weight_A = class_weight.compute_class_weight('balanced',
                                                 YclassA,
                                                 YflatA)
Yflat16B = Y[:,:,:,16:].reshape(num*H*W,16)
YflatB = np.argmax(Yflat16B,axis=1)
YclassB = np.unique(YflatB)
class_weight_B = class_weight.compute_class_weight('balanced',
                                                 YclassB,
                                                 YflatB)

class_weight = np.zeros(32)
for i in range(len(YclassA)):
    class_weight[YclassA[i]]=class_weight_A[i]
for i in range(len(YclassB)):
    class_weight[YclassB[i]+16]=class_weight_B[i]

plt.stem(class_weight)
plt.yscale('log')
plt.ylabel('class_weight')
plt.xlabel('classes')
# Out:
# Text(0.5,0,'classes')

# %%
# Building the neural network
import keras.backend as K
K.clear_session()
model = Sequential()
model.add(InputLayer(input_shape=(None, None, 1)))
model.add(Conv2D(8, (3, 3), activation='relu', padding='same', strides=2))
model.add(BatchNormalization(axis=-1))
model.add(Dropout(0.25))
model.add(Conv2D(8, (3, 3), activation='relu', padding='same'))
model.add(BatchNormalization(axis=-1))
model.add(Dropout(0.25))
model.add(Conv2D(16, (3, 3), activation='relu', padding='same'))
model.add(BatchNormalization(axis=-1))
model.add(Dropout(0.25))
model.add(Conv2D(16, (3, 3), activation='relu', padding='same', strides=2))
model.add(BatchNormalization(axis=-1))
model.add(Dropout(0.25))
model.add(Conv2D(32, (3, 3), activation='relu', padding='same'))
model.add(BatchNormalization(axis=-1))
model.add(Dropout(0.25))
model.add(Conv2D(32, (3, 3), activation='relu', padding='same', strides=2))
model.add(Conv2DTranspose(32, (2,2), strides=2, padding='same', activation='relu'))
model.add(BatchNormalization(axis=-1))
model.add(Dropout(0.25))
model.add(Conv2D(32, (3, 3), activation='relu', padding='same'))
model.add(Conv2DTranspose(32, (2,2), strides=2, padding='same', activation='relu'))
model.add(BatchNormalization(axis=-1))
model.add(Dropout(0.25))
model.add(Conv2D(16, (3, 3), activation='relu', padding='same'))
model.add(Conv2DTranspose(32, (2,2), strides=2, padding='same', activation='relu'))
model.add(BatchNormalization(axis=-1))
model.add(Dropout(0.25))
model.add(Conv2D(32, (3, 3), activation='sigmoid', padding='same'))#TODO
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, None, None, 1)     0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, None, None, 8)     80
# _________________________________________________________________
# batch_normalization_1 (Batch (None, None, None, 8)     32
# _________________________________________________________________
# dropout_1 (Dropout)          (None, None, None, 8)     0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, None, None, 8)     584
# _________________________________________________________________
# batch_normalization_2 (Batch (None, None, None, 8)     32
# _________________________________________________________________
# dropout_2 (Dropout)          (None, None, None, 8)     0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, None, None, 16)    1168
# _________________________________________________________________
# batch_normalization_3 (Batch (None, None, None, 16)    64
# _________________________________________________________________
# dropout_3 (Dropout)          (None, None, None, 16)    0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, None, None, 16)    2320
# _________________________________________________________________
# batch_normalization_4 (Batch (None, None, None, 16)    64
# _________________________________________________________________
# dropout_4 (Dropout)          (None, None, None, 16)    0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, None, None, 32)    4640
# _________________________________________________________________
# batch_normalization_5 (Batch (None, None, None, 32)    128
# _________________________________________________________________
# dropout_5 (Dropout)          (None, None, None, 32)    0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, None, None, 32)    9248
# _________________________________________________________________
# conv2d_transpose_1 (Conv2DTr (None, None, None, 32)    4128
# _________________________________________________________________
# batch_normalization_6 (Batch (None, None, None, 32)    128
# _________________________________________________________________
# dropout_6 (Dropout)          (None, None, None, 32)    0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, None, None, 32)    9248
# _________________________________________________________________
# conv2d_transpose_2 (Conv2DTr (None, None, None, 32)    4128
# _________________________________________________________________
# batch_normalization_7 (Batch (None, None, None, 32)    128
# _________________________________________________________________
# dropout_7 (Dropout)          (None, None, None, 32)    0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, None, None, 16)    4624
# _________________________________________________________________
# conv2d_transpose_3 (Conv2DTr (None, None, None, 32)    2080
# _________________________________________________________________
# batch_normalization_8 (Batch (None, None, None, 32)    128
# _________________________________________________________________
# dropout_8 (Dropout)          (None, None, None, 32)    0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, None, None, 32)    9248
# =================================================================
# Total params: 52,200
# Trainable params: 51,848
# Non-trainable params: 352
# _________________________________________________________________

# %%
# compile model
opt = optimizers.Adam(lr=0.001)
model.compile(optimizer=opt,
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %%
train_generator = generator(batch_size, train_dir, H, W)
test_generator = generator(batch_size, test_dir, H, W)
tr_size = len(glob.glob(train_dir))
ts_size = len(glob.glob(test_dir))
steps_per_epoch = tr_size// batch_size
validation_steps = ts_size // batch_size
print(tr_size,ts_size,steps_per_epoch,validation_steps)
# Out:
# 400 200 12 6

# %%
t0 = time()
hist = model.fit_generator(train_generator,
                            steps_per_epoch=steps_per_epoch,
                            epochs=200,
                            validation_data=test_generator,
                            validation_steps=validation_steps,
                            class_weight=class_weight,
                            verbose=1)
print('Train time: %.fm'%((time()-t0)/60))
# Out:
# Epoch 1/200
# /home/tking/.local/lib/python3.5/site-packages/ipykernel_launcher.py:9: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.
#   if __name__ == '__main__':
# 12/12 [==============================] - 11s 933ms/step - loss: 6.9840 - acc: 0.0503 - val_loss: 6.4230 - val_acc: 0.1193
# Epoch 2/200
# 12/12 [==============================] - 2s 194ms/step - loss: 6.5309 - acc: 0.1267 - val_loss: 6.0052 - val_acc: 0.2859
# Epoch 3/200
# 12/12 [==============================] - 3s 257ms/step - loss: 5.8730 - acc: 0.1748 - val_loss: 5.5573 - val_acc: 0.3548
# Epoch 4/200
# 12/12 [==============================] - 2s 208ms/step - loss: 5.3185 - acc: 0.1660 - val_loss: 5.3746 - val_acc: 0.0146
# Epoch 5/200
# 12/12 [==============================] - 3s 211ms/step - loss: 5.1390 - acc: 0.1615 - val_loss: 5.1723 - val_acc: 0.3167
# Epoch 6/200
# 12/12 [==============================] - 2s 203ms/step - loss: 5.0355 - acc: 0.1132 - val_loss: 4.9530 - val_acc: 0.0921
# Epoch 7/200
# 12/12 [==============================] - 3s 233ms/step - loss: 4.9463 - acc: 0.1395 - val_loss: 4.8096 - val_acc: 0.1146
# Epoch 8/200
# 12/12 [==============================] - 3s 216ms/step - loss: 4.9275 - acc: 0.1320 - val_loss: 6.2157 - val_acc: 0.0081
# Epoch 9/200
# 12/12 [==============================] - 3s 227ms/step - loss: 4.7943 - acc: 0.1380 - val_loss: 6.1892 - val_acc: 0.0113
# Epoch 10/200
# 12/12 [==============================] - 3s 222ms/step - loss: 4.8330 - acc: 0.1284 - val_loss: 6.1698 - val_acc: 0.0172
# Epoch 11/200
# 12/12 [==============================] - 3s 219ms/step - loss: 4.8111 - acc: 0.1262 - val_loss: 6.1479 - val_acc: 0.0041
# Epoch 12/200
# 12/12 [==============================] - 3s 262ms/step - loss: 4.7731 - acc: 0.1705 - val_loss: 5.9843 - val_acc: 0.0633
# Epoch 13/200
# 12/12 [==============================] - 3s 244ms/step - loss: 4.7911 - acc: 0.1084 - val_loss: 5.4018 - val_acc: 0.0097
# Epoch 14/200
# 12/12 [==============================] - 3s 240ms/step - loss: 4.6713 - acc: 0.0990 - val_loss: 4.6729 - val_acc: 0.0526
# Epoch 15/200
# 12/12 [==============================] - 2s 201ms/step - loss: 4.7056 - acc: 0.1480 - val_loss: 4.9151 - val_acc: 0.0699
# Epoch 16/200
# 12/12 [==============================] - 3s 229ms/step - loss: 4.6647 - acc: 0.1458 - val_loss: 4.6886 - val_acc: 0.0464
# Epoch 17/200
# 12/12 [==============================] - 3s 222ms/step - loss: 4.6138 - acc: 0.1069 - val_loss: 4.7062 - val_acc: 0.0960
# Epoch 18/200
# 12/12 [==============================] - 3s 230ms/step - loss: 4.6001 - acc: 0.1682 - val_loss: 4.5836 - val_acc: 0.1822
# Epoch 19/200
# 12/12 [==============================] - 3s 243ms/step - loss: 4.6235 - acc: 0.1566 - val_loss: 4.7135 - val_acc: 0.1010
# Epoch 20/200
# 12/12 [==============================] - 3s 212ms/step - loss: 4.6559 - acc: 0.1095 - val_loss: 4.5689 - val_acc: 0.3506
# Epoch 21/200
# 12/12 [==============================] - 3s 251ms/step - loss: 4.6642 - acc: 0.1120 - val_loss: 4.4432 - val_acc: 0.3464
# Epoch 22/200
# 12/12 [==============================] - 3s 216ms/step - loss: 4.6160 - acc: 0.0998 - val_loss: 4.5043 - val_acc: 0.2790
# Epoch 23/200
# 12/12 [==============================] - 3s 232ms/step - loss: 4.6171 - acc: 0.1073 - val_loss: 4.4523 - val_acc: 0.2698
# Epoch 24/200
# 12/12 [==============================] - 3s 223ms/step - loss: 4.5755 - acc: 0.1148 - val_loss: 4.4865 - val_acc: 0.3154
# Epoch 25/200
# 12/12 [==============================] - 2s 205ms/step - loss: 4.5112 - acc: 0.1198 - val_loss: 4.5967 - val_acc: 0.2609
# Epoch 26/200
# 12/12 [==============================] - 3s 240ms/step - loss: 4.6233 - acc: 0.1173 - val_loss: 4.6207 - val_acc: 0.3459
# Epoch 27/200
# 12/12 [==============================] - 3s 240ms/step - loss: 4.6182 - acc: 0.1355 - val_loss: 4.4541 - val_acc: 0.3052
# Epoch 28/200
# 12/12 [==============================] - 3s 228ms/step - loss: 4.5719 - acc: 0.1285 - val_loss: 4.5651 - val_acc: 0.3009
# Epoch 29/200
# 12/12 [==============================] - 3s 224ms/step - loss: 4.5903 - acc: 0.1292 - val_loss: 4.5192 - val_acc: 0.2879
# Epoch 30/200
# 12/12 [==============================] - 3s 222ms/step - loss: 4.5535 - acc: 0.1226 - val_loss: 4.3855 - val_acc: 0.2341
# Epoch 31/200
# 12/12 [==============================] - 3s 220ms/step - loss: 4.5422 - acc: 0.1351 - val_loss: 4.3957 - val_acc: 0.2645
# Epoch 32/200
# 12/12 [==============================] - 3s 229ms/step - loss: 4.5700 - acc: 0.1375 - val_loss: 4.4834 - val_acc: 0.3256
# Epoch 33/200
# 12/12 [==============================] - 2s 197ms/step - loss: 4.6217 - acc: 0.1125 - val_loss: 4.6101 - val_acc: 0.2547
# Epoch 34/200
# 12/12 [==============================] - 3s 209ms/step - loss: 4.5376 - acc: 0.1018 - val_loss: 4.5568 - val_acc: 0.2573
# Epoch 35/200
# 12/12 [==============================] - 3s 227ms/step - loss: 4.5575 - acc: 0.0998 - val_loss: 4.4446 - val_acc: 0.2654
# Epoch 36/200
# 12/12 [==============================] - 3s 269ms/step - loss: 4.5561 - acc: 0.1049 - val_loss: 4.4992 - val_acc: 0.2589
# Epoch 37/200
# 12/12 [==============================] - 3s 237ms/step - loss: 4.5457 - acc: 0.1320 - val_loss: 4.5170 - val_acc: 0.2848
# Epoch 38/200
# 12/12 [==============================] - 3s 224ms/step - loss: 4.5096 - acc: 0.1228 - val_loss: 4.4496 - val_acc: 0.2684
# Epoch 39/200
# 12/12 [==============================] - 3s 217ms/step - loss: 4.4483 - acc: 0.1374 - val_loss: 4.5466 - val_acc: 0.2787
# Epoch 40/200
# 12/12 [==============================] - 3s 224ms/step - loss: 4.5318 - acc: 0.1349 - val_loss: 4.5066 - val_acc: 0.3191
# Epoch 41/200
# 12/12 [==============================] - 3s 224ms/step - loss: 4.5406 - acc: 0.1521 - val_loss: 4.4305 - val_acc: 0.2811
# Epoch 42/200
# 12/12 [==============================] - 3s 287ms/step - loss: 4.5036 - acc: 0.1476 - val_loss: 4.5620 - val_acc: 0.3282
# Epoch 43/200
# 12/12 [==============================] - 3s 246ms/step - loss: 4.4652 - acc: 0.1801 - val_loss: 4.6364 - val_acc: 0.2836
# Epoch 44/200
# 12/12 [==============================] - 3s 245ms/step - loss: 4.5017 - acc: 0.1362 - val_loss: 4.5677 - val_acc: 0.2763
# Epoch 45/200
# 12/12 [==============================] - 3s 214ms/step - loss: 4.6242 - acc: 0.1259 - val_loss: 4.6271 - val_acc: 0.2770
# Epoch 46/200
# 12/12 [==============================] - 3s 256ms/step - loss: 4.5316 - acc: 0.1529 - val_loss: 4.5719 - val_acc: 0.2699
# Epoch 47/200
# 12/12 [==============================] - 3s 244ms/step - loss: 4.4793 - acc: 0.1280 - val_loss: 4.4728 - val_acc: 0.2050
# Epoch 48/200
# 12/12 [==============================] - 3s 236ms/step - loss: 4.5240 - acc: 0.1119 - val_loss: 4.5904 - val_acc: 0.2616
# Epoch 49/200
# 12/12 [==============================] - 3s 242ms/step - loss: 4.4904 - acc: 0.1196 - val_loss: 4.5446 - val_acc: 0.3156
# Epoch 50/200
# 12/12 [==============================] - 3s 223ms/step - loss: 4.4391 - acc: 0.1417 - val_loss: 4.4087 - val_acc: 0.2578
# Epoch 51/200
# 12/12 [==============================] - 3s 238ms/step - loss: 4.4351 - acc: 0.1217 - val_loss: 4.4197 - val_acc: 0.2173
# Epoch 52/200
# 12/12 [==============================] - 3s 225ms/step - loss: 4.4659 - acc: 0.1321 - val_loss: 4.4758 - val_acc: 0.2235
# Epoch 53/200
# 12/12 [==============================] - 3s 238ms/step - loss: 4.4180 - acc: 0.1283 - val_loss: 4.4747 - val_acc: 0.2427
# Epoch 54/200
# 12/12 [==============================] - 3s 214ms/step - loss: 4.5177 - acc: 0.1523 - val_loss: 4.3735 - val_acc: 0.2059
# Epoch 55/200
# 12/12 [==============================] - 3s 211ms/step - loss: 4.5590 - acc: 0.1231 - val_loss: 4.5459 - val_acc: 0.2791
# Epoch 56/200
# 12/12 [==============================] - 3s 249ms/step - loss: 4.4799 - acc: 0.1653 - val_loss: 4.5479 - val_acc: 0.3397
# Epoch 57/200
# 12/12 [==============================] - 3s 236ms/step - loss: 4.5491 - acc: 0.1405 - val_loss: 4.6305 - val_acc: 0.3053
# Epoch 58/200
# 12/12 [==============================] - 3s 233ms/step - loss: 4.4876 - acc: 0.1282 - val_loss: 4.5670 - val_acc: 0.2312
# Epoch 59/200
# 12/12 [==============================] - 3s 215ms/step - loss: 4.5046 - acc: 0.1746 - val_loss: 4.4962 - val_acc: 0.2015
# Epoch 60/200
# 12/12 [==============================] - 2s 198ms/step - loss: 4.4586 - acc: 0.1637 - val_loss: 4.5362 - val_acc: 0.2178
# Epoch 61/200
# 12/12 [==============================] - 3s 229ms/step - loss: 4.4456 - acc: 0.1153 - val_loss: 4.3899 - val_acc: 0.2213
# Epoch 62/200
# 12/12 [==============================] - 3s 225ms/step - loss: 4.4718 - acc: 0.1489 - val_loss: 4.4688 - val_acc: 0.3387
# Epoch 63/200
# 12/12 [==============================] - 3s 271ms/step - loss: 4.4396 - acc: 0.1849 - val_loss: 4.5031 - val_acc: 0.3078
# Epoch 64/200
# 12/12 [==============================] - 3s 247ms/step - loss: 4.5588 - acc: 0.1688 - val_loss: 4.5453 - val_acc: 0.2821
# Epoch 65/200
# 12/12 [==============================] - 3s 225ms/step - loss: 4.4949 - acc: 0.1701 - val_loss: 4.4549 - val_acc: 0.2667
# Epoch 66/200
# 12/12 [==============================] - 3s 252ms/step - loss: 4.4955 - acc: 0.1493 - val_loss: 4.4122 - val_acc: 0.2745
# Epoch 67/200
# 12/12 [==============================] - 3s 257ms/step - loss: 4.4975 - acc: 0.1670 - val_loss: 4.4667 - val_acc: 0.2987
# Epoch 68/200
# 12/12 [==============================] - 3s 214ms/step - loss: 4.4705 - acc: 0.2041 - val_loss: 4.4606 - val_acc: 0.2927
# Epoch 69/200
# 12/12 [==============================] - 3s 215ms/step - loss: 4.4103 - acc: 0.1710 - val_loss: 4.4534 - val_acc: 0.2395
# Epoch 70/200
# 12/12 [==============================] - 3s 235ms/step - loss: 4.4410 - acc: 0.1460 - val_loss: 4.5259 - val_acc: 0.2495
# Epoch 71/200
# 12/12 [==============================] - 3s 231ms/step - loss: 4.4932 - acc: 0.1521 - val_loss: 4.4999 - val_acc: 0.2484
# Epoch 72/200
# 12/12 [==============================] - 3s 218ms/step - loss: 4.4391 - acc: 0.1611 - val_loss: 4.4613 - val_acc: 0.2731
# Epoch 73/200
# 12/12 [==============================] - 3s 212ms/step - loss: 4.3909 - acc: 0.1714 - val_loss: 4.5574 - val_acc: 0.3052
# Epoch 74/200
# 12/12 [==============================] - 3s 210ms/step - loss: 4.4385 - acc: 0.1703 - val_loss: 4.4808 - val_acc: 0.2863
# Epoch 75/200
# 12/12 [==============================] - 3s 208ms/step - loss: 4.4471 - acc: 0.1811 - val_loss: 4.4817 - val_acc: 0.2686
# Epoch 76/200
# 12/12 [==============================] - 2s 199ms/step - loss: 4.5405 - acc: 0.1312 - val_loss: 4.3776 - val_acc: 0.1265
# Epoch 77/200
# 12/12 [==============================] - 2s 207ms/step - loss: 4.5149 - acc: 0.1354 - val_loss: 4.4616 - val_acc: 0.3022
# Epoch 78/200
# 12/12 [==============================] - 2s 193ms/step - loss: 4.4391 - acc: 0.2179 - val_loss: 4.4834 - val_acc: 0.3482
# Epoch 79/200
# 12/12 [==============================] - 3s 260ms/step - loss: 4.3809 - acc: 0.1844 - val_loss: 4.5028 - val_acc: 0.2893
# Epoch 80/200
# 12/12 [==============================] - 3s 247ms/step - loss: 4.4573 - acc: 0.1403 - val_loss: 4.4776 - val_acc: 0.2469
# Epoch 81/200
# 12/12 [==============================] - 3s 258ms/step - loss: 4.3673 - acc: 0.1601 - val_loss: 4.3258 - val_acc: 0.2478
# Epoch 82/200
# 12/12 [==============================] - 3s 214ms/step - loss: 4.3704 - acc: 0.1378 - val_loss: 4.4013 - val_acc: 0.2337
# Epoch 83/200
# 12/12 [==============================] - 3s 227ms/step - loss: 4.4449 - acc: 0.1865 - val_loss: 4.4603 - val_acc: 0.2958
# Epoch 84/200
# 12/12 [==============================] - 3s 239ms/step - loss: 4.4453 - acc: 0.1925 - val_loss: 4.4712 - val_acc: 0.2429
# Epoch 85/200
# 12/12 [==============================] - 3s 266ms/step - loss: 4.4995 - acc: 0.1318 - val_loss: 4.4673 - val_acc: 0.2363
# Epoch 86/200
# 12/12 [==============================] - 3s 211ms/step - loss: 4.4929 - acc: 0.1732 - val_loss: 4.7467 - val_acc: 0.2716
# Epoch 87/200
# 12/12 [==============================] - 2s 207ms/step - loss: 4.4599 - acc: 0.2106 - val_loss: 4.5460 - val_acc: 0.2585
# Epoch 88/200
# 12/12 [==============================] - 3s 227ms/step - loss: 4.5065 - acc: 0.1821 - val_loss: 4.5455 - val_acc: 0.2232
# Epoch 89/200
# 12/12 [==============================] - 3s 227ms/step - loss: 4.3854 - acc: 0.1471 - val_loss: 4.4919 - val_acc: 0.1256
# Epoch 90/200
# 12/12 [==============================] - 3s 245ms/step - loss: 4.4045 - acc: 0.1007 - val_loss: 4.4696 - val_acc: 0.1505
# Epoch 91/200
# 12/12 [==============================] - 2s 203ms/step - loss: 4.3985 - acc: 0.1499 - val_loss: 4.4622 - val_acc: 0.2555
# Epoch 92/200
# 12/12 [==============================] - 2s 204ms/step - loss: 4.4063 - acc: 0.1593 - val_loss: 4.3978 - val_acc: 0.2275
# Epoch 93/200
# 12/12 [==============================] - 2s 195ms/step - loss: 4.3847 - acc: 0.1245 - val_loss: 4.4238 - val_acc: 0.1634
# Epoch 94/200
# 12/12 [==============================] - 3s 231ms/step - loss: 4.4476 - acc: 0.1464 - val_loss: 4.5053 - val_acc: 0.1972
# Epoch 95/200
# 12/12 [==============================] - 3s 216ms/step - loss: 4.4159 - acc: 0.1791 - val_loss: 4.4405 - val_acc: 0.2293
# Epoch 96/200
# 12/12 [==============================] - 3s 236ms/step - loss: 4.4847 - acc: 0.1451 - val_loss: 4.4495 - val_acc: 0.2513
# Epoch 97/200
# 12/12 [==============================] - 3s 252ms/step - loss: 4.4242 - acc: 0.1698 - val_loss: 4.4631 - val_acc: 0.2220
# Epoch 98/200
# 12/12 [==============================] - 3s 225ms/step - loss: 4.3766 - acc: 0.1892 - val_loss: 4.3717 - val_acc: 0.2242
# Epoch 99/200
# 12/12 [==============================] - 3s 213ms/step - loss: 4.3866 - acc: 0.1546 - val_loss: 4.5227 - val_acc: 0.1835
# Epoch 100/200
# 12/12 [==============================] - 3s 237ms/step - loss: 4.4409 - acc: 0.1342 - val_loss: 4.3994 - val_acc: 0.2336
# Epoch 101/200
# 12/12 [==============================] - 3s 259ms/step - loss: 4.4502 - acc: 0.1951 - val_loss: 4.4333 - val_acc: 0.2678
# Epoch 102/200
# 12/12 [==============================] - 2s 200ms/step - loss: 4.4040 - acc: 0.2099 - val_loss: 4.4704 - val_acc: 0.2186
# Epoch 103/200
# 12/12 [==============================] - 2s 201ms/step - loss: 4.3645 - acc: 0.1418 - val_loss: 4.3785 - val_acc: 0.1936
# Epoch 104/200
# 12/12 [==============================] - 3s 220ms/step - loss: 4.3769 - acc: 0.1523 - val_loss: 4.3568 - val_acc: 0.2074
# Epoch 105/200
# 12/12 [==============================] - 2s 204ms/step - loss: 4.4822 - acc: 0.1847 - val_loss: 4.4931 - val_acc: 0.2518
# Epoch 106/200
# 12/12 [==============================] - 3s 248ms/step - loss: 4.3968 - acc: 0.1765 - val_loss: 4.4684 - val_acc: 0.2061
# Epoch 107/200
# 12/12 [==============================] - 3s 217ms/step - loss: 4.4194 - acc: 0.1451 - val_loss: 4.4281 - val_acc: 0.2572
# Epoch 108/200
# 12/12 [==============================] - 3s 241ms/step - loss: 4.4111 - acc: 0.1747 - val_loss: 4.4880 - val_acc: 0.2595
# Epoch 109/200
# 12/12 [==============================] - 3s 221ms/step - loss: 4.3743 - acc: 0.1861 - val_loss: 4.3300 - val_acc: 0.2498
# Epoch 110/200
# 12/12 [==============================] - 3s 215ms/step - loss: 4.5126 - acc: 0.1563 - val_loss: 4.5030 - val_acc: 0.2066
# Epoch 111/200
# 12/12 [==============================] - 3s 264ms/step - loss: 4.4092 - acc: 0.1548 - val_loss: 4.5291 - val_acc: 0.0959
# Epoch 112/200
# 12/12 [==============================] - 3s 221ms/step - loss: 4.4401 - acc: 0.1628 - val_loss: 4.6010 - val_acc: 0.1631
# Epoch 113/200
# 12/12 [==============================] - 3s 210ms/step - loss: 4.4325 - acc: 0.1875 - val_loss: 4.6071 - val_acc: 0.1543
# Epoch 114/200
# 12/12 [==============================] - 3s 227ms/step - loss: 4.5214 - acc: 0.1580 - val_loss: 4.6198 - val_acc: 0.1689
# Epoch 115/200
# 12/12 [==============================] - 2s 196ms/step - loss: 4.4773 - acc: 0.1685 - val_loss: 4.4760 - val_acc: 0.1884
# Epoch 116/200
# 12/12 [==============================] - 3s 214ms/step - loss: 4.4517 - acc: 0.1677 - val_loss: 4.6173 - val_acc: 0.1520
# Epoch 117/200
# 12/12 [==============================] - 4s 316ms/step - loss: 4.3622 - acc: 0.1632 - val_loss: 4.6169 - val_acc: 0.1423
# Epoch 118/200
# 12/12 [==============================] - 3s 244ms/step - loss: 4.4126 - acc: 0.1548 - val_loss: 4.5434 - val_acc: 0.1551
# Epoch 119/200
# 12/12 [==============================] - 3s 223ms/step - loss: 4.4569 - acc: 0.1588 - val_loss: 4.5106 - val_acc: 0.1425
# Epoch 120/200
# 12/12 [==============================] - 3s 246ms/step - loss: 4.3939 - acc: 0.1625 - val_loss: 4.6194 - val_acc: 0.1240
# Epoch 121/200
# 12/12 [==============================] - 2s 196ms/step - loss: 4.4860 - acc: 0.1701 - val_loss: 4.5725 - val_acc: 0.1360
# Epoch 122/200
# 12/12 [==============================] - 3s 209ms/step - loss: 4.4212 - acc: 0.1789 - val_loss: 4.5261 - val_acc: 0.0978
# Epoch 123/200
# 12/12 [==============================] - 2s 202ms/step - loss: 4.3725 - acc: 0.1692 - val_loss: 4.4312 - val_acc: 0.1260
# Epoch 124/200
# 12/12 [==============================] - 3s 260ms/step - loss: 4.4395 - acc: 0.1480 - val_loss: 4.4631 - val_acc: 0.1003
# Epoch 125/200
# 12/12 [==============================] - 2s 202ms/step - loss: 4.4538 - acc: 0.1414 - val_loss: 4.4592 - val_acc: 0.1254
# Epoch 126/200
# 12/12 [==============================] - 3s 240ms/step - loss: 4.4259 - acc: 0.1413 - val_loss: 4.4796 - val_acc: 0.1178
# Epoch 127/200
# 12/12 [==============================] - 2s 199ms/step - loss: 4.4091 - acc: 0.1759 - val_loss: 4.4961 - val_acc: 0.1228
# Epoch 128/200
# 12/12 [==============================] - 2s 206ms/step - loss: 4.4375 - acc: 0.1778 - val_loss: 4.4496 - val_acc: 0.1646
# Epoch 129/200
# 12/12 [==============================] - 3s 225ms/step - loss: 4.4265 - acc: 0.1810 - val_loss: 4.6405 - val_acc: 0.1362
# Epoch 130/200
# 12/12 [==============================] - 3s 238ms/step - loss: 4.4251 - acc: 0.1595 - val_loss: 4.3324 - val_acc: 0.1369
# Epoch 131/200
# 12/12 [==============================] - 3s 245ms/step - loss: 4.4311 - acc: 0.1507 - val_loss: 4.3961 - val_acc: 0.1577
# Epoch 132/200
# 12/12 [==============================] - 3s 264ms/step - loss: 4.3747 - acc: 0.1796 - val_loss: 4.4508 - val_acc: 0.1747
# Epoch 133/200
# 12/12 [==============================] - 3s 247ms/step - loss: 4.4064 - acc: 0.2003 - val_loss: 4.4420 - val_acc: 0.1706
# Epoch 134/200
# 12/12 [==============================] - 3s 226ms/step - loss: 4.4656 - acc: 0.1765 - val_loss: 4.3963 - val_acc: 0.1966
# Epoch 135/200
# 12/12 [==============================] - 3s 239ms/step - loss: 4.4174 - acc: 0.1651 - val_loss: 4.3575 - val_acc: 0.2323
# Epoch 136/200
# 12/12 [==============================] - 3s 228ms/step - loss: 4.4584 - acc: 0.1699 - val_loss: 4.3346 - val_acc: 0.2222
# Epoch 137/200
# 12/12 [==============================] - 3s 242ms/step - loss: 4.4059 - acc: 0.1605 - val_loss: 4.5299 - val_acc: 0.1592
# Epoch 138/200
# 12/12 [==============================] - 3s 225ms/step - loss: 4.4039 - acc: 0.1490 - val_loss: 4.4251 - val_acc: 0.1585
# Epoch 139/200
# 12/12 [==============================] - 3s 226ms/step - loss: 4.4234 - acc: 0.1624 - val_loss: 4.4949 - val_acc: 0.1957
# Epoch 140/200
# 12/12 [==============================] - 2s 196ms/step - loss: 4.3887 - acc: 0.1656 - val_loss: 4.3487 - val_acc: 0.1661
# Epoch 141/200
# 12/12 [==============================] - 3s 210ms/step - loss: 4.4724 - acc: 0.1474 - val_loss: 4.4357 - val_acc: 0.1808
# Epoch 142/200
# 12/12 [==============================] - 3s 243ms/step - loss: 4.4673 - acc: 0.1709 - val_loss: 4.3722 - val_acc: 0.1921
# Epoch 143/200
# 12/12 [==============================] - 2s 203ms/step - loss: 4.3975 - acc: 0.1703 - val_loss: 4.4212 - val_acc: 0.1917
# Epoch 144/200
# 12/12 [==============================] - 3s 240ms/step - loss: 4.4022 - acc: 0.1514 - val_loss: 4.4174 - val_acc: 0.1643
# Epoch 145/200
# 12/12 [==============================] - 3s 220ms/step - loss: 4.4181 - acc: 0.1658 - val_loss: 4.3264 - val_acc: 0.1889
# Epoch 146/200
# 12/12 [==============================] - 3s 211ms/step - loss: 4.4512 - acc: 0.1837 - val_loss: 4.4253 - val_acc: 0.2072
# Epoch 147/200
# 12/12 [==============================] - 2s 198ms/step - loss: 4.4623 - acc: 0.1793 - val_loss: 4.3359 - val_acc: 0.1701
# Epoch 148/200
# 12/12 [==============================] - 3s 245ms/step - loss: 4.3902 - acc: 0.1705 - val_loss: 4.3800 - val_acc: 0.1678
# Epoch 149/200
# 12/12 [==============================] - 2s 200ms/step - loss: 4.4566 - acc: 0.1756 - val_loss: 4.4530 - val_acc: 0.1776
# Epoch 150/200
# 12/12 [==============================] - 3s 238ms/step - loss: 4.4144 - acc: 0.1861 - val_loss: 4.4243 - val_acc: 0.1654
# Epoch 151/200
# 12/12 [==============================] - 3s 271ms/step - loss: 4.4025 - acc: 0.1695 - val_loss: 4.3515 - val_acc: 0.1786
# Epoch 152/200
# 12/12 [==============================] - 3s 226ms/step - loss: 4.4802 - acc: 0.1530 - val_loss: 4.4813 - val_acc: 0.1852
# Epoch 153/200
# 12/12 [==============================] - 2s 197ms/step - loss: 4.3945 - acc: 0.1729 - val_loss: 4.4859 - val_acc: 0.1685
# Epoch 154/200
# 12/12 [==============================] - 2s 205ms/step - loss: 4.3930 - acc: 0.1490 - val_loss: 4.3540 - val_acc: 0.1710
# Epoch 155/200
# 12/12 [==============================] - 3s 241ms/step - loss: 4.3308 - acc: 0.1700 - val_loss: 4.3667 - val_acc: 0.1732
# Epoch 156/200
# 12/12 [==============================] - 2s 203ms/step - loss: 4.4221 - acc: 0.1574 - val_loss: 4.4411 - val_acc: 0.1478
# Epoch 157/200
# 12/12 [==============================] - 2s 197ms/step - loss: 4.4489 - acc: 0.1600 - val_loss: 4.3226 - val_acc: 0.1709
# Epoch 158/200
# 12/12 [==============================] - 3s 228ms/step - loss: 4.4159 - acc: 0.1683 - val_loss: 4.3855 - val_acc: 0.1467
# Epoch 159/200
# 12/12 [==============================] - 3s 242ms/step - loss: 4.4336 - acc: 0.1251 - val_loss: 4.3814 - val_acc: 0.0989
# Epoch 160/200
# 12/12 [==============================] - 3s 257ms/step - loss: 4.4058 - acc: 0.1406 - val_loss: 4.4003 - val_acc: 0.1447
# Epoch 161/200
# 12/12 [==============================] - 2s 205ms/step - loss: 4.3733 - acc: 0.1561 - val_loss: 4.3544 - val_acc: 0.1519
# Epoch 162/200
# 12/12 [==============================] - 3s 232ms/step - loss: 4.4132 - acc: 0.1764 - val_loss: 4.4495 - val_acc: 0.1603
# Epoch 163/200
# 12/12 [==============================] - 3s 225ms/step - loss: 4.4001 - acc: 0.1986 - val_loss: 4.4215 - val_acc: 0.1983
# Epoch 164/200
# 12/12 [==============================] - 3s 238ms/step - loss: 4.4024 - acc: 0.1703 - val_loss: 4.4254 - val_acc: 0.1869
# Epoch 165/200
# 12/12 [==============================] - 2s 206ms/step - loss: 4.4257 - acc: 0.1716 - val_loss: 4.3913 - val_acc: 0.2002
# Epoch 166/200
# 12/12 [==============================] - 3s 209ms/step - loss: 4.3590 - acc: 0.1381 - val_loss: 4.5236 - val_acc: 0.1291
# Epoch 167/200
# 12/12 [==============================] - 3s 212ms/step - loss: 4.3789 - acc: 0.1538 - val_loss: 4.4032 - val_acc: 0.1798
# Epoch 168/200
# 12/12 [==============================] - 3s 223ms/step - loss: 4.3612 - acc: 0.1608 - val_loss: 4.3957 - val_acc: 0.1461
# Epoch 169/200
# 12/12 [==============================] - 2s 208ms/step - loss: 4.3522 - acc: 0.1421 - val_loss: 4.4136 - val_acc: 0.1905
# Epoch 170/200
# 12/12 [==============================] - 3s 216ms/step - loss: 4.4372 - acc: 0.1527 - val_loss: 4.3474 - val_acc: 0.1910
# Epoch 171/200
# 12/12 [==============================] - 4s 300ms/step - loss: 4.3988 - acc: 0.1562 - val_loss: 4.3669 - val_acc: 0.1990
# Epoch 172/200
# 12/12 [==============================] - 3s 225ms/step - loss: 4.3796 - acc: 0.1708 - val_loss: 4.2995 - val_acc: 0.1751
# Epoch 173/200
# 12/12 [==============================] - 2s 197ms/step - loss: 4.4546 - acc: 0.1703 - val_loss: 4.3410 - val_acc: 0.2201
# Epoch 174/200
# 12/12 [==============================] - 3s 225ms/step - loss: 4.3819 - acc: 0.1622 - val_loss: 4.3494 - val_acc: 0.1687
# Epoch 175/200
# 12/12 [==============================] - 3s 236ms/step - loss: 4.3681 - acc: 0.1646 - val_loss: 4.3105 - val_acc: 0.1711
# Epoch 176/200
# 12/12 [==============================] - 3s 223ms/step - loss: 4.4478 - acc: 0.1629 - val_loss: 4.3636 - val_acc: 0.1937
# Epoch 177/200
# 12/12 [==============================] - 2s 199ms/step - loss: 4.3439 - acc: 0.1787 - val_loss: 4.3551 - val_acc: 0.1835
# Epoch 178/200
# 12/12 [==============================] - 3s 237ms/step - loss: 4.4009 - acc: 0.1857 - val_loss: 4.4725 - val_acc: 0.2037
# Epoch 179/200
# 12/12 [==============================] - 3s 244ms/step - loss: 4.4209 - acc: 0.1908 - val_loss: 4.3382 - val_acc: 0.2163
# Epoch 180/200
# 12/12 [==============================] - 3s 220ms/step - loss: 4.3832 - acc: 0.1750 - val_loss: 4.4349 - val_acc: 0.1849
# Epoch 181/200
# 12/12 [==============================] - 3s 256ms/step - loss: 4.3505 - acc: 0.1588 - val_loss: 4.3566 - val_acc: 0.1961
# Epoch 182/200
# 12/12 [==============================] - 2s 204ms/step - loss: 4.4364 - acc: 0.1753 - val_loss: 4.3713 - val_acc: 0.2226
# Epoch 183/200
# 12/12 [==============================] - 3s 223ms/step - loss: 4.3359 - acc: 0.1836 - val_loss: 4.3314 - val_acc: 0.1456
# Epoch 184/200
# 12/12 [==============================] - 3s 235ms/step - loss: 4.4187 - acc: 0.1526 - val_loss: 4.3674 - val_acc: 0.1850
# Epoch 185/200
# 12/12 [==============================] - 3s 219ms/step - loss: 4.3823 - acc: 0.1528 - val_loss: 4.4222 - val_acc: 0.1455
# Epoch 186/200
# 12/12 [==============================] - 3s 248ms/step - loss: 4.3946 - acc: 0.1522 - val_loss: 4.3270 - val_acc: 0.1458
# Epoch 187/200
# 12/12 [==============================] - 3s 277ms/step - loss: 4.3740 - acc: 0.1376 - val_loss: 4.3652 - val_acc: 0.1606
# Epoch 188/200
# 12/12 [==============================] - 3s 238ms/step - loss: 4.3245 - acc: 0.1600 - val_loss: 4.3775 - val_acc: 0.1684
# Epoch 189/200
# 12/12 [==============================] - 3s 258ms/step - loss: 4.3826 - acc: 0.1764 - val_loss: 4.3137 - val_acc: 0.1649
# Epoch 190/200
# 12/12 [==============================] - 3s 216ms/step - loss: 4.3537 - acc: 0.1696 - val_loss: 4.3593 - val_acc: 0.1524
# Epoch 191/200
# 12/12 [==============================] - 3s 245ms/step - loss: 4.3348 - acc: 0.1630 - val_loss: 4.4062 - val_acc: 0.1720
# Epoch 192/200
# 12/12 [==============================] - 3s 219ms/step - loss: 4.3393 - acc: 0.1794 - val_loss: 4.3719 - val_acc: 0.1756
# Epoch 193/200
# 12/12 [==============================] - 3s 258ms/step - loss: 4.3768 - acc: 0.1814 - val_loss: 4.3764 - val_acc: 0.1947
# Epoch 194/200
# 12/12 [==============================] - 2s 196ms/step - loss: 4.3604 - acc: 0.1876 - val_loss: 4.3111 - val_acc: 0.1904
# Epoch 195/200
# 12/12 [==============================] - 3s 230ms/step - loss: 4.3410 - acc: 0.1897 - val_loss: 4.4631 - val_acc: 0.1360
# Epoch 196/200
# 12/12 [==============================] - 3s 238ms/step - loss: 4.4244 - acc: 0.1617 - val_loss: 4.4324 - val_acc: 0.1396
# Epoch 197/200
# 12/12 [==============================] - 3s 241ms/step - loss: 4.3544 - acc: 0.1719 - val_loss: 4.3172 - val_acc: 0.1641
# Epoch 198/200
# 12/12 [==============================] - 3s 262ms/step - loss: 4.3791 - acc: 0.1569 - val_loss: 4.4782 - val_acc: 0.1440
# Epoch 199/200
# 12/12 [==============================] - 2s 207ms/step - loss: 4.3793 - acc: 0.1815 - val_loss: 4.4235 - val_acc: 0.1929
# Epoch 200/200
# 12/12 [==============================] - 3s 221ms/step - loss: 4.3989 - acc: 0.1909 - val_loss: 4.4286 - val_acc: 0.1576
# Train time: 9m

# %%
plt.figure(figsize=(15,5))
plt.subplot(1,2,1)
plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.legend(['loss','val_loss'])
plt.grid()
plt.subplot(1,2,2)
plt.plot(hist.history['acc'])
plt.plot(hist.history['val_acc'])
plt.legend(['acc','val_acc'])
plt.grid()

# %%
history = []
history.append(hist.history['loss'])
history.append(hist.history['val_loss'])
history.append(hist.history['acc'])
history.append(hist.history['val_acc'])
history = np.array(history)
np.savetxt(model_name+"_"+dir_name+"_history.txt", history, delimiter=",")

# %%
model_json = model.to_json()
with open(model_name+"_"+dir_name+".json", "w") as json_file:
    json_file.write(model_json)
model.save_weights(model_name+"_"+dir_name+".h5")

# %%
from keras.models import model_from_json

# %%
json_file = open(model_name+"_"+dir_name+".json", "r")
loaded_model_json = json_file.read()
json_file.close()
loaded_model = model_from_json(loaded_model_json)
# load weights into new model
loaded_model.load_weights(model_name+"_"+dir_name+".h5")

# %%
# result on train images
X,Y = generator(batch_size, train_dir, H, W).__next__()
Yhat = model.predict(X)
j =1
plt.figure(figsize=(20,20))
for i in range(12):
    # original
    plt.subplot(6,8,j)
    j+=1
    img = XY2img(X[i],Y[i])
    plt.imshow(img)
    plt.axis('OFF')
    # grayscale
    plt.subplot(6,8,j)
    j+=1
    plt.imshow(X[i,:,:,0],'gray')
    plt.axis('OFF')
    # predict
    plt.subplot(6,8,j)
    j += 1
    img = XY2img(X[i],Yhat[i])
    plt.imshow(img)
    plt.axis('OFF')
    # predict
    plt.subplot(6,8,j)
    j += 1
    img = XY2imgf(X[i],Yhat[i])
    plt.imshow(img)
    plt.axis('OFF')
# Out:
# /home/tking/.local/lib/python3.5/site-packages/ipykernel_launcher.py:9: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.
#   if __name__ == '__main__':

# %%
# result on test images
X,Y = generator(batch_size, test_dir, H, W).__next__()
Yhat = model.predict(X)
j =1
plt.figure(figsize=(20,20))
for i in range(12):
    # original
    plt.subplot(6,8,j)
    j+=1
    img = XY2img(X[i],Y[i])
    plt.imshow(img)
    plt.axis('OFF')
    # grayscale
    plt.subplot(6,8,j)
    j+=1
    plt.imshow(X[i,:,:,0],'gray')
    plt.axis('OFF')
    # predict
    plt.subplot(6,8,j)
    j += 1
    img = XY2img(X[i],Yhat[i])
    plt.imshow(img)
    plt.axis('OFF')
    # predict
    plt.subplot(6,8,j)
    j += 1
    img = XY2imgf(X[i],Yhat[i])
    plt.imshow(img)
    plt.axis('OFF')
# Out:
# /home/tking/.local/lib/python3.5/site-packages/ipykernel_launcher.py:9: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.
#   if __name__ == '__main__':

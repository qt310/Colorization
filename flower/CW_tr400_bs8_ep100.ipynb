# %%
from keras.layers import Conv2D, UpSampling2D, InputLayer, Conv2DTranspose
from keras.layers import Activation, Dense, Dropout, Flatten
from keras.layers.normalization import BatchNormalization
from keras.models import Sequential
from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img
from skimage.color import rgb2lab, lab2rgb, rgb2gray, xyz2lab
from skimage.io import imsave
import numpy as np
import os
import random
import tensorflow as tf
from time import time
# Out:
# /home/tking/.local/lib/python3.5/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
import cv2

from scipy.misc import imresize
from skimage.transform import resize

import glob

import matplotlib.pyplot as plt
# %matplotlib inline

from keras.callbacks import EarlyStopping
from keras.utils import to_categorical
import random
from keras import optimizers

# %%
# select vaild images and put into train and test dir (only run once) 
# i = 0
# num_tr = 400
# num_ts = 200
# for img in glob.glob(r"../../images/flower/*.jpg"):
#     n= cv2.imread(img)#BGR
#     if  n is None or np.mean(n)>250 or np.mean(np.std(n,axis=2))<2:
#         os.remove(img)
#     else:
#         if i<num_tr:
#             i+=1
            
#             os.rename(img,r"../../images/flower/train/"+str(i)+".jpg")
#         elif i>=num_tr and i<num_tr+num_ts:
#             i+=1
#             os.rename(img,r"../../images/flower/test/"+str(i)+".jpg")
#         else:
#             break

# %%
def generator(batch_size, dir_path, H, W):
    while True:
#         img_all = []
        X = []
        Y = []
        img_batch = random.sample(glob.glob(dir_path), batch_size)
        for img in img_batch:
            # choose random index in features
            n= cv2.imread(img)#BGR
            m = imresize(n,(H,W,3))
            img_lab = cv2.cvtColor(m.astype(np.uint8), cv2.COLOR_BGR2LAB)
            L = img_lab[:,:,0].reshape(1,H,W,1)
#             img_all.append(m)
            y = np.floor(img_lab[:,:,1:]/16)

            # to_categorical
            y0=y[:,:,0].flatten()
            y1=y[:,:,1].flatten()
            Yc2d0 = to_categorical(y0, num_classes = 16 )
            Yc3d0 = Yc2d0.reshape(H,W,16)
            Yc2d1 = to_categorical(y1, num_classes = 16 )
            Yc3d1 = Yc2d1.reshape(H,W,16)
            Yc3d = np.zeros((H,W,32))
            Yc3d[:,:,:16] = Yc3d0
            Yc3d[:,:,16:] = Yc3d1

            Y.append(Yc3d)
            X.append(L)
        X=np.array(X)
        Y=np.array(Y)
        X=np.reshape(X, (batch_size, H, W, 1))
        Y=np.reshape(Y, (batch_size, H, W, 32))
        yield X, Y

# %%
def XY2img(X,Y):
    H, W, _ = X.shape
    img_lab = np.zeros((H,W,3))
    img_lab[:,:,0] = X[:,:,0]
    img_lab[:,:,1] = np.argmax(Y[:,:,:16],axis=2)*16+8
    img_lab[:,:,2] = np.argmax(Y[:,:,16:],axis=2)*16+8
    img = cv2.cvtColor(img_lab.astype(np.uint8), cv2.COLOR_LAB2RGB)
    return img

# %%
from scipy.ndimage import filters
def XY2imgf(X,Y):
    H, W, _ = X.shape
    img_lab = np.zeros((H,W,3))
    img_lab[:,:,0] = X[:,:,0]
    img_lab[:,:,1] = filters.gaussian_filter(np.argmax(Y[:,:,:16],axis=2)*16+8,3)
    img_lab[:,:,2] = filters.gaussian_filter(np.argmax(Y[:,:,16:],axis=2)*16+8,3)
    img = cv2.cvtColor(img_lab.astype(np.uint8), cv2.COLOR_LAB2RGB)
    return img

# %%
# test if generator and XY2img work
X,Y = generator(1, r"../../images/flower/train/*.jpg", 400, 400).__next__()
img = XY2img(X[0],Y[0])
plt.imshow(img)
plt.axis('off')
# Out:
# /home/tking/.local/lib/python3.5/site-packages/ipykernel_launcher.py:10: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.
#   # Remove the CWD from sys.path while we load stuff.
# (-0.5, 399.5, 399.5, -0.5)

# %%
H = 64
W = 64
train_dir = r"../../images/flower/train/*.jpg"
test_dir = r"../../images/flower/test*.jpg"

# %%
# read images to compute class_weight
# img_all = []
# X = []
Y = []
for img in glob.glob(train_dir):
    n= cv2.imread(img)#BGR
    m = imresize(n,(H,W,3))
    img_lab = cv2.cvtColor(m.astype(np.uint8), cv2.COLOR_BGR2LAB)
#     L = img_lab[:,:,0].reshape(1,H,W,1)
#     img_all.append(m)
    y = np.floor(img_lab[:,:,1:]/16)
    
    # to_categorical
    y0=y[:,:,0].flatten()
    y1=y[:,:,1].flatten()
    yc2d0 = to_categorical(y0, num_classes = 16 )
    yc3d0 = yc2d0.reshape(H,W,16)
    yc2d1 = to_categorical(y1, num_classes = 16 )
    yc3d1 = yc2d1.reshape(H,W,16)
    yc3d = np.zeros((H,W,32))
    yc3d[:,:,:16] = yc3d0
    yc3d[:,:,16:] = yc3d1

    Y.append(yc3d)
#     X.append(L)
#     if len(Y)==num:
#         break
# Out:
# /home/tking/.local/lib/python3.5/site-packages/ipykernel_launcher.py:7: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.
#   import sys

# %%
num = len(Y)
Y=np.array(Y)
Y=np.reshape(Y, (num, H, W, 32))

# %%
# compute class_weight
from sklearn.utils import class_weight
Yflat16A = Y[:,:,:,:16].reshape(num*H*W,16)
YflatA = np.argmax(Yflat16A,axis=1)
YclassA = np.unique(YflatA)
class_weight_A = class_weight.compute_class_weight('balanced',
                                                 YclassA,
                                                 YflatA)
Yflat16B = Y[:,:,:,16:].reshape(num*H*W,16)
YflatB = np.argmax(Yflat16B,axis=1)
YclassB = np.unique(YflatB)
class_weight_B = class_weight.compute_class_weight('balanced',
                                                 YclassB,
                                                 YflatB)

class_weight = np.zeros(32)# ones or zeros?
for i in range(len(YclassA)):
    class_weight[YclassA[i]]=class_weight_A[i]
for i in range(len(YclassB)):
    class_weight[YclassB[i]+16]=class_weight_B[i]

print(class_weight)
# Out:
# [0.00000000e+00 0.00000000e+00 4.20102564e+04 1.33932805e+02
#  2.39283784e+01 1.98824335e+00 4.56828533e-01 2.06168106e-01
#  2.55026992e-01 1.44831323e+00 2.79925303e+00 3.45611718e+00
#  7.22736376e+00 8.50410049e+01 3.15076923e+04 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 4.55111111e+04 1.05921903e+02
#  1.80838852e+01 6.32655268e+00 2.67722917e+00 8.74149007e-01
#  2.43799946e-01 3.16529306e-01 5.71936836e-01 1.24170880e+00
#  2.88727232e+00 1.01458968e+01 0.00000000e+00 0.00000000e+00]

# %%
# Building the neural network
import keras.backend as K
K.clear_session()
model = Sequential()
model.add(InputLayer(input_shape=(None, None, 1)))
model.add(Conv2D(8, (3, 3), activation='relu', padding='same', strides=2))
model.add(Conv2D(8, (3, 3), activation='relu', padding='same'))
model.add(Conv2D(16, (3, 3), activation='relu', padding='same'))
model.add(Conv2D(16, (3, 3), activation='relu', padding='same', strides=2))
model.add(Conv2D(32, (3, 3), activation='relu', padding='same'))
model.add(Conv2D(32, (3, 3), activation='relu', padding='same', strides=2))
model.add(UpSampling2D((2, 2)))
model.add(Conv2D(32, (3, 3), activation='relu', padding='same'))
model.add(UpSampling2D((2, 2)))
model.add(Conv2D(16, (3, 3), activation='relu', padding='same'))
model.add(UpSampling2D((2, 2)))
model.add(Conv2D(32, (3, 3), activation='sigmoid', padding='same'))#TODO
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, None, None, 1)     0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, None, None, 8)     80
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, None, None, 8)     584
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, None, None, 16)    1168
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, None, None, 16)    2320
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, None, None, 32)    4640
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, None, None, 32)    9248
# _________________________________________________________________
# up_sampling2d_1 (UpSampling2 (None, None, None, 32)    0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, None, None, 32)    9248
# _________________________________________________________________
# up_sampling2d_2 (UpSampling2 (None, None, None, 32)    0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, None, None, 16)    4624
# _________________________________________________________________
# up_sampling2d_3 (UpSampling2 (None, None, None, 16)    0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, None, None, 32)    4640
# =================================================================
# Total params: 36,552
# Trainable params: 36,552
# Non-trainable params: 0
# _________________________________________________________________

# %%
# compile model
opt = optimizers.Adam(lr=0.001)
model.compile(optimizer=opt,
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %%
batch_size = 8
train_dir = r"../../images/flower/train/*.jpg"
test_dir = r"../../images/flower/test/*.jpg"

train_generator = generator(batch_size, train_dir, H, W)
test_generator = generator(batch_size, test_dir, H, W)
tr_size = len(glob.glob(train_dir))
ts_size = len(glob.glob(test_dir))
steps_per_epoch = tr_size// batch_size
validation_steps = ts_size // batch_size
print(tr_size,ts_size,steps_per_epoch,validation_steps)
# Out:
# 400 200 50 25

# %%
# TODO change to fit_generator
t0 = time()
hist = model.fit_generator(train_generator,
                            steps_per_epoch=steps_per_epoch,
                            epochs=100,
                            validation_data=test_generator,
                            validation_steps=validation_steps,
                            class_weight=class_weight)
                            #callbacks=[EarlyStopping(patience=5)])
print('Train time: %.fm'%((time()-t0)/60))
# Out:
# Epoch 1/100
# /home/tking/.local/lib/python3.5/site-packages/ipykernel_launcher.py:10: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.
#   # Remove the CWD from sys.path while we load stuff.
# 50/50 [==============================] - 4s 86ms/step - loss: 5.2792 - acc: 0.2633 - val_loss: 4.8531 - val_acc: 0.2839
# Epoch 2/100
# 50/50 [==============================] - 3s 62ms/step - loss: 4.8429 - acc: 0.3070 - val_loss: 4.8647 - val_acc: 0.3358
# Epoch 3/100
# 50/50 [==============================] - 3s 63ms/step - loss: 4.7220 - acc: 0.3576 - val_loss: 4.7567 - val_acc: 0.4129
# Epoch 4/100
# 50/50 [==============================] - 3s 63ms/step - loss: 4.7627 - acc: 0.3699 - val_loss: 4.6891 - val_acc: 0.4005
# Epoch 5/100
# 50/50 [==============================] - 3s 63ms/step - loss: 4.6340 - acc: 0.3745 - val_loss: 4.7294 - val_acc: 0.3727
# Epoch 6/100
# 50/50 [==============================] - 3s 62ms/step - loss: 4.7228 - acc: 0.3631 - val_loss: 4.7329 - val_acc: 0.4028
# Epoch 7/100
# 50/50 [==============================] - 3s 63ms/step - loss: 4.6074 - acc: 0.3703 - val_loss: 4.6393 - val_acc: 0.4052
# Epoch 8/100
# 50/50 [==============================] - 3s 63ms/step - loss: 4.6828 - acc: 0.3756 - val_loss: 4.7546 - val_acc: 0.3729
# Epoch 9/100
# 50/50 [==============================] - 3s 63ms/step - loss: 4.5949 - acc: 0.3741 - val_loss: 4.6876 - val_acc: 0.3833
# Epoch 10/100
# 50/50 [==============================] - 3s 63ms/step - loss: 4.5664 - acc: 0.3882 - val_loss: 4.5978 - val_acc: 0.4084
# Epoch 11/100
# 50/50 [==============================] - 3s 63ms/step - loss: 4.5591 - acc: 0.3829 - val_loss: 4.5868 - val_acc: 0.3791
# Epoch 12/100
# 50/50 [==============================] - 3s 63ms/step - loss: 4.5227 - acc: 0.3681 - val_loss: 4.6877 - val_acc: 0.3850
# Epoch 13/100
# 50/50 [==============================] - 3s 63ms/step - loss: 4.5476 - acc: 0.3775 - val_loss: 4.6004 - val_acc: 0.3901
# Epoch 14/100
# 50/50 [==============================] - 3s 63ms/step - loss: 4.5065 - acc: 0.3930 - val_loss: 4.8699 - val_acc: 0.3519
# Epoch 15/100
# 50/50 [==============================] - 3s 63ms/step - loss: 4.4643 - acc: 0.3881 - val_loss: 4.5657 - val_acc: 0.3941
# Epoch 16/100
# 50/50 [==============================] - 3s 63ms/step - loss: 4.5104 - acc: 0.3710 - val_loss: 4.6954 - val_acc: 0.3742
# Epoch 17/100
# 50/50 [==============================] - 3s 63ms/step - loss: 4.4727 - acc: 0.3726 - val_loss: 4.7650 - val_acc: 0.3555
# Epoch 18/100
# 50/50 [==============================] - 3s 63ms/step - loss: 4.4781 - acc: 0.3760 - val_loss: 4.6874 - val_acc: 0.3873
# Epoch 19/100
# 50/50 [==============================] - 3s 63ms/step - loss: 4.3892 - acc: 0.3839 - val_loss: 4.7610 - val_acc: 0.3595
# Epoch 20/100
# 50/50 [==============================] - 3s 62ms/step - loss: 4.4458 - acc: 0.3738 - val_loss: 4.7059 - val_acc: 0.3689
# Epoch 21/100
# 50/50 [==============================] - 3s 63ms/step - loss: 4.4205 - acc: 0.3193 - val_loss: 4.7380 - val_acc: 0.2696
# Epoch 22/100
# 50/50 [==============================] - 3s 62ms/step - loss: 4.3713 - acc: 0.3047 - val_loss: 4.6106 - val_acc: 0.3222
# Epoch 23/100
# 50/50 [==============================] - 3s 63ms/step - loss: 4.4389 - acc: 0.3208 - val_loss: 4.6733 - val_acc: 0.3096
# Epoch 24/100
# 50/50 [==============================] - 3s 62ms/step - loss: 4.3211 - acc: 0.3091 - val_loss: 4.6478 - val_acc: 0.3398
# Epoch 25/100
# 50/50 [==============================] - 3s 62ms/step - loss: 4.3727 - acc: 0.2842 - val_loss: 4.8524 - val_acc: 0.2213
# Epoch 26/100
# 50/50 [==============================] - 3s 62ms/step - loss: 4.3273 - acc: 0.2724 - val_loss: 4.7338 - val_acc: 0.2913
# Epoch 27/100
# 50/50 [==============================] - 3s 63ms/step - loss: 4.2560 - acc: 0.2718 - val_loss: 4.8287 - val_acc: 0.2152
# Epoch 28/100
# 50/50 [==============================] - 3s 62ms/step - loss: 4.2261 - acc: 0.2822 - val_loss: 4.8216 - val_acc: 0.2590
# Epoch 29/100
# 50/50 [==============================] - 3s 63ms/step - loss: 4.2369 - acc: 0.2824 - val_loss: 4.7199 - val_acc: 0.2624
# Epoch 30/100
# 50/50 [==============================] - 3s 63ms/step - loss: 4.2506 - acc: 0.3165 - val_loss: 5.0102 - val_acc: 0.2046
# Epoch 31/100
# 50/50 [==============================] - 3s 63ms/step - loss: 4.2089 - acc: 0.3237 - val_loss: 4.9296 - val_acc: 0.2075
# Epoch 32/100
# 50/50 [==============================] - 3s 62ms/step - loss: 4.2295 - acc: 0.2992 - val_loss: 4.8346 - val_acc: 0.2371
# Epoch 33/100
# 50/50 [==============================] - 3s 62ms/step - loss: 4.1693 - acc: 0.2962 - val_loss: 4.8853 - val_acc: 0.3012
# Epoch 34/100
# 50/50 [==============================] - 3s 63ms/step - loss: 4.1666 - acc: 0.3106 - val_loss: 5.0114 - val_acc: 0.2185
# Epoch 35/100
# 50/50 [==============================] - 3s 63ms/step - loss: 4.1472 - acc: 0.2784 - val_loss: 5.0716 - val_acc: 0.2695
# Epoch 36/100
# 50/50 [==============================] - 3s 63ms/step - loss: 4.1112 - acc: 0.2975 - val_loss: 5.1210 - val_acc: 0.2231
# Epoch 37/100
# 50/50 [==============================] - 3s 62ms/step - loss: 4.1167 - acc: 0.2974 - val_loss: 4.8245 - val_acc: 0.2845
# Epoch 38/100
# 50/50 [==============================] - 3s 63ms/step - loss: 4.0852 - acc: 0.3163 - val_loss: 5.0919 - val_acc: 0.2657
# Epoch 39/100
# 50/50 [==============================] - 3s 62ms/step - loss: 4.0463 - acc: 0.2933 - val_loss: 5.1293 - val_acc: 0.2375
# Epoch 40/100
# 50/50 [==============================] - 3s 62ms/step - loss: 4.0838 - acc: 0.3304 - val_loss: 5.2618 - val_acc: 0.2697
# Epoch 41/100
# 50/50 [==============================] - 3s 62ms/step - loss: 3.9680 - acc: 0.3406 - val_loss: 5.0583 - val_acc: 0.2420
# Epoch 42/100
# 50/50 [==============================] - 3s 63ms/step - loss: 3.9418 - acc: 0.3051 - val_loss: 5.1271 - val_acc: 0.1927
# Epoch 43/100
# 50/50 [==============================] - 3s 62ms/step - loss: 3.9380 - acc: 0.3302 - val_loss: 5.3467 - val_acc: 0.2299
# Epoch 44/100
# 50/50 [==============================] - 3s 62ms/step - loss: 3.9019 - acc: 0.3477 - val_loss: 5.3842 - val_acc: 0.2322
# Epoch 45/100
# 50/50 [==============================] - 3s 63ms/step - loss: 3.9691 - acc: 0.3220 - val_loss: 5.0746 - val_acc: 0.2453
# Epoch 46/100
# 50/50 [==============================] - 3s 63ms/step - loss: 3.8323 - acc: 0.3342 - val_loss: 5.3604 - val_acc: 0.2232
# Epoch 47/100
# 50/50 [==============================] - 3s 62ms/step - loss: 3.9249 - acc: 0.3140 - val_loss: 5.4033 - val_acc: 0.2401
# Epoch 48/100
# 50/50 [==============================] - 3s 62ms/step - loss: 3.8619 - acc: 0.3074 - val_loss: 5.4095 - val_acc: 0.2492
# Epoch 49/100
# 50/50 [==============================] - 3s 63ms/step - loss: 3.8394 - acc: 0.3428 - val_loss: 5.1215 - val_acc: 0.1739
# Epoch 50/100
# 50/50 [==============================] - 3s 63ms/step - loss: 3.8074 - acc: 0.3348 - val_loss: 5.0427 - val_acc: 0.2889
# Epoch 51/100
# 50/50 [==============================] - 3s 63ms/step - loss: 3.8294 - acc: 0.3504 - val_loss: 5.2800 - val_acc: 0.2622
# Epoch 52/100
# 50/50 [==============================] - 3s 62ms/step - loss: 3.8617 - acc: 0.3253 - val_loss: 5.4129 - val_acc: 0.2702
# Epoch 53/100
# 50/50 [==============================] - 3s 64ms/step - loss: 3.8505 - acc: 0.3343 - val_loss: 5.5247 - val_acc: 0.2402
# Epoch 54/100
# 50/50 [==============================] - 3s 62ms/step - loss: 3.8011 - acc: 0.3422 - val_loss: 5.7379 - val_acc: 0.2179
# Epoch 55/100
# 50/50 [==============================] - 3s 63ms/step - loss: 3.7401 - acc: 0.3483 - val_loss: 5.3756 - val_acc: 0.2286
# Epoch 56/100
# 50/50 [==============================] - 3s 62ms/step - loss: 3.8127 - acc: 0.3443 - val_loss: 5.6679 - val_acc: 0.2060
# Epoch 57/100
# 50/50 [==============================] - 3s 63ms/step - loss: 3.7344 - acc: 0.3481 - val_loss: 5.6788 - val_acc: 0.2057
# Epoch 58/100
# 50/50 [==============================] - 3s 63ms/step - loss: 3.7979 - acc: 0.3680 - val_loss: 5.4028 - val_acc: 0.2317
# Epoch 59/100
# 50/50 [==============================] - 3s 63ms/step - loss: 3.7259 - acc: 0.3374 - val_loss: 5.6318 - val_acc: 0.1952
# Epoch 60/100
# 50/50 [==============================] - 3s 63ms/step - loss: 3.7414 - acc: 0.3423 - val_loss: 5.5631 - val_acc: 0.1967
# Epoch 61/100
# 50/50 [==============================] - 3s 61ms/step - loss: 3.7406 - acc: 0.3651 - val_loss: 5.6854 - val_acc: 0.2066
# Epoch 62/100
# 50/50 [==============================] - 3s 63ms/step - loss: 3.7803 - acc: 0.3235 - val_loss: 5.5968 - val_acc: 0.2004
# Epoch 63/100
# 50/50 [==============================] - 3s 63ms/step - loss: 3.7202 - acc: 0.3373 - val_loss: 5.7523 - val_acc: 0.2144
# Epoch 64/100
# 50/50 [==============================] - 3s 62ms/step - loss: 3.6957 - acc: 0.3641 - val_loss: 5.4734 - val_acc: 0.2152
# Epoch 65/100
# 50/50 [==============================] - 3s 63ms/step - loss: 3.6781 - acc: 0.3426 - val_loss: 5.5622 - val_acc: 0.2530
# Epoch 66/100
# 50/50 [==============================] - 3s 63ms/step - loss: 3.6745 - acc: 0.3542 - val_loss: 5.7943 - val_acc: 0.2135
# Epoch 67/100
# 50/50 [==============================] - 3s 62ms/step - loss: 3.6532 - acc: 0.3478 - val_loss: 5.6822 - val_acc: 0.1932
# Epoch 68/100
# 50/50 [==============================] - 3s 63ms/step - loss: 3.7137 - acc: 0.3405 - val_loss: 5.7789 - val_acc: 0.1729
# Epoch 69/100
# 50/50 [==============================] - 3s 63ms/step - loss: 3.7232 - acc: 0.3627 - val_loss: 5.8379 - val_acc: 0.2183
# Epoch 70/100
# 50/50 [==============================] - 3s 62ms/step - loss: 3.7001 - acc: 0.3424 - val_loss: 5.9141 - val_acc: 0.2346
# Epoch 71/100
# 50/50 [==============================] - 3s 63ms/step - loss: 3.7072 - acc: 0.3566 - val_loss: 5.8186 - val_acc: 0.1832
# Epoch 72/100
# 50/50 [==============================] - 3s 62ms/step - loss: 3.6667 - acc: 0.3643 - val_loss: 5.5531 - val_acc: 0.2423
# Epoch 73/100
# 50/50 [==============================] - 3s 62ms/step - loss: 3.6015 - acc: 0.3675 - val_loss: 5.6472 - val_acc: 0.2532
# Epoch 74/100
# 50/50 [==============================] - 3s 63ms/step - loss: 3.6105 - acc: 0.3866 - val_loss: 5.6856 - val_acc: 0.2231
# Epoch 75/100
# 50/50 [==============================] - 3s 62ms/step - loss: 3.6735 - acc: 0.3666 - val_loss: 5.7085 - val_acc: 0.2369
# Epoch 76/100
# 50/50 [==============================] - 3s 63ms/step - loss: 3.6544 - acc: 0.3562 - val_loss: 5.7044 - val_acc: 0.2200
# Epoch 77/100
# 50/50 [==============================] - 3s 63ms/step - loss: 3.6049 - acc: 0.3599 - val_loss: 5.7515 - val_acc: 0.2545
# Epoch 78/100
# 50/50 [==============================] - 3s 62ms/step - loss: 3.5855 - acc: 0.3713 - val_loss: 5.6935 - val_acc: 0.2038
# Epoch 79/100
# 50/50 [==============================] - 3s 63ms/step - loss: 3.5586 - acc: 0.3692 - val_loss: 5.9713 - val_acc: 0.1996
# Epoch 80/100
# 50/50 [==============================] - 3s 62ms/step - loss: 3.5991 - acc: 0.3708 - val_loss: 5.6561 - val_acc: 0.2508
# Epoch 81/100
# 50/50 [==============================] - 3s 63ms/step - loss: 3.5771 - acc: 0.3828 - val_loss: 5.7009 - val_acc: 0.2397
# Epoch 82/100
# 50/50 [==============================] - 3s 63ms/step - loss: 3.5260 - acc: 0.3731 - val_loss: 5.8743 - val_acc: 0.2206
# Epoch 83/100
# 50/50 [==============================] - 3s 62ms/step - loss: 3.5501 - acc: 0.3631 - val_loss: 5.7368 - val_acc: 0.2195
# Epoch 84/100
# 50/50 [==============================] - 3s 63ms/step - loss: 3.5639 - acc: 0.3515 - val_loss: 5.9478 - val_acc: 0.1714
# Epoch 85/100
# 50/50 [==============================] - 3s 62ms/step - loss: 3.5548 - acc: 0.3608 - val_loss: 5.7308 - val_acc: 0.1880
# Epoch 86/100
# 50/50 [==============================] - 3s 63ms/step - loss: 3.5822 - acc: 0.3744 - val_loss: 5.8002 - val_acc: 0.2266
# Epoch 87/100
# 50/50 [==============================] - 3s 62ms/step - loss: 3.5459 - acc: 0.3807 - val_loss: 5.7994 - val_acc: 0.2509
# Epoch 88/100
# 50/50 [==============================] - 3s 63ms/step - loss: 3.6086 - acc: 0.3722 - val_loss: 5.7677 - val_acc: 0.2133
# Epoch 89/100
# 50/50 [==============================] - 3s 62ms/step - loss: 3.5748 - acc: 0.3689 - val_loss: 5.8978 - val_acc: 0.2281
# Epoch 90/100
# 50/50 [==============================] - 3s 63ms/step - loss: 3.5620 - acc: 0.3623 - val_loss: 5.8530 - val_acc: 0.2396
# Epoch 91/100
# 50/50 [==============================] - 3s 63ms/step - loss: 3.5501 - acc: 0.3576 - val_loss: 6.1064 - val_acc: 0.2284
# Epoch 92/100
# 50/50 [==============================] - 3s 62ms/step - loss: 3.5436 - acc: 0.3411 - val_loss: 5.8539 - val_acc: 0.2211
# Epoch 93/100
# 50/50 [==============================] - 3s 63ms/step - loss: 3.5411 - acc: 0.3595 - val_loss: 6.2155 - val_acc: 0.2217
# Epoch 94/100
# 50/50 [==============================] - 3s 63ms/step - loss: 3.5147 - acc: 0.3690 - val_loss: 6.0006 - val_acc: 0.2435
# Epoch 95/100
# 50/50 [==============================] - 3s 62ms/step - loss: 3.4868 - acc: 0.3840 - val_loss: 5.9032 - val_acc: 0.1918
# Epoch 96/100
# 50/50 [==============================] - 3s 63ms/step - loss: 3.5129 - acc: 0.3724 - val_loss: 5.9107 - val_acc: 0.2197
# Epoch 97/100
# 50/50 [==============================] - 3s 63ms/step - loss: 3.5172 - acc: 0.3614 - val_loss: 5.8761 - val_acc: 0.2191
# Epoch 98/100
# 50/50 [==============================] - 3s 63ms/step - loss: 3.5410 - acc: 0.3567 - val_loss: 5.9989 - val_acc: 0.1914
# Epoch 99/100
# 50/50 [==============================] - 3s 63ms/step - loss: 3.5255 - acc: 0.3693 - val_loss: 5.7623 - val_acc: 0.2158
# Epoch 100/100
# 50/50 [==============================] - 3s 62ms/step - loss: 3.5017 - acc: 0.3749 - val_loss: 5.8901 - val_acc: 0.2131
# Train time: 5m

# %%
plt.figure(figsize=(15,5))
plt.subplot(1,2,1)
plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.legend(['loss','val_loss'])
plt.grid()
plt.subplot(1,2,2)
plt.plot(hist.history['acc'])
plt.plot(hist.history['val_acc'])
plt.legend(['acc','val_acc'])
plt.grid()

# %%
model_json = model.to_json()
with open("model_CW_flower_tr400_bs8_ep100.json", "w") as json_file:
    json_file.write(model_json)
model.save_weights("model_CW_flower_tr400_bs8_ep100.h5")

# %%
from keras.models import model_from_json

# %%
json_file = open('model_CW_flower_tr400_bs8_ep100.json', 'r')
loaded_model_json = json_file.read()
json_file.close()
loaded_model = model_from_json(loaded_model_json)
# load weights into new model
loaded_model.load_weights("model_CW_flower_tr400_bs8_ep100.h5")

# %%
# result on train images
X,Y = generator(batch_size, train_dir, H, W).__next__()
Yhat = model.predict(X)
j =1
plt.figure(figsize=(20,20))
for i in range(batch_size):
    # original
    plt.subplot(6,8,j)
    j+=1
    img = XY2img(X[i],Y[i])
    plt.imshow(img)
    plt.axis('OFF')
    # grayscale
    plt.subplot(6,8,j)
    j+=1
    plt.imshow(X[i,:,:,0],'gray')
    plt.axis('OFF')
    # predict
    plt.subplot(6,8,j)
    j += 1
    img = XY2img(X[i],Yhat[i])
    plt.imshow(img)
    plt.axis('OFF')
    # predict
    plt.subplot(6,8,j)
    j += 1
    img = XY2imgf(X[i],Yhat[i])
    plt.imshow(img)
    plt.axis('OFF')
# Out:
# /home/tking/.local/lib/python3.5/site-packages/ipykernel_launcher.py:10: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.
#   # Remove the CWD from sys.path while we load stuff.

# %%
# result on test images
X,Y = generator(batch_size, test_dir, H, W).__next__()
Yhat = model.predict(X)
j =1
plt.figure(figsize=(20,20))
for i in range(batch_size):
    # original
    plt.subplot(6,8,j)
    j+=1
    img = XY2img(X[i],Y[i])
    plt.imshow(img)
    plt.axis('OFF')
    # grayscale
    plt.subplot(6,8,j)
    j+=1
    plt.imshow(X[i,:,:,0],'gray')
    plt.axis('OFF')
    # predict
    plt.subplot(6,8,j)
    j += 1
    img = XY2img(X[i],Yhat[i])
    plt.imshow(img)
    plt.axis('OFF')
    # predict
    plt.subplot(6,8,j)
    j += 1
    img = XY2imgf(X[i],Yhat[i])
    plt.imshow(img)
    plt.axis('OFF')
# Out:
# /home/tking/.local/lib/python3.5/site-packages/ipykernel_launcher.py:10: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.
#   # Remove the CWD from sys.path while we load stuff.

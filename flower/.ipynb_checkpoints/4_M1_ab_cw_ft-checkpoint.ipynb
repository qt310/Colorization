# %%
from keras.layers import Conv2D, UpSampling2D, InputLayer, Conv2DTranspose
from keras.layers import Activation, Dense, Dropout, Flatten
from keras.layers.normalization import BatchNormalization
from keras.models import Sequential
from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img
from skimage.color import rgb2lab, lab2rgb, rgb2gray, xyz2lab
from skimage.io import imsave
import numpy as np
import os
import random
import tensorflow as tf
from time import time

import cv2

from scipy.misc import imresize
from skimage.transform import resize

import glob

import matplotlib.pyplot as plt
# %matplotlib inline

from keras.callbacks import EarlyStopping
from keras.utils import to_categorical
import random
from keras import optimizers
from scipy.ndimage import filters
# Out:
# /home/tking/.local/lib/python3.5/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
#define parameters:
dir_name = "flower" # Variable
model_name = "4_M1_ab_cw_ft"# Variable

train_dir = r"../../images/"+dir_name+"/train/*.jpg"
test_dir = r"../../images/"+dir_name+"/test/*.jpg"
H = 64
W = 64
batch_size = 32

# %%
# select vaild images and put into train and test dir (only run once) 
# i = 0
# num_tr = 2000
# num_ts = 500
# for img in glob.glob(r"../../images/"+dir_name+"/*.jpg"):
#     try:
#         n= cv2.imread(img)#BGR
#         if  n is None or np.mean(n)>250 or np.mean(np.std(n,axis=2))<2:
#             os.remove(img)
#         else:
#             if i<num_tr:
#                 i+=1
#                 os.rename(img,r"../../images/"+dir_name+"/train/"+str(i)+".jpg")
#             elif i>=num_tr and i<num_tr+num_ts:
#                 i+=1
#                 os.rename(img,r"../../images/"+dir_name+"/test/"+str(i)+".jpg")
#             else:
#                 break
#     except:
#         pass
print('tr_size = ',len(glob.glob(train_dir)))
print('ts_size = ',len(glob.glob(test_dir)))
# Out:
# tr_size =  400
# ts_size =  200

# %%
def generator(batch_size, dir_path, H, W):
    while True:
        X = []
        Y = []
        img_batch = random.sample(glob.glob(dir_path), batch_size)
        for img in img_batch:
            # choose random index in features
            n= cv2.imread(img)#BGR
            m = imresize(n,(H,W,3))
            img_lab = cv2.cvtColor(m.astype(np.uint8), cv2.COLOR_BGR2LAB)
            L = img_lab[:,:,0].reshape(1,H,W,1)
            y = np.floor(img_lab[:,:,1:]/16)

            # to_categorical
            y0=y[:,:,0].flatten()
            y1=y[:,:,1].flatten()
            Yc2d0 = to_categorical(y0, num_classes = 16 )
            Yc3d0 = Yc2d0.reshape(H,W,16)
            Yc2d1 = to_categorical(y1, num_classes = 16 )
            Yc3d1 = Yc2d1.reshape(H,W,16)
            Yc3d = np.zeros((H,W,32))
            Yc3d[:,:,:16] = Yc3d0
            Yc3d[:,:,16:] = Yc3d1

            Y.append(Yc3d)
            X.append(L)
        X=np.array(X)
        Y=np.array(Y)
        X=np.reshape(X, (batch_size, H, W, 1))
        Y=np.reshape(Y, (batch_size, H, W, 32))
        yield X, Y

# %%
def XY2img(X,Y):
    H, W, _ = X.shape
    img_lab = np.zeros((H,W,3))
    img_lab[:,:,0] = X[:,:,0]
    img_lab[:,:,1] = np.argmax(Y[:,:,:16],axis=2)*16+8
    img_lab[:,:,2] = np.argmax(Y[:,:,16:],axis=2)*16+8
    img = cv2.cvtColor(img_lab.astype(np.uint8), cv2.COLOR_LAB2RGB)
    return img

# %%
def XY2imgf(X,Y):
    H, W, _ = X.shape
    img_lab = np.zeros((H,W,3))
    img_lab[:,:,0] = X[:,:,0]
    img_lab[:,:,1] = filters.gaussian_filter(np.argmax(Y[:,:,:16],axis=2)*16+8,5)
    img_lab[:,:,2] = filters.gaussian_filter(np.argmax(Y[:,:,16:],axis=2)*16+8,5)
    img = cv2.cvtColor(img_lab.astype(np.uint8), cv2.COLOR_LAB2RGB)
    return img

# %%
# show some images
plt.figure(figsize=(15,5))
X,Y = generator(batch_size, train_dir, H, W).__next__()    
for i in range(8):
    plt.subplot(1,8,i+1)
    img = XY2img(X[i],Y[i])
    plt.imshow(img)
    plt.axis('off')
# Out:
# /home/tking/.local/lib/python3.5/site-packages/ipykernel_launcher.py:9: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.
#   if __name__ == '__main__':

# %%
# read images to compute class_weight
Y = []
img_sample = random.sample(glob.glob(train_dir), 400)#save memory
for img in img_sample:
    n= cv2.imread(img)#BGR
    m = imresize(n,(H,W,3))
    img_lab = cv2.cvtColor(m.astype(np.uint8), cv2.COLOR_BGR2LAB)
    y = np.floor(img_lab[:,:,1:]/16)
    
    # to_categorical
    y0=y[:,:,0].flatten()
    y1=y[:,:,1].flatten()
    yc2d0 = to_categorical(y0, num_classes = 16 )
    yc3d0 = yc2d0.reshape(H,W,16)
    yc2d1 = to_categorical(y1, num_classes = 16 )
    yc3d1 = yc2d1.reshape(H,W,16)
    yc3d = np.zeros((H,W,32))
    yc3d[:,:,:16] = yc3d0
    yc3d[:,:,16:] = yc3d1
    Y.append(yc3d)
num = len(Y)
Y=np.array(Y)
Y=np.reshape(Y, (num, H, W, 32))
# Out:
# /home/tking/.local/lib/python3.5/site-packages/ipykernel_launcher.py:6: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.

# %%
# compute class_weight
from sklearn.utils import class_weight
Yflat16A = Y[:,:,:,:16].reshape(num*H*W,16)
YflatA = np.argmax(Yflat16A,axis=1)
YclassA = np.unique(YflatA)
class_weight_A = class_weight.compute_class_weight('balanced',
                                                 YclassA,
                                                 YflatA)
Yflat16B = Y[:,:,:,16:].reshape(num*H*W,16)
YflatB = np.argmax(Yflat16B,axis=1)
YclassB = np.unique(YflatB)
class_weight_B = class_weight.compute_class_weight('balanced',
                                                 YclassB,
                                                 YflatB)

class_weight = np.zeros(32)
for i in range(len(YclassA)):
    class_weight[YclassA[i]]=class_weight_A[i]
for i in range(len(YclassB)):
    class_weight[YclassB[i]+16]=class_weight_B[i]

plt.stem(class_weight)
plt.yscale('log')
plt.ylabel('class_weight')
plt.xlabel('classes')
# Out:
# Text(0.5,0,'classes')

# %%
# Building the neural network
import keras.backend as K
K.clear_session()
model = Sequential()
model.add(InputLayer(input_shape=(None, None, 1)))
model.add(Conv2D(8, (3, 3), activation='relu', padding='same', strides=2))
model.add(Conv2D(8, (3, 3), activation='relu', padding='same'))
model.add(Conv2D(16, (3, 3), activation='relu', padding='same'))
model.add(Conv2D(16, (3, 3), activation='relu', padding='same', strides=2))
model.add(Conv2D(32, (3, 3), activation='relu', padding='same'))
model.add(Conv2D(32, (3, 3), activation='relu', padding='same', strides=2))
model.add(Conv2DTranspose(32, (2,2), strides=2, padding='same', activation='relu'))
model.add(Conv2D(32, (3, 3), activation='relu', padding='same'))
model.add(Conv2DTranspose(32, (2,2), strides=2, padding='same', activation='relu'))
model.add(Conv2D(16, (3, 3), activation='relu', padding='same'))
model.add(Conv2DTranspose(32, (2,2), strides=2, padding='same', activation='relu'))
model.add(Conv2D(32, (3, 3), activation='sigmoid', padding='same'))#TODO
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, None, None, 1)     0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, None, None, 8)     80
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, None, None, 8)     584
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, None, None, 16)    1168
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, None, None, 16)    2320
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, None, None, 32)    4640
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, None, None, 32)    9248
# _________________________________________________________________
# conv2d_transpose_1 (Conv2DTr (None, None, None, 32)    4128
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, None, None, 32)    9248
# _________________________________________________________________
# conv2d_transpose_2 (Conv2DTr (None, None, None, 32)    4128
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, None, None, 16)    4624
# _________________________________________________________________
# conv2d_transpose_3 (Conv2DTr (None, None, None, 32)    2080
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, None, None, 32)    9248
# =================================================================
# Total params: 51,496
# Trainable params: 51,496
# Non-trainable params: 0
# _________________________________________________________________

# %%
# compile model
opt = optimizers.Adam(lr=0.001)
model.compile(optimizer=opt,
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %%
train_generator = generator(batch_size, train_dir, H, W)
test_generator = generator(batch_size, test_dir, H, W)
tr_size = len(glob.glob(train_dir))
ts_size = len(glob.glob(test_dir))
steps_per_epoch = tr_size// batch_size
validation_steps = ts_size // batch_size
print(tr_size,ts_size,steps_per_epoch,validation_steps)
# Out:
# 400 200 12 6

# %%
t0 = time()
hist = model.fit_generator(train_generator,
                            steps_per_epoch=steps_per_epoch,
                            epochs=100,
                            validation_data=test_generator,
                            validation_steps=validation_steps,
                            class_weight=class_weight,
                            verbose=1)
print('Train time: %.fm'%((time()-t0)/60))
# Out:
# Epoch 1/100
# /home/tking/.local/lib/python3.5/site-packages/ipykernel_launcher.py:9: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.
#   if __name__ == '__main__':
# 12/12 [==============================] - 17s 1s/step - loss: 4.4061 - acc: 0.3831 - val_loss: 4.6929 - val_acc: 0.3844
# Epoch 2/100
# 12/12 [==============================] - 16s 1s/step - loss: 4.4297 - acc: 0.3820 - val_loss: 4.7221 - val_acc: 0.3547
# Epoch 3/100
# 12/12 [==============================] - 16s 1s/step - loss: 4.4410 - acc: 0.3977 - val_loss: 4.6571 - val_acc: 0.4000
# Epoch 4/100
# 12/12 [==============================] - 16s 1s/step - loss: 4.4542 - acc: 0.3748 - val_loss: 4.7257 - val_acc: 0.3838
# Epoch 5/100
# 12/12 [==============================] - 16s 1s/step - loss: 4.4681 - acc: 0.3673 - val_loss: 4.6218 - val_acc: 0.4023
# Epoch 6/100
# 12/12 [==============================] - 16s 1s/step - loss: 4.4937 - acc: 0.3719 - val_loss: 4.7544 - val_acc: 0.3696
# Epoch 7/100
# 12/12 [==============================] - 16s 1s/step - loss: 4.3820 - acc: 0.3866 - val_loss: 4.6934 - val_acc: 0.3972
# Epoch 8/100
# 12/12 [==============================] - 16s 1s/step - loss: 4.4258 - acc: 0.3835 - val_loss: 4.8087 - val_acc: 0.3756
# Epoch 9/100
# 12/12 [==============================] - 16s 1s/step - loss: 4.3703 - acc: 0.3774 - val_loss: 4.7043 - val_acc: 0.3682
# Epoch 10/100
# 12/12 [==============================] - 16s 1s/step - loss: 4.4328 - acc: 0.3526 - val_loss: 4.7371 - val_acc: 0.3959
# Epoch 11/100
# 12/12 [==============================] - 16s 1s/step - loss: 4.4485 - acc: 0.3532 - val_loss: 4.7142 - val_acc: 0.3388
# Epoch 12/100
# 12/12 [==============================] - 16s 1s/step - loss: 4.3975 - acc: 0.3188 - val_loss: 4.7045 - val_acc: 0.3633
# Epoch 13/100
# 12/12 [==============================] - 16s 1s/step - loss: 4.4005 - acc: 0.3249 - val_loss: 4.7374 - val_acc: 0.3405
# Epoch 14/100
# 12/12 [==============================] - 16s 1s/step - loss: 4.4268 - acc: 0.3266 - val_loss: 4.7424 - val_acc: 0.3523
# Epoch 15/100
# 12/12 [==============================] - 16s 1s/step - loss: 4.3917 - acc: 0.3098 - val_loss: 4.7857 - val_acc: 0.3135
# Epoch 16/100
# 12/12 [==============================] - 16s 1s/step - loss: 4.3767 - acc: 0.2873 - val_loss: 4.7443 - val_acc: 0.3374
# Epoch 17/100
# 12/12 [==============================] - 16s 1s/step - loss: 4.3100 - acc: 0.2866 - val_loss: 4.7231 - val_acc: 0.3117
# Epoch 18/100
# 12/12 [==============================] - 16s 1s/step - loss: 4.3714 - acc: 0.2948 - val_loss: 4.7839 - val_acc: 0.3228
# Epoch 19/100
# 12/12 [==============================] - 16s 1s/step - loss: 4.3536 - acc: 0.2999 - val_loss: 4.8929 - val_acc: 0.2827
# Epoch 20/100
# 12/12 [==============================] - 16s 1s/step - loss: 4.3148 - acc: 0.2852 - val_loss: 4.8401 - val_acc: 0.2940
# Epoch 21/100
# 12/12 [==============================] - 16s 1s/step - loss: 4.3082 - acc: 0.2854 - val_loss: 4.7308 - val_acc: 0.3264
# Epoch 22/100
# 12/12 [==============================] - 16s 1s/step - loss: 4.2929 - acc: 0.3044 - val_loss: 4.8705 - val_acc: 0.2962
# Epoch 23/100
# 12/12 [==============================] - 16s 1s/step - loss: 4.2968 - acc: 0.2845 - val_loss: 4.8109 - val_acc: 0.2717
# Epoch 24/100
# 12/12 [==============================] - 16s 1s/step - loss: 4.3010 - acc: 0.2702 - val_loss: 4.8161 - val_acc: 0.2948
# Epoch 25/100
# 12/12 [==============================] - 16s 1s/step - loss: 4.2926 - acc: 0.2972 - val_loss: 4.9528 - val_acc: 0.2330
# Epoch 26/100
# 12/12 [==============================] - 16s 1s/step - loss: 4.3317 - acc: 0.2799 - val_loss: 5.0292 - val_acc: 0.2180
# Epoch 27/100
# 12/12 [==============================] - 16s 1s/step - loss: 4.3749 - acc: 0.2445 - val_loss: 4.9765 - val_acc: 0.2067
# Epoch 28/100
# 12/12 [==============================] - 16s 1s/step - loss: 4.2657 - acc: 0.2289 - val_loss: 4.7177 - val_acc: 0.2876
# Epoch 29/100
# 12/12 [==============================] - 16s 1s/step - loss: 4.3589 - acc: 0.2982 - val_loss: 4.9863 - val_acc: 0.2810
# Epoch 30/100
# 12/12 [==============================] - 16s 1s/step - loss: 4.2645 - acc: 0.2559 - val_loss: 4.9386 - val_acc: 0.2086
# Epoch 31/100
# 12/12 [==============================] - 16s 1s/step - loss: 4.2100 - acc: 0.2760 - val_loss: 4.9742 - val_acc: 0.2958
# Epoch 32/100
# 12/12 [==============================] - 16s 1s/step - loss: 4.2663 - acc: 0.2565 - val_loss: 5.0110 - val_acc: 0.2472
# Epoch 33/100
# 12/12 [==============================] - 16s 1s/step - loss: 4.2437 - acc: 0.2694 - val_loss: 4.9986 - val_acc: 0.2573
# Epoch 34/100
# 12/12 [==============================] - 16s 1s/step - loss: 4.2258 - acc: 0.2667 - val_loss: 4.8704 - val_acc: 0.2437
# Epoch 35/100
# 12/12 [==============================] - 16s 1s/step - loss: 4.1892 - acc: 0.3356 - val_loss: 5.2626 - val_acc: 0.2516
# Epoch 36/100
# 12/12 [==============================] - 16s 1s/step - loss: 4.2125 - acc: 0.2913 - val_loss: 5.0704 - val_acc: 0.2547
# Epoch 37/100
# 12/12 [==============================] - 16s 1s/step - loss: 4.2004 - acc: 0.2828 - val_loss: 4.9828 - val_acc: 0.2141
# Epoch 38/100
# 12/12 [==============================] - 16s 1s/step - loss: 4.1444 - acc: 0.2674 - val_loss: 5.0328 - val_acc: 0.2824
# Epoch 39/100
# 12/12 [==============================] - 16s 1s/step - loss: 4.1241 - acc: 0.3005 - val_loss: 5.0376 - val_acc: 0.2945
# Epoch 40/100
# 12/12 [==============================] - 16s 1s/step - loss: 4.1738 - acc: 0.2837 - val_loss: 4.9050 - val_acc: 0.1979
# Epoch 41/100
# 12/12 [==============================] - 16s 1s/step - loss: 4.1903 - acc: 0.2503 - val_loss: 5.0802 - val_acc: 0.2586
# Epoch 42/100
# 12/12 [==============================] - 16s 1s/step - loss: 4.1277 - acc: 0.3313 - val_loss: 5.0021 - val_acc: 0.2624
# Epoch 43/100
# 12/12 [==============================] - 16s 1s/step - loss: 4.1303 - acc: 0.2316 - val_loss: 4.9492 - val_acc: 0.2269
# Epoch 44/100
# 12/12 [==============================] - 16s 1s/step - loss: 4.0569 - acc: 0.2812 - val_loss: 5.2704 - val_acc: 0.1956
# Epoch 45/100
# 12/12 [==============================] - 16s 1s/step - loss: 4.0712 - acc: 0.2515 - val_loss: 5.0032 - val_acc: 0.2139
# Epoch 46/100
# 12/12 [==============================] - 16s 1s/step - loss: 4.1414 - acc: 0.2851 - val_loss: 5.2833 - val_acc: 0.1886
# Epoch 47/100
# 12/12 [==============================] - 16s 1s/step - loss: 4.0940 - acc: 0.3036 - val_loss: 4.9631 - val_acc: 0.2622
# Epoch 48/100
# 12/12 [==============================] - 16s 1s/step - loss: 4.1007 - acc: 0.3111 - val_loss: 5.2439 - val_acc: 0.2117
# Epoch 49/100
# 12/12 [==============================] - 16s 1s/step - loss: 4.0517 - acc: 0.2658 - val_loss: 5.2128 - val_acc: 0.1942
# Epoch 50/100
# 12/12 [==============================] - 16s 1s/step - loss: 4.0703 - acc: 0.2729 - val_loss: 5.2597 - val_acc: 0.2285
# Epoch 51/100
# 12/12 [==============================] - 16s 1s/step - loss: 4.0415 - acc: 0.2999 - val_loss: 5.3220 - val_acc: 0.1753
# Epoch 52/100
# 12/12 [==============================] - 16s 1s/step - loss: 4.0409 - acc: 0.3015 - val_loss: 5.1339 - val_acc: 0.2526
# Epoch 53/100
# 12/12 [==============================] - 16s 1s/step - loss: 4.0245 - acc: 0.2976 - val_loss: 5.2214 - val_acc: 0.2158
# Epoch 54/100
# 12/12 [==============================] - 16s 1s/step - loss: 4.0702 - acc: 0.2465 - val_loss: 5.2754 - val_acc: 0.1504
# Epoch 55/100
# 12/12 [==============================] - 16s 1s/step - loss: 4.0649 - acc: 0.2672 - val_loss: 5.1927 - val_acc: 0.1802
# Epoch 56/100
# 12/12 [==============================] - 16s 1s/step - loss: 4.1111 - acc: 0.2874 - val_loss: 5.1760 - val_acc: 0.2099
# Epoch 57/100
# 12/12 [==============================] - 16s 1s/step - loss: 3.9735 - acc: 0.2716 - val_loss: 5.1157 - val_acc: 0.2222
# Epoch 58/100
# 12/12 [==============================] - 16s 1s/step - loss: 4.0596 - acc: 0.3111 - val_loss: 5.1241 - val_acc: 0.2005
# Epoch 59/100
# 12/12 [==============================] - 16s 1s/step - loss: 3.9842 - acc: 0.3065 - val_loss: 5.2979 - val_acc: 0.2347
# Epoch 60/100
# 12/12 [==============================] - 16s 1s/step - loss: 3.9925 - acc: 0.2675 - val_loss: 5.5275 - val_acc: 0.1899
# Epoch 61/100
# 12/12 [==============================] - 16s 1s/step - loss: 4.0444 - acc: 0.2886 - val_loss: 5.2886 - val_acc: 0.1942
# Epoch 62/100
# 12/12 [==============================] - 16s 1s/step - loss: 3.9616 - acc: 0.3166 - val_loss: 5.1239 - val_acc: 0.2128
# Epoch 63/100
# 12/12 [==============================] - 16s 1s/step - loss: 3.9523 - acc: 0.3127 - val_loss: 5.4199 - val_acc: 0.2779
# Epoch 64/100
# 12/12 [==============================] - 16s 1s/step - loss: 3.9619 - acc: 0.3125 - val_loss: 5.2654 - val_acc: 0.2033
# Epoch 65/100
# 12/12 [==============================] - 16s 1s/step - loss: 3.9016 - acc: 0.2984 - val_loss: 5.4279 - val_acc: 0.1913
# Epoch 66/100
# 12/12 [==============================] - 16s 1s/step - loss: 3.9356 - acc: 0.2758 - val_loss: 5.4843 - val_acc: 0.1734
# Epoch 67/100
# 12/12 [==============================] - 16s 1s/step - loss: 3.8474 - acc: 0.3044 - val_loss: 5.6342 - val_acc: 0.2238
# Epoch 68/100
# 12/12 [==============================] - 16s 1s/step - loss: 3.8790 - acc: 0.3018 - val_loss: 5.4270 - val_acc: 0.2150
# Epoch 69/100
# 12/12 [==============================] - 16s 1s/step - loss: 3.8787 - acc: 0.3281 - val_loss: 5.4260 - val_acc: 0.2008
# Epoch 70/100
# 12/12 [==============================] - 16s 1s/step - loss: 3.9173 - acc: 0.2897 - val_loss: 5.3692 - val_acc: 0.2051
# Epoch 71/100
# 12/12 [==============================] - 16s 1s/step - loss: 3.9142 - acc: 0.3191 - val_loss: 5.4073 - val_acc: 0.1614
# Epoch 72/100
# 12/12 [==============================] - 16s 1s/step - loss: 3.8647 - acc: 0.2768 - val_loss: 5.3481 - val_acc: 0.1665
# Epoch 73/100
# 12/12 [==============================] - 16s 1s/step - loss: 3.8502 - acc: 0.3009 - val_loss: 5.3371 - val_acc: 0.2193
# Epoch 74/100
# 12/12 [==============================] - 16s 1s/step - loss: 3.9092 - acc: 0.3350 - val_loss: 5.7160 - val_acc: 0.2024
# Epoch 75/100
# 12/12 [==============================] - 16s 1s/step - loss: 3.8936 - acc: 0.3173 - val_loss: 5.4736 - val_acc: 0.1543
# Epoch 76/100
# 12/12 [==============================] - 16s 1s/step - loss: 3.8728 - acc: 0.2830 - val_loss: 5.5137 - val_acc: 0.2380
# Epoch 77/100
# 12/12 [==============================] - 16s 1s/step - loss: 3.7981 - acc: 0.3305 - val_loss: 5.4876 - val_acc: 0.1564
# Epoch 78/100
# 12/12 [==============================] - 16s 1s/step - loss: 3.8430 - acc: 0.2944 - val_loss: 5.5071 - val_acc: 0.2695
# Epoch 79/100
# 12/12 [==============================] - 16s 1s/step - loss: 3.8311 - acc: 0.3255 - val_loss: 5.2648 - val_acc: 0.1893
# Epoch 80/100
# 12/12 [==============================] - 16s 1s/step - loss: 3.8641 - acc: 0.3022 - val_loss: 5.5099 - val_acc: 0.2239
# Epoch 81/100
# 12/12 [==============================] - 16s 1s/step - loss: 3.8715 - acc: 0.2792 - val_loss: 5.7032 - val_acc: 0.2211
# Epoch 82/100
# 12/12 [==============================] - 16s 1s/step - loss: 3.8391 - acc: 0.3089 - val_loss: 5.3468 - val_acc: 0.1976
# Epoch 83/100
# 12/12 [==============================] - 16s 1s/step - loss: 3.8489 - acc: 0.3205 - val_loss: 5.6962 - val_acc: 0.2024
# Epoch 84/100
# 12/12 [==============================] - 16s 1s/step - loss: 3.8617 - acc: 0.3156 - val_loss: 5.7855 - val_acc: 0.2082
# Epoch 85/100
# 12/12 [==============================] - 16s 1s/step - loss: 3.8560 - acc: 0.3118 - val_loss: 5.4787 - val_acc: 0.2030
# Epoch 86/100
# 12/12 [==============================] - 16s 1s/step - loss: 3.8221 - acc: 0.2994 - val_loss: 5.5244 - val_acc: 0.1476
# Epoch 87/100
# 12/12 [==============================] - 16s 1s/step - loss: 3.8532 - acc: 0.3095 - val_loss: 5.3168 - val_acc: 0.1812
# Epoch 88/100
# 12/12 [==============================] - 16s 1s/step - loss: 3.8100 - acc: 0.2854 - val_loss: 5.6229 - val_acc: 0.2096
# Epoch 89/100
# 12/12 [==============================] - 16s 1s/step - loss: 3.8351 - acc: 0.2881 - val_loss: 5.6619 - val_acc: 0.1724
# Epoch 90/100
# 12/12 [==============================] - 16s 1s/step - loss: 3.7775 - acc: 0.2919 - val_loss: 5.4929 - val_acc: 0.1724
# Epoch 91/100
# 12/12 [==============================] - 16s 1s/step - loss: 3.7755 - acc: 0.3509 - val_loss: 5.5638 - val_acc: 0.2032
# Epoch 92/100
# 12/12 [==============================] - 16s 1s/step - loss: 3.7942 - acc: 0.2906 - val_loss: 5.4416 - val_acc: 0.1843
# Epoch 93/100
# 12/12 [==============================] - 16s 1s/step - loss: 3.8093 - acc: 0.3079 - val_loss: 5.6579 - val_acc: 0.1890
# Epoch 94/100
# 12/12 [==============================] - 16s 1s/step - loss: 3.7255 - acc: 0.2857 - val_loss: 5.7941 - val_acc: 0.1532
# Epoch 95/100
# 12/12 [==============================] - 16s 1s/step - loss: 3.7619 - acc: 0.2993 - val_loss: 5.6907 - val_acc: 0.2005
# Epoch 96/100
# 12/12 [==============================] - 16s 1s/step - loss: 3.7801 - acc: 0.3212 - val_loss: 5.7069 - val_acc: 0.2230
# Epoch 97/100
# 12/12 [==============================] - 16s 1s/step - loss: 3.7518 - acc: 0.3108 - val_loss: 5.8007 - val_acc: 0.1718
# Epoch 98/100
# 12/12 [==============================] - 16s 1s/step - loss: 3.7300 - acc: 0.3089 - val_loss: 5.7772 - val_acc: 0.1704
# Epoch 99/100
# 12/12 [==============================] - 16s 1s/step - loss: 3.7455 - acc: 0.3289 - val_loss: 5.8599 - val_acc: 0.2036
# Epoch 100/100
# 12/12 [==============================] - 16s 1s/step - loss: 3.7379 - acc: 0.3187 - val_loss: 5.6452 - val_acc: 0.2490
# Train time: 26m

# %%
plt.figure(figsize=(15,5))
plt.subplot(1,2,1)
plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.legend(['loss','val_loss'])
plt.grid()
plt.subplot(1,2,2)
plt.plot(hist.history['acc'])
plt.plot(hist.history['val_acc'])
plt.legend(['acc','val_acc'])
plt.grid()

# %%
history = []
history.append(hist.history['loss'])
history.append(hist.history['val_loss'])
history.append(hist.history['acc'])
history.append(hist.history['val_acc'])
history = np.array(history)
np.savetxt(model_name+"_"+dir_name+"_history.txt", history, delimiter=",")

# %%
model_json = model.to_json()
with open(model_name+"_"+dir_name+".json", "w") as json_file:
    json_file.write(model_json)
model.save_weights(model_name+"_"+dir_name+".h5")

# %%
from keras.models import model_from_json

# %%
json_file = open(model_name+"_"+dir_name+".json", "r")
loaded_model_json = json_file.read()
json_file.close()
loaded_model = model_from_json(loaded_model_json)
# load weights into new model
loaded_model.load_weights(model_name+"_"+dir_name+".h5")

# %%
# result on train images
X,Y = generator(batch_size, train_dir, H, W).__next__()
Yhat = model.predict(X)
j =1
plt.figure(figsize=(20,20))
for i in range(12):
    # original
    plt.subplot(6,8,j)
    j+=1
    img = XY2img(X[i],Y[i])
    plt.imshow(img)
    plt.axis('OFF')
    # grayscale
    plt.subplot(6,8,j)
    j+=1
    plt.imshow(X[i,:,:,0],'gray')
    plt.axis('OFF')
    # predict
    plt.subplot(6,8,j)
    j += 1
    img = XY2img(X[i],Yhat[i])
    plt.imshow(img)
    plt.axis('OFF')
    # predict
    plt.subplot(6,8,j)
    j += 1
    img = XY2imgf(X[i],Yhat[i])
    plt.imshow(img)
    plt.axis('OFF')
# Out:
# /home/tking/.local/lib/python3.5/site-packages/ipykernel_launcher.py:9: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.
#   if __name__ == '__main__':

# %%
# result on test images
X,Y = generator(batch_size, test_dir, H, W).__next__()
Yhat = model.predict(X)
j =1
plt.figure(figsize=(20,20))
for i in range(12):
    # original
    plt.subplot(6,8,j)
    j+=1
    img = XY2img(X[i],Y[i])
    plt.imshow(img)
    plt.axis('OFF')
    # grayscale
    plt.subplot(6,8,j)
    j+=1
    plt.imshow(X[i,:,:,0],'gray')
    plt.axis('OFF')
    # predict
    plt.subplot(6,8,j)
    j += 1
    img = XY2img(X[i],Yhat[i])
    plt.imshow(img)
    plt.axis('OFF')
    # predict
    plt.subplot(6,8,j)
    j += 1
    img = XY2imgf(X[i],Yhat[i])
    plt.imshow(img)
    plt.axis('OFF')
# Out:
# /home/tking/.local/lib/python3.5/site-packages/ipykernel_launcher.py:9: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.
#   if __name__ == '__main__':

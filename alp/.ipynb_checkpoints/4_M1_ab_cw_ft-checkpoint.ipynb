# %%
from keras.layers import Conv2D, UpSampling2D, InputLayer, Conv2DTranspose
from keras.layers import Activation, Dense, Dropout, Flatten
from keras.layers.normalization import BatchNormalization
from keras.models import Sequential
from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img
from skimage.color import rgb2lab, lab2rgb, rgb2gray, xyz2lab
from skimage.io import imsave
import numpy as np
import os
import random
import tensorflow as tf
from time import time

import cv2

from scipy.misc import imresize
from skimage.transform import resize

import glob

import matplotlib.pyplot as plt
# %matplotlib inline

from keras.callbacks import EarlyStopping
from keras.utils import to_categorical
import random
from keras import optimizers
from scipy.ndimage import filters
# Out:
# /home/tking/.local/lib/python3.5/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
#define parameters:
dir_name = "alp" # Variable
model_name = "4_M1_ab_cw_ft"# Variable

train_dir = r"../../images/"+dir_name+"/train/*.jpg"
test_dir = r"../../images/"+dir_name+"/test/*.jpg"
H = 64
W = 64
batch_size = 32

# %%
# select vaild images and put into train and test dir (only run once) 
# i = 0
# num_tr = 2000
# num_ts = 500
# for img in glob.glob(r"../../images/"+dir_name+"/*.jpg"):
#     try:
#         n= cv2.imread(img)#BGR
#         if  n is None or np.mean(n)>250 or np.mean(np.std(n,axis=2))<2:
#             os.remove(img)
#         else:
#             if i<num_tr:
#                 i+=1
#                 os.rename(img,r"../../images/"+dir_name+"/train/"+str(i)+".jpg")
#             elif i>=num_tr and i<num_tr+num_ts:
#                 i+=1
#                 os.rename(img,r"../../images/"+dir_name+"/test/"+str(i)+".jpg")
#             else:
#                 break
#     except:
#         pass
print('tr_size = ',len(glob.glob(train_dir)))
print('ts_size = ',len(glob.glob(test_dir)))
# Out:
# tr_size =  400
# ts_size =  200

# %%
def generator(batch_size, dir_path, H, W):
    while True:
        X = []
        Y = []
        img_batch = random.sample(glob.glob(dir_path), batch_size)
        for img in img_batch:
            # choose random index in features
            n= cv2.imread(img)#BGR
            m = imresize(n,(H,W,3))
            img_lab = cv2.cvtColor(m.astype(np.uint8), cv2.COLOR_BGR2LAB)
            L = img_lab[:,:,0].reshape(1,H,W,1)
            y = np.floor(img_lab[:,:,1:]/16)

            # to_categorical
            y0=y[:,:,0].flatten()
            y1=y[:,:,1].flatten()
            Yc2d0 = to_categorical(y0, num_classes = 16 )
            Yc3d0 = Yc2d0.reshape(H,W,16)
            Yc2d1 = to_categorical(y1, num_classes = 16 )
            Yc3d1 = Yc2d1.reshape(H,W,16)
            Yc3d = np.zeros((H,W,32))
            Yc3d[:,:,:16] = Yc3d0
            Yc3d[:,:,16:] = Yc3d1

            Y.append(Yc3d)
            X.append(L)
        X=np.array(X)
        Y=np.array(Y)
        X=np.reshape(X, (batch_size, H, W, 1))
        Y=np.reshape(Y, (batch_size, H, W, 32))
        yield X, Y

# %%
def XY2img(X,Y):
    H, W, _ = X.shape
    img_lab = np.zeros((H,W,3))
    img_lab[:,:,0] = X[:,:,0]
    img_lab[:,:,1] = np.argmax(Y[:,:,:16],axis=2)*16+8
    img_lab[:,:,2] = np.argmax(Y[:,:,16:],axis=2)*16+8
    img = cv2.cvtColor(img_lab.astype(np.uint8), cv2.COLOR_LAB2RGB)
    return img

# %%
def XY2imgf(X,Y):
    H, W, _ = X.shape
    img_lab = np.zeros((H,W,3))
    img_lab[:,:,0] = X[:,:,0]
    img_lab[:,:,1] = filters.gaussian_filter(np.argmax(Y[:,:,:16],axis=2)*16+8,5)
    img_lab[:,:,2] = filters.gaussian_filter(np.argmax(Y[:,:,16:],axis=2)*16+8,5)
    img = cv2.cvtColor(img_lab.astype(np.uint8), cv2.COLOR_LAB2RGB)
    return img

# %%
# show some images
plt.figure(figsize=(15,5))
X,Y = generator(batch_size, train_dir, H, W).__next__()    
for i in range(8):
    plt.subplot(1,8,i+1)
    img = XY2img(X[i],Y[i])
    plt.imshow(img)
    plt.axis('off')
# Out:
# /home/tking/.local/lib/python3.5/site-packages/ipykernel_launcher.py:9: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.
#   if __name__ == '__main__':

# %%
# read images to compute class_weight
Y = []
img_sample = random.sample(glob.glob(train_dir), 400)#save memory
for img in img_sample:
    n= cv2.imread(img)#BGR
    m = imresize(n,(H,W,3))
    img_lab = cv2.cvtColor(m.astype(np.uint8), cv2.COLOR_BGR2LAB)
    y = np.floor(img_lab[:,:,1:]/16)
    
    # to_categorical
    y0=y[:,:,0].flatten()
    y1=y[:,:,1].flatten()
    yc2d0 = to_categorical(y0, num_classes = 16 )
    yc3d0 = yc2d0.reshape(H,W,16)
    yc2d1 = to_categorical(y1, num_classes = 16 )
    yc3d1 = yc2d1.reshape(H,W,16)
    yc3d = np.zeros((H,W,32))
    yc3d[:,:,:16] = yc3d0
    yc3d[:,:,16:] = yc3d1
    Y.append(yc3d)
num = len(Y)
Y=np.array(Y)
Y=np.reshape(Y, (num, H, W, 32))
# Out:
# /home/tking/.local/lib/python3.5/site-packages/ipykernel_launcher.py:6: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.

# %%
# compute class_weight
from sklearn.utils import class_weight
Yflat16A = Y[:,:,:,:16].reshape(num*H*W,16)
YflatA = np.argmax(Yflat16A,axis=1)
YclassA = np.unique(YflatA)
class_weight_A = class_weight.compute_class_weight('balanced',
                                                 YclassA,
                                                 YflatA)
Yflat16B = Y[:,:,:,16:].reshape(num*H*W,16)
YflatB = np.argmax(Yflat16B,axis=1)
YclassB = np.unique(YflatB)
class_weight_B = class_weight.compute_class_weight('balanced',
                                                 YclassB,
                                                 YflatB)

class_weight = np.zeros(32)
for i in range(len(YclassA)):
    class_weight[YclassA[i]]=class_weight_A[i]
for i in range(len(YclassB)):
    class_weight[YclassB[i]+16]=class_weight_B[i]

plt.stem(class_weight)
plt.yscale('log')
plt.ylabel('class_weight')
plt.xlabel('classes')
# Out:
# Text(0.5,0,'classes')

# %%
# Building the neural network
import keras.backend as K
K.clear_session()
model = Sequential()
model.add(InputLayer(input_shape=(None, None, 1)))
model.add(Conv2D(8, (3, 3), activation='relu', padding='same', strides=2))
model.add(Conv2D(8, (3, 3), activation='relu', padding='same'))
model.add(Conv2D(16, (3, 3), activation='relu', padding='same'))
model.add(Conv2D(16, (3, 3), activation='relu', padding='same', strides=2))
model.add(Conv2D(32, (3, 3), activation='relu', padding='same'))
model.add(Conv2D(32, (3, 3), activation='relu', padding='same', strides=2))
model.add(Conv2DTranspose(32, (2,2), strides=2, padding='same', activation='relu'))
model.add(Conv2D(32, (3, 3), activation='relu', padding='same'))
model.add(Conv2DTranspose(32, (2,2), strides=2, padding='same', activation='relu'))
model.add(Conv2D(16, (3, 3), activation='relu', padding='same'))
model.add(Conv2DTranspose(32, (2,2), strides=2, padding='same', activation='relu'))
model.add(Conv2D(32, (3, 3), activation='sigmoid', padding='same'))#TODO
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, None, None, 1)     0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, None, None, 8)     80
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, None, None, 8)     584
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, None, None, 16)    1168
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, None, None, 16)    2320
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, None, None, 32)    4640
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, None, None, 32)    9248
# _________________________________________________________________
# conv2d_transpose_1 (Conv2DTr (None, None, None, 32)    4128
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, None, None, 32)    9248
# _________________________________________________________________
# conv2d_transpose_2 (Conv2DTr (None, None, None, 32)    4128
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, None, None, 16)    4624
# _________________________________________________________________
# conv2d_transpose_3 (Conv2DTr (None, None, None, 32)    2080
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, None, None, 32)    9248
# =================================================================
# Total params: 51,496
# Trainable params: 51,496
# Non-trainable params: 0
# _________________________________________________________________

# %%
# compile model
opt = optimizers.Adam(lr=0.001)
model.compile(optimizer=opt,
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %%
train_generator = generator(batch_size, train_dir, H, W)
test_generator = generator(batch_size, test_dir, H, W)
tr_size = len(glob.glob(train_dir))
ts_size = len(glob.glob(test_dir))
steps_per_epoch = tr_size// batch_size
validation_steps = ts_size // batch_size
print(tr_size,ts_size,steps_per_epoch,validation_steps)
# Out:
# 400 200 12 6

# %%
t0 = time()
hist = model.fit_generator(train_generator,
                            steps_per_epoch=steps_per_epoch,
                            epochs=100,
                            validation_data=test_generator,
                            validation_steps=validation_steps,
                            class_weight=class_weight,
                            verbose=1)
print('Train time: %.fm'%((time()-t0)/60))
# Out:
# Epoch 1/100
# /home/tking/.local/lib/python3.5/site-packages/ipykernel_launcher.py:9: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.
#   if __name__ == '__main__':
# 12/12 [==============================] - 4s 332ms/step - loss: 6.2189 - acc: 0.1622 - val_loss: 4.8695 - val_acc: 0.2781
# Epoch 2/100
# 12/12 [==============================] - 2s 176ms/step - loss: 4.4171 - acc: 0.3112 - val_loss: 4.2065 - val_acc: 0.3385
# Epoch 3/100
# 12/12 [==============================] - 3s 225ms/step - loss: 4.1295 - acc: 0.3279 - val_loss: 4.0291 - val_acc: 0.3388
# Epoch 4/100
# 12/12 [==============================] - 3s 218ms/step - loss: 4.0587 - acc: 0.3473 - val_loss: 4.0345 - val_acc: 0.3865
# Epoch 5/100
# 12/12 [==============================] - 2s 188ms/step - loss: 3.9803 - acc: 0.4040 - val_loss: 3.9241 - val_acc: 0.4225
# Epoch 6/100
# 12/12 [==============================] - 2s 207ms/step - loss: 3.9410 - acc: 0.3965 - val_loss: 3.9403 - val_acc: 0.4323
# Epoch 7/100
# 12/12 [==============================] - 3s 228ms/step - loss: 3.9526 - acc: 0.4332 - val_loss: 4.0078 - val_acc: 0.4480
# Epoch 8/100
# 12/12 [==============================] - 2s 191ms/step - loss: 3.9159 - acc: 0.4585 - val_loss: 3.8486 - val_acc: 0.4690
# Epoch 9/100
# 12/12 [==============================] - 2s 180ms/step - loss: 3.8191 - acc: 0.4691 - val_loss: 4.0184 - val_acc: 0.4607
# Epoch 10/100
# 12/12 [==============================] - 3s 262ms/step - loss: 3.8620 - acc: 0.4666 - val_loss: 3.9391 - val_acc: 0.4682
# Epoch 11/100
# 12/12 [==============================] - 3s 246ms/step - loss: 3.9066 - acc: 0.4841 - val_loss: 3.9110 - val_acc: 0.4660
# Epoch 12/100
# 12/12 [==============================] - 3s 214ms/step - loss: 3.8638 - acc: 0.4755 - val_loss: 3.8579 - val_acc: 0.4652
# Epoch 13/100
# 12/12 [==============================] - 2s 208ms/step - loss: 3.7945 - acc: 0.4810 - val_loss: 3.9274 - val_acc: 0.4640
# Epoch 14/100
# 12/12 [==============================] - 3s 219ms/step - loss: 3.7937 - acc: 0.4834 - val_loss: 3.8327 - val_acc: 0.4584
# Epoch 15/100
# 12/12 [==============================] - 3s 214ms/step - loss: 3.8498 - acc: 0.4881 - val_loss: 3.8634 - val_acc: 0.4678
# Epoch 16/100
# 12/12 [==============================] - 3s 251ms/step - loss: 3.8144 - acc: 0.4845 - val_loss: 3.8597 - val_acc: 0.4373
# Epoch 17/100
# 12/12 [==============================] - 3s 249ms/step - loss: 3.8160 - acc: 0.4907 - val_loss: 3.8673 - val_acc: 0.4765
# Epoch 18/100
# 12/12 [==============================] - 2s 167ms/step - loss: 3.9076 - acc: 0.4617 - val_loss: 3.8470 - val_acc: 0.4837
# Epoch 19/100
# 12/12 [==============================] - 3s 238ms/step - loss: 3.7471 - acc: 0.4783 - val_loss: 3.8311 - val_acc: 0.4715
# Epoch 20/100
# 12/12 [==============================] - 3s 264ms/step - loss: 3.7438 - acc: 0.5029 - val_loss: 3.8772 - val_acc: 0.4497
# Epoch 21/100
# 12/12 [==============================] - 3s 253ms/step - loss: 3.7005 - acc: 0.4935 - val_loss: 3.7710 - val_acc: 0.4717
# Epoch 22/100
# 12/12 [==============================] - 2s 189ms/step - loss: 3.7208 - acc: 0.5066 - val_loss: 3.8459 - val_acc: 0.4353
# Epoch 23/100
# 12/12 [==============================] - 3s 224ms/step - loss: 3.7814 - acc: 0.4966 - val_loss: 3.8583 - val_acc: 0.4391
# Epoch 24/100
# 12/12 [==============================] - 2s 198ms/step - loss: 3.7421 - acc: 0.4995 - val_loss: 3.7733 - val_acc: 0.4589
# Epoch 25/100
# 12/12 [==============================] - 3s 250ms/step - loss: 3.7238 - acc: 0.4932 - val_loss: 3.7869 - val_acc: 0.4492
# Epoch 26/100
# 12/12 [==============================] - 2s 187ms/step - loss: 3.7009 - acc: 0.4890 - val_loss: 3.7835 - val_acc: 0.4335
# Epoch 27/100
# 12/12 [==============================] - 3s 238ms/step - loss: 3.7491 - acc: 0.5058 - val_loss: 3.6706 - val_acc: 0.4626
# Epoch 28/100
# 12/12 [==============================] - 3s 215ms/step - loss: 3.7322 - acc: 0.5035 - val_loss: 3.7505 - val_acc: 0.4587
# Epoch 29/100
# 12/12 [==============================] - 2s 208ms/step - loss: 3.7238 - acc: 0.5142 - val_loss: 3.8174 - val_acc: 0.4483
# Epoch 30/100
# 12/12 [==============================] - 3s 272ms/step - loss: 3.7105 - acc: 0.4955 - val_loss: 3.7048 - val_acc: 0.4269
# Epoch 31/100
# 12/12 [==============================] - 2s 193ms/step - loss: 3.7194 - acc: 0.4879 - val_loss: 3.7139 - val_acc: 0.4419
# Epoch 32/100
# 12/12 [==============================] - 3s 231ms/step - loss: 3.7421 - acc: 0.5012 - val_loss: 3.7098 - val_acc: 0.4601
# Epoch 33/100
# 12/12 [==============================] - 3s 230ms/step - loss: 3.7130 - acc: 0.4883 - val_loss: 3.7153 - val_acc: 0.4678
# Epoch 34/100
# 12/12 [==============================] - 3s 210ms/step - loss: 3.6693 - acc: 0.4750 - val_loss: 3.7033 - val_acc: 0.4280
# Epoch 35/100
# 12/12 [==============================] - 2s 202ms/step - loss: 3.6786 - acc: 0.5155 - val_loss: 3.8061 - val_acc: 0.4290
# Epoch 36/100
# 12/12 [==============================] - 2s 197ms/step - loss: 3.7016 - acc: 0.5069 - val_loss: 3.7415 - val_acc: 0.4364
# Epoch 37/100
# 12/12 [==============================] - 3s 226ms/step - loss: 3.6355 - acc: 0.5021 - val_loss: 3.7041 - val_acc: 0.4276
# Epoch 38/100
# 12/12 [==============================] - 3s 236ms/step - loss: 3.6749 - acc: 0.4808 - val_loss: 3.8164 - val_acc: 0.4587
# Epoch 39/100
# 12/12 [==============================] - 3s 233ms/step - loss: 3.6858 - acc: 0.4472 - val_loss: 3.7221 - val_acc: 0.4209
# Epoch 40/100
# 12/12 [==============================] - 2s 200ms/step - loss: 3.7094 - acc: 0.5176 - val_loss: 3.8137 - val_acc: 0.4319
# Epoch 41/100
# 12/12 [==============================] - 3s 259ms/step - loss: 3.6722 - acc: 0.5014 - val_loss: 3.7253 - val_acc: 0.4563
# Epoch 42/100
# 12/12 [==============================] - 3s 215ms/step - loss: 3.6459 - acc: 0.4824 - val_loss: 3.7129 - val_acc: 0.4194
# Epoch 43/100
# 12/12 [==============================] - 3s 254ms/step - loss: 3.6616 - acc: 0.5028 - val_loss: 3.6969 - val_acc: 0.4720
# Epoch 44/100
# 12/12 [==============================] - 3s 239ms/step - loss: 3.6608 - acc: 0.4956 - val_loss: 3.7581 - val_acc: 0.4566
# Epoch 45/100
# 12/12 [==============================] - 3s 272ms/step - loss: 3.6375 - acc: 0.4807 - val_loss: 3.6830 - val_acc: 0.4652
# Epoch 46/100
# 12/12 [==============================] - 3s 251ms/step - loss: 3.6648 - acc: 0.5039 - val_loss: 3.8101 - val_acc: 0.4102
# Epoch 47/100
# 12/12 [==============================] - 3s 211ms/step - loss: 3.5644 - acc: 0.5295 - val_loss: 3.7385 - val_acc: 0.4410
# Epoch 48/100
# 12/12 [==============================] - 3s 244ms/step - loss: 3.7093 - acc: 0.4804 - val_loss: 3.6895 - val_acc: 0.4602
# Epoch 49/100
# 12/12 [==============================] - 3s 210ms/step - loss: 3.6232 - acc: 0.4952 - val_loss: 3.7021 - val_acc: 0.4413
# Epoch 50/100
# 12/12 [==============================] - 3s 222ms/step - loss: 3.5986 - acc: 0.4794 - val_loss: 3.6650 - val_acc: 0.4388
# Epoch 51/100
# 12/12 [==============================] - 3s 282ms/step - loss: 3.5950 - acc: 0.4895 - val_loss: 3.6426 - val_acc: 0.4556
# Epoch 52/100
# 12/12 [==============================] - 3s 214ms/step - loss: 3.6559 - acc: 0.4877 - val_loss: 3.7124 - val_acc: 0.4719
# Epoch 53/100
# 12/12 [==============================] - 2s 205ms/step - loss: 3.6321 - acc: 0.5203 - val_loss: 3.6638 - val_acc: 0.4492
# Epoch 54/100
# 12/12 [==============================] - 2s 195ms/step - loss: 3.6106 - acc: 0.4967 - val_loss: 3.6571 - val_acc: 0.4544
# Epoch 55/100
# 12/12 [==============================] - 3s 225ms/step - loss: 3.5454 - acc: 0.4947 - val_loss: 3.6962 - val_acc: 0.4263
# Epoch 56/100
# 12/12 [==============================] - 3s 232ms/step - loss: 3.6289 - acc: 0.4913 - val_loss: 3.6701 - val_acc: 0.4258
# Epoch 57/100
# 12/12 [==============================] - 3s 227ms/step - loss: 3.5597 - acc: 0.4809 - val_loss: 3.7132 - val_acc: 0.4388
# Epoch 58/100
# 12/12 [==============================] - 2s 189ms/step - loss: 3.5667 - acc: 0.4787 - val_loss: 3.6104 - val_acc: 0.4707
# Epoch 59/100
# 12/12 [==============================] - 3s 275ms/step - loss: 3.6060 - acc: 0.5055 - val_loss: 3.6318 - val_acc: 0.4730
# Epoch 60/100
# 12/12 [==============================] - 3s 235ms/step - loss: 3.5751 - acc: 0.4932 - val_loss: 3.6670 - val_acc: 0.4460
# Epoch 61/100
# 12/12 [==============================] - 3s 240ms/step - loss: 3.5616 - acc: 0.5036 - val_loss: 3.6548 - val_acc: 0.4535
# Epoch 62/100
# 12/12 [==============================] - 3s 269ms/step - loss: 3.5766 - acc: 0.5184 - val_loss: 3.6085 - val_acc: 0.4282
# Epoch 63/100
# 12/12 [==============================] - 2s 177ms/step - loss: 3.5598 - acc: 0.4987 - val_loss: 3.6406 - val_acc: 0.4487
# Epoch 64/100
# 12/12 [==============================] - 3s 251ms/step - loss: 3.5749 - acc: 0.5192 - val_loss: 3.7851 - val_acc: 0.4566
# Epoch 65/100
# 12/12 [==============================] - 3s 235ms/step - loss: 3.6166 - acc: 0.4781 - val_loss: 3.7132 - val_acc: 0.4403
# Epoch 66/100
# 12/12 [==============================] - 2s 194ms/step - loss: 3.5469 - acc: 0.4962 - val_loss: 3.6667 - val_acc: 0.4577
# Epoch 67/100
# 12/12 [==============================] - 2s 196ms/step - loss: 3.5581 - acc: 0.4757 - val_loss: 3.6254 - val_acc: 0.4423
# Epoch 68/100
# 12/12 [==============================] - 3s 216ms/step - loss: 3.5152 - acc: 0.4933 - val_loss: 3.7475 - val_acc: 0.4354
# Epoch 69/100
# 12/12 [==============================] - 3s 242ms/step - loss: 3.5354 - acc: 0.4900 - val_loss: 3.7434 - val_acc: 0.4556
# Epoch 70/100
# 12/12 [==============================] - 3s 216ms/step - loss: 3.5602 - acc: 0.4785 - val_loss: 3.6692 - val_acc: 0.4560
# Epoch 71/100
# 12/12 [==============================] - 2s 206ms/step - loss: 3.4991 - acc: 0.4911 - val_loss: 3.6637 - val_acc: 0.4522
# Epoch 72/100
# 12/12 [==============================] - 3s 231ms/step - loss: 3.5509 - acc: 0.4894 - val_loss: 3.7015 - val_acc: 0.4605
# Epoch 73/100
# 12/12 [==============================] - 2s 205ms/step - loss: 3.5475 - acc: 0.4742 - val_loss: 3.7669 - val_acc: 0.4708
# Epoch 74/100
# 12/12 [==============================] - 2s 173ms/step - loss: 3.5208 - acc: 0.4990 - val_loss: 3.7465 - val_acc: 0.4424
# Epoch 75/100
# 12/12 [==============================] - 3s 240ms/step - loss: 3.5015 - acc: 0.4911 - val_loss: 3.6953 - val_acc: 0.4803
# Epoch 76/100
# 12/12 [==============================] - 3s 233ms/step - loss: 3.4887 - acc: 0.4904 - val_loss: 3.6920 - val_acc: 0.4632
# Epoch 77/100
# 12/12 [==============================] - 2s 197ms/step - loss: 3.5336 - acc: 0.4762 - val_loss: 3.7524 - val_acc: 0.4728
# Epoch 78/100
# 12/12 [==============================] - 2s 203ms/step - loss: 3.5191 - acc: 0.4793 - val_loss: 3.6747 - val_acc: 0.4887
# Epoch 79/100
# 12/12 [==============================] - 2s 206ms/step - loss: 3.4744 - acc: 0.4846 - val_loss: 3.6392 - val_acc: 0.4805
# Epoch 80/100
# 12/12 [==============================] - 3s 232ms/step - loss: 3.5115 - acc: 0.4821 - val_loss: 3.7498 - val_acc: 0.4735
# Epoch 81/100
# 12/12 [==============================] - 3s 257ms/step - loss: 3.5093 - acc: 0.4937 - val_loss: 3.7318 - val_acc: 0.4708
# Epoch 82/100
# 12/12 [==============================] - 3s 257ms/step - loss: 3.4770 - acc: 0.4819 - val_loss: 3.6565 - val_acc: 0.4699
# Epoch 83/100
# 12/12 [==============================] - 3s 215ms/step - loss: 3.4500 - acc: 0.4618 - val_loss: 3.7875 - val_acc: 0.4940
# Epoch 84/100
# 12/12 [==============================] - 2s 175ms/step - loss: 3.4763 - acc: 0.4845 - val_loss: 3.6965 - val_acc: 0.4641
# Epoch 85/100
# 12/12 [==============================] - 3s 238ms/step - loss: 3.4929 - acc: 0.4964 - val_loss: 3.7402 - val_acc: 0.4638
# Epoch 86/100
# 12/12 [==============================] - 3s 236ms/step - loss: 3.4620 - acc: 0.5080 - val_loss: 3.6346 - val_acc: 0.4967
# Epoch 87/100
# 12/12 [==============================] - 2s 198ms/step - loss: 3.4578 - acc: 0.4830 - val_loss: 3.6968 - val_acc: 0.4877
# Epoch 88/100
# 12/12 [==============================] - 2s 178ms/step - loss: 3.4637 - acc: 0.4869 - val_loss: 3.7024 - val_acc: 0.4856
# Epoch 89/100
# 12/12 [==============================] - 2s 205ms/step - loss: 3.4696 - acc: 0.4863 - val_loss: 3.7074 - val_acc: 0.5000
# Epoch 90/100
# 12/12 [==============================] - 3s 226ms/step - loss: 3.4704 - acc: 0.4936 - val_loss: 3.7222 - val_acc: 0.5077
# Epoch 91/100
# 12/12 [==============================] - 2s 163ms/step - loss: 3.3860 - acc: 0.4774 - val_loss: 3.7000 - val_acc: 0.5085
# Epoch 92/100
# 12/12 [==============================] - 3s 227ms/step - loss: 3.4019 - acc: 0.4835 - val_loss: 3.8381 - val_acc: 0.4750
# Epoch 93/100
# 12/12 [==============================] - 3s 228ms/step - loss: 3.3894 - acc: 0.4918 - val_loss: 3.8070 - val_acc: 0.4815
# Epoch 94/100
# 12/12 [==============================] - 2s 208ms/step - loss: 3.4522 - acc: 0.4878 - val_loss: 3.6968 - val_acc: 0.5252
# Epoch 95/100
# 12/12 [==============================] - 3s 212ms/step - loss: 3.4685 - acc: 0.4875 - val_loss: 3.8251 - val_acc: 0.5083
# Epoch 96/100
# 12/12 [==============================] - 3s 210ms/step - loss: 3.4390 - acc: 0.4786 - val_loss: 3.9418 - val_acc: 0.4948
# Epoch 97/100
# 12/12 [==============================] - 3s 228ms/step - loss: 3.4879 - acc: 0.4799 - val_loss: 3.6749 - val_acc: 0.4855
# Epoch 98/100
# 12/12 [==============================] - 2s 194ms/step - loss: 3.4367 - acc: 0.4870 - val_loss: 3.7592 - val_acc: 0.4965
# Epoch 99/100
# 12/12 [==============================] - 2s 207ms/step - loss: 3.4059 - acc: 0.4678 - val_loss: 3.7776 - val_acc: 0.5201
# Epoch 100/100
# 12/12 [==============================] - 3s 248ms/step - loss: 3.4078 - acc: 0.4691 - val_loss: 3.6997 - val_acc: 0.5059
# Train time: 4m

# %%
plt.figure(figsize=(15,5))
plt.subplot(1,2,1)
plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.legend(['loss','val_loss'])
plt.grid()
plt.subplot(1,2,2)
plt.plot(hist.history['acc'])
plt.plot(hist.history['val_acc'])
plt.legend(['acc','val_acc'])
plt.grid()

# %%
history = []
history.append(hist.history['loss'])
history.append(hist.history['val_loss'])
history.append(hist.history['acc'])
history.append(hist.history['val_acc'])
history = np.array(history)
np.savetxt(model_name+"_"+dir_name+"_history.txt", history, delimiter=",")

# %%
model_json = model.to_json()
with open(model_name+"_"+dir_name+".json", "w") as json_file:
    json_file.write(model_json)
model.save_weights(model_name+"_"+dir_name+".h5")

# %%
from keras.models import model_from_json

# %%
json_file = open(model_name+"_"+dir_name+".json", "r")
loaded_model_json = json_file.read()
json_file.close()
loaded_model = model_from_json(loaded_model_json)
# load weights into new model
loaded_model.load_weights(model_name+"_"+dir_name+".h5")

# %%
# result on train images
X,Y = generator(batch_size, train_dir, H, W).__next__()
Yhat = model.predict(X)
j =1
plt.figure(figsize=(20,20))
for i in range(12):
    # original
    plt.subplot(6,8,j)
    j+=1
    img = XY2img(X[i],Y[i])
    plt.imshow(img)
    plt.axis('OFF')
    # grayscale
    plt.subplot(6,8,j)
    j+=1
    plt.imshow(X[i,:,:,0],'gray')
    plt.axis('OFF')
    # predict
    plt.subplot(6,8,j)
    j += 1
    img = XY2img(X[i],Yhat[i])
    plt.imshow(img)
    plt.axis('OFF')
    # predict
    plt.subplot(6,8,j)
    j += 1
    img = XY2imgf(X[i],Yhat[i])
    plt.imshow(img)
    plt.axis('OFF')
# Out:
# /home/tking/.local/lib/python3.5/site-packages/ipykernel_launcher.py:9: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.
#   if __name__ == '__main__':

# %%
# result on test images
X,Y = generator(batch_size, test_dir, H, W).__next__()
Yhat = model.predict(X)
j =1
plt.figure(figsize=(20,20))
for i in range(12):
    # original
    plt.subplot(6,8,j)
    j+=1
    img = XY2img(X[i],Y[i])
    plt.imshow(img)
    plt.axis('OFF')
    # grayscale
    plt.subplot(6,8,j)
    j+=1
    plt.imshow(X[i,:,:,0],'gray')
    plt.axis('OFF')
    # predict
    plt.subplot(6,8,j)
    j += 1
    img = XY2img(X[i],Yhat[i])
    plt.imshow(img)
    plt.axis('OFF')
    # predict
    plt.subplot(6,8,j)
    j += 1
    img = XY2imgf(X[i],Yhat[i])
    plt.imshow(img)
    plt.axis('OFF')
# Out:
# /home/tking/.local/lib/python3.5/site-packages/ipykernel_launcher.py:9: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.
#   if __name__ == '__main__':

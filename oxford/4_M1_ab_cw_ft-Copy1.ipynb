# %%
from keras.layers import Conv2D, UpSampling2D, InputLayer, Conv2DTranspose
from keras.layers import Activation, Dense, Dropout, Flatten
from keras.layers.normalization import BatchNormalization
from keras.models import Sequential
from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img
from skimage.color import rgb2lab, lab2rgb, rgb2gray, xyz2lab
from skimage.io import imsave
import numpy as np
import os
import random
import tensorflow as tf
from time import time

import cv2

from scipy.misc import imresize
from skimage.transform import resize

import glob

import matplotlib.pyplot as plt
# %matplotlib inline

from keras.callbacks import EarlyStopping
from keras.utils import to_categorical
import random
from keras import optimizers
from scipy.ndimage import filters
# Out:
# /home/tking/.local/lib/python3.5/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
#define parameters:
dir_name = "oxford" # Variable
model_name = "4_M1_ab_cw_ft"# Variable

train_dir = r"../../images/"+dir_name+"/train/*.jpg"
test_dir = r"../../images/"+dir_name+"/test/*.jpg"
H = 64
W = 64
batch_size = 32

# %%
# select vaild images and put into train and test dir (only run once) 
# i = 0
# num_tr = 2000
# num_ts = 500
# for img in glob.glob(r"../../images/"+dir_name+"/*.jpg"):
#     try:
#         n= cv2.imread(img)#BGR
#         if  n is None or np.mean(n)>250 or np.mean(np.std(n,axis=2))<2:
#             os.remove(img)
#         else:
#             if i<num_tr:
#                 i+=1
#                 os.rename(img,r"../../images/"+dir_name+"/train/"+str(i)+".jpg")
#             elif i>=num_tr and i<num_tr+num_ts:
#                 i+=1
#                 os.rename(img,r"../../images/"+dir_name+"/test/"+str(i)+".jpg")
#             else:
#                 break
#     except:
#         pass
print('tr_size = ',len(glob.glob(train_dir)))
print('ts_size = ',len(glob.glob(test_dir)))
# Out:
# tr_size =  200
# ts_size =  50

# %%
def generator(batch_size, dir_path, H, W):
    while True:
        X = []
        Y = []
        img_batch = random.sample(glob.glob(dir_path), batch_size)
        for img in img_batch:
            # choose random index in features
            n= cv2.imread(img)#BGR
            m = imresize(n,(H,W,3))
            img_lab = cv2.cvtColor(m.astype(np.uint8), cv2.COLOR_BGR2LAB)
            L = img_lab[:,:,0].reshape(1,H,W,1)
            y = np.floor(img_lab[:,:,1:]/16)

            # to_categorical
            y0=y[:,:,0].flatten()
            y1=y[:,:,1].flatten()
            Yc2d0 = to_categorical(y0, num_classes = 16 )
            Yc3d0 = Yc2d0.reshape(H,W,16)
            Yc2d1 = to_categorical(y1, num_classes = 16 )
            Yc3d1 = Yc2d1.reshape(H,W,16)
            Yc3d = np.zeros((H,W,32))
            Yc3d[:,:,:16] = Yc3d0
            Yc3d[:,:,16:] = Yc3d1

            Y.append(Yc3d)
            X.append(L)
        X=np.array(X)
        Y=np.array(Y)
        X=np.reshape(X, (batch_size, H, W, 1))
        Y=np.reshape(Y, (batch_size, H, W, 32))
        yield X, Y

# %%
def XY2img(X,Y):
    H, W, _ = X.shape
    img_lab = np.zeros((H,W,3))
    img_lab[:,:,0] = X[:,:,0]
    img_lab[:,:,1] = np.argmax(Y[:,:,:16],axis=2)*16+8
    img_lab[:,:,2] = np.argmax(Y[:,:,16:],axis=2)*16+8
    img = cv2.cvtColor(img_lab.astype(np.uint8), cv2.COLOR_LAB2RGB)
    return img

# %%
def XY2imgf(X,Y):
    H, W, _ = X.shape
    img_lab = np.zeros((H,W,3))
    img_lab[:,:,0] = X[:,:,0]
    img_lab[:,:,1] = filters.gaussian_filter(np.argmax(Y[:,:,:16],axis=2)*16+8,5)
    img_lab[:,:,2] = filters.gaussian_filter(np.argmax(Y[:,:,16:],axis=2)*16+8,5)
    img = cv2.cvtColor(img_lab.astype(np.uint8), cv2.COLOR_LAB2RGB)
    return img

# %%
# show some images
plt.figure(figsize=(15,5))
X,Y = generator(batch_size, train_dir, H, W).__next__()    
for i in range(8):
    plt.subplot(1,8,i+1)
    img = XY2img(X[i],Y[i])
    plt.imshow(img)
    plt.axis('off')
# Out:
# /home/tking/.local/lib/python3.5/site-packages/ipykernel_launcher.py:9: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.
#   if __name__ == '__main__':

# %%
# read images to compute class_weight
Y = []
img_sample = random.sample(glob.glob(train_dir), 200)#save memory
for img in img_sample:
    n= cv2.imread(img)#BGR
    m = imresize(n,(H,W,3))
    img_lab = cv2.cvtColor(m.astype(np.uint8), cv2.COLOR_BGR2LAB)
    y = np.floor(img_lab[:,:,1:]/16)
    
    # to_categorical
    y0=y[:,:,0].flatten()
    y1=y[:,:,1].flatten()
    yc2d0 = to_categorical(y0, num_classes = 16 )
    yc3d0 = yc2d0.reshape(H,W,16)
    yc2d1 = to_categorical(y1, num_classes = 16 )
    yc3d1 = yc2d1.reshape(H,W,16)
    yc3d = np.zeros((H,W,32))
    yc3d[:,:,:16] = yc3d0
    yc3d[:,:,16:] = yc3d1
    Y.append(yc3d)
num = len(Y)
Y=np.array(Y)
Y=np.reshape(Y, (num, H, W, 32))
# Out:
# /home/tking/.local/lib/python3.5/site-packages/ipykernel_launcher.py:6: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.

# %%
# compute class_weight
from sklearn.utils import class_weight
Yflat16A = Y[:,:,:,:16].reshape(num*H*W,16)
YflatA = np.argmax(Yflat16A,axis=1)
YclassA = np.unique(YflatA)
class_weight_A = class_weight.compute_class_weight('balanced',
                                                 YclassA,
                                                 YflatA)
Yflat16B = Y[:,:,:,16:].reshape(num*H*W,16)
YflatB = np.argmax(Yflat16B,axis=1)
YclassB = np.unique(YflatB)
class_weight_B = class_weight.compute_class_weight('balanced',
                                                 YclassB,
                                                 YflatB)

class_weight = np.zeros(32)
for i in range(len(YclassA)):
    class_weight[YclassA[i]]=class_weight_A[i]
for i in range(len(YclassB)):
    class_weight[YclassB[i]+16]=class_weight_B[i]

plt.stem(class_weight)
plt.yscale('log')
plt.ylabel('class_weight')
plt.xlabel('classes')
# Out:
# Text(0.5,0,'classes')

# %%
# Building the neural network
import keras.backend as K
K.clear_session()
model = Sequential()
model.add(InputLayer(input_shape=(None, None, 1)))
model.add(Conv2D(8, (3, 3), activation='relu', padding='same', strides=2))
model.add(Conv2D(8, (3, 3), activation='relu', padding='same'))
model.add(Conv2D(16, (3, 3), activation='relu', padding='same'))
model.add(Conv2D(16, (3, 3), activation='relu', padding='same', strides=2))
model.add(Conv2D(32, (3, 3), activation='relu', padding='same'))
model.add(Conv2D(32, (3, 3), activation='relu', padding='same', strides=2))
model.add(Conv2DTranspose(32, (2,2), strides=2, padding='same', activation='relu'))
model.add(Conv2D(32, (3, 3), activation='relu', padding='same'))
model.add(Conv2DTranspose(32, (2,2), strides=2, padding='same', activation='relu'))
model.add(Conv2D(16, (3, 3), activation='relu', padding='same'))
model.add(Conv2DTranspose(32, (2,2), strides=2, padding='same', activation='relu'))
model.add(Conv2D(32, (3, 3), activation='sigmoid', padding='same'))#TODO
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, None, None, 1)     0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, None, None, 8)     80
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, None, None, 8)     584
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, None, None, 16)    1168
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, None, None, 16)    2320
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, None, None, 32)    4640
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, None, None, 32)    9248
# _________________________________________________________________
# conv2d_transpose_1 (Conv2DTr (None, None, None, 32)    4128
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, None, None, 32)    9248
# _________________________________________________________________
# conv2d_transpose_2 (Conv2DTr (None, None, None, 32)    4128
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, None, None, 16)    4624
# _________________________________________________________________
# conv2d_transpose_3 (Conv2DTr (None, None, None, 32)    2080
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, None, None, 32)    9248
# =================================================================
# Total params: 51,496
# Trainable params: 51,496
# Non-trainable params: 0
# _________________________________________________________________

# %%
# compile model
opt = optimizers.Adam(lr=0.001)
model.compile(optimizer=opt,
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %%
train_generator = generator(batch_size, train_dir, H, W)
test_generator = generator(batch_size, test_dir, H, W)
tr_size = len(glob.glob(train_dir))
ts_size = len(glob.glob(test_dir))
steps_per_epoch = tr_size// batch_size
validation_steps = ts_size // batch_size
print(tr_size,ts_size,steps_per_epoch,validation_steps)
# Out:
# 200 50 6 1

# %%
t0 = time()
hist = model.fit_generator(train_generator,
                            steps_per_epoch=steps_per_epoch,
                            epochs=100,
                            validation_data=test_generator,
                            validation_steps=validation_steps,
                            class_weight=class_weight,
                            verbose=1)
print('Train time: %.fm'%((time()-t0)/60))
# Out:
# Epoch 1/100
# /home/tking/.local/lib/python3.5/site-packages/ipykernel_launcher.py:9: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.
#   if __name__ == '__main__':
# 6/6 [==============================] - 5s 774ms/step - loss: 6.7665 - acc: 0.0929 - val_loss: 6.0857 - val_acc: 0.1972
# Epoch 2/100
# 6/6 [==============================] - 3s 566ms/step - loss: 5.2614 - acc: 0.2150 - val_loss: 4.8175 - val_acc: 0.2500
# Epoch 3/100
# 6/6 [==============================] - 3s 562ms/step - loss: 4.2304 - acc: 0.2114 - val_loss: 4.0995 - val_acc: 0.1118
# Epoch 4/100
# 6/6 [==============================] - 3s 572ms/step - loss: 4.0623 - acc: 0.1054 - val_loss: 4.0469 - val_acc: 0.1200
# Epoch 5/100
# 6/6 [==============================] - 3s 578ms/step - loss: 3.9832 - acc: 0.1305 - val_loss: 3.8676 - val_acc: 0.1384
# Epoch 6/100
# 6/6 [==============================] - 3s 570ms/step - loss: 3.9314 - acc: 0.1531 - val_loss: 3.8923 - val_acc: 0.1507
# Epoch 7/100
# 6/6 [==============================] - 3s 579ms/step - loss: 3.9124 - acc: 0.1694 - val_loss: 3.8261 - val_acc: 0.1657
# Epoch 8/100
# 6/6 [==============================] - 3s 578ms/step - loss: 3.8681 - acc: 0.1899 - val_loss: 3.7587 - val_acc: 0.1827
# Epoch 9/100
# 6/6 [==============================] - 3s 562ms/step - loss: 3.8098 - acc: 0.2199 - val_loss: 3.8419 - val_acc: 0.2172
# Epoch 10/100
# 6/6 [==============================] - 3s 560ms/step - loss: 3.8199 - acc: 0.2146 - val_loss: 3.8448 - val_acc: 0.2290
# Epoch 11/100
# 6/6 [==============================] - 3s 567ms/step - loss: 3.7953 - acc: 0.2194 - val_loss: 3.7663 - val_acc: 0.2222
# Epoch 12/100
# 6/6 [==============================] - 3s 575ms/step - loss: 3.7615 - acc: 0.2238 - val_loss: 3.6829 - val_acc: 0.2074
# Epoch 13/100
# 6/6 [==============================] - 3s 573ms/step - loss: 3.7502 - acc: 0.2519 - val_loss: 3.7878 - val_acc: 0.2364
# Epoch 14/100
# 6/6 [==============================] - 3s 571ms/step - loss: 3.7220 - acc: 0.2406 - val_loss: 3.6746 - val_acc: 0.2283
# Epoch 15/100
# 6/6 [==============================] - 3s 573ms/step - loss: 3.6798 - acc: 0.2441 - val_loss: 3.7795 - val_acc: 0.2532
# Epoch 16/100
# 6/6 [==============================] - 3s 578ms/step - loss: 3.7050 - acc: 0.2439 - val_loss: 3.6772 - val_acc: 0.2449
# Epoch 17/100
# 6/6 [==============================] - 3s 575ms/step - loss: 3.7068 - acc: 0.2556 - val_loss: 3.6281 - val_acc: 0.2307
# Epoch 18/100
# 6/6 [==============================] - 3s 573ms/step - loss: 3.6497 - acc: 0.2797 - val_loss: 3.7647 - val_acc: 0.2808
# Epoch 19/100
# 6/6 [==============================] - 3s 573ms/step - loss: 3.6138 - acc: 0.2810 - val_loss: 3.6418 - val_acc: 0.2800
# Epoch 20/100
# 6/6 [==============================] - 3s 578ms/step - loss: 3.6442 - acc: 0.2926 - val_loss: 3.6257 - val_acc: 0.2569
# Epoch 21/100
# 6/6 [==============================] - 3s 573ms/step - loss: 3.6544 - acc: 0.3118 - val_loss: 3.6681 - val_acc: 0.2509
# Epoch 22/100
# 6/6 [==============================] - 3s 566ms/step - loss: 3.6484 - acc: 0.2819 - val_loss: 3.5697 - val_acc: 0.3154
# Epoch 23/100
# 6/6 [==============================] - 3s 573ms/step - loss: 3.5849 - acc: 0.3058 - val_loss: 3.5548 - val_acc: 0.2969
# Epoch 24/100
# 6/6 [==============================] - 3s 573ms/step - loss: 3.5957 - acc: 0.3314 - val_loss: 3.6331 - val_acc: 0.3123
# Epoch 25/100
# 6/6 [==============================] - 3s 570ms/step - loss: 3.5563 - acc: 0.3262 - val_loss: 3.5598 - val_acc: 0.3390
# Epoch 26/100
# 6/6 [==============================] - 4s 629ms/step - loss: 3.5601 - acc: 0.3658 - val_loss: 3.5255 - val_acc: 0.3246
# Epoch 27/100
# 6/6 [==============================] - 3s 574ms/step - loss: 3.5384 - acc: 0.3513 - val_loss: 3.5454 - val_acc: 0.3315
# Epoch 28/100
# 6/6 [==============================] - 3s 564ms/step - loss: 3.5285 - acc: 0.3565 - val_loss: 3.5011 - val_acc: 0.3363
# Epoch 29/100
# 6/6 [==============================] - 3s 562ms/step - loss: 3.5712 - acc: 0.3715 - val_loss: 3.5362 - val_acc: 0.3673
# Epoch 30/100
# 6/6 [==============================] - 3s 573ms/step - loss: 3.4850 - acc: 0.3854 - val_loss: 3.6508 - val_acc: 0.3430
# Epoch 31/100
# 6/6 [==============================] - 3s 577ms/step - loss: 3.5382 - acc: 0.3786 - val_loss: 3.5393 - val_acc: 0.3710
# Epoch 32/100
# 6/6 [==============================] - 3s 569ms/step - loss: 3.5086 - acc: 0.3770 - val_loss: 3.6194 - val_acc: 0.4253
# Epoch 33/100
# 6/6 [==============================] - 3s 570ms/step - loss: 3.4920 - acc: 0.4289 - val_loss: 3.6148 - val_acc: 0.3686
# Epoch 34/100
# 6/6 [==============================] - 3s 573ms/step - loss: 3.5397 - acc: 0.3937 - val_loss: 3.5438 - val_acc: 0.4164
# Epoch 35/100
# 6/6 [==============================] - 3s 572ms/step - loss: 3.4854 - acc: 0.4329 - val_loss: 3.5545 - val_acc: 0.4005
# Epoch 36/100
# 6/6 [==============================] - 3s 565ms/step - loss: 3.4875 - acc: 0.4183 - val_loss: 3.5401 - val_acc: 0.4877
# Epoch 37/100
# 6/6 [==============================] - 3s 572ms/step - loss: 3.4709 - acc: 0.4457 - val_loss: 3.5178 - val_acc: 0.4201
# Epoch 38/100
# 6/6 [==============================] - 3s 564ms/step - loss: 3.4424 - acc: 0.4657 - val_loss: 3.5877 - val_acc: 0.4526
# Epoch 39/100
# 6/6 [==============================] - 3s 571ms/step - loss: 3.4736 - acc: 0.4409 - val_loss: 3.5209 - val_acc: 0.5070
# Epoch 40/100
# 6/6 [==============================] - 3s 570ms/step - loss: 3.4870 - acc: 0.4728 - val_loss: 3.5612 - val_acc: 0.4511
# Epoch 41/100
# 6/6 [==============================] - 3s 564ms/step - loss: 3.4329 - acc: 0.4678 - val_loss: 3.5922 - val_acc: 0.5102
# Epoch 42/100
# 6/6 [==============================] - 3s 566ms/step - loss: 3.4171 - acc: 0.5026 - val_loss: 3.5132 - val_acc: 0.4673
# Epoch 43/100
# 6/6 [==============================] - 3s 564ms/step - loss: 3.4602 - acc: 0.4807 - val_loss: 3.5087 - val_acc: 0.4640
# Epoch 44/100
# 6/6 [==============================] - 3s 571ms/step - loss: 3.4008 - acc: 0.4988 - val_loss: 3.4966 - val_acc: 0.5185
# Epoch 45/100
# 6/6 [==============================] - 3s 578ms/step - loss: 3.3909 - acc: 0.5412 - val_loss: 3.5849 - val_acc: 0.5206
# Epoch 46/100
# 6/6 [==============================] - 3s 570ms/step - loss: 3.3745 - acc: 0.5335 - val_loss: 3.4826 - val_acc: 0.5084
# Epoch 47/100
# 6/6 [==============================] - 3s 567ms/step - loss: 3.3888 - acc: 0.5526 - val_loss: 3.5405 - val_acc: 0.5051
# Epoch 48/100
# 6/6 [==============================] - 4s 584ms/step - loss: 3.4374 - acc: 0.5413 - val_loss: 3.5498 - val_acc: 0.4725
# Epoch 49/100
# 6/6 [==============================] - 3s 552ms/step - loss: 3.3877 - acc: 0.5742 - val_loss: 3.5848 - val_acc: 0.5076
# Epoch 50/100
# 6/6 [==============================] - 3s 573ms/step - loss: 3.4363 - acc: 0.5839 - val_loss: 3.4118 - val_acc: 0.5444
# Epoch 51/100
# 6/6 [==============================] - 3s 580ms/step - loss: 3.3615 - acc: 0.5642 - val_loss: 3.4009 - val_acc: 0.5646
# Epoch 52/100
# 6/6 [==============================] - 3s 566ms/step - loss: 3.3517 - acc: 0.5784 - val_loss: 3.4780 - val_acc: 0.6099
# Epoch 53/100
# 6/6 [==============================] - 3s 577ms/step - loss: 3.4313 - acc: 0.6337 - val_loss: 3.5514 - val_acc: 0.5475
# Epoch 54/100
# 6/6 [==============================] - 3s 572ms/step - loss: 3.3879 - acc: 0.6348 - val_loss: 3.4214 - val_acc: 0.6121
# Epoch 55/100
# 6/6 [==============================] - 3s 577ms/step - loss: 3.3741 - acc: 0.6311 - val_loss: 3.4312 - val_acc: 0.6266
# Epoch 56/100
# 6/6 [==============================] - 3s 567ms/step - loss: 3.3747 - acc: 0.6481 - val_loss: 3.4258 - val_acc: 0.6164
# Epoch 57/100
# 6/6 [==============================] - 3s 567ms/step - loss: 3.3413 - acc: 0.6619 - val_loss: 3.4397 - val_acc: 0.5394
# Epoch 58/100
# 6/6 [==============================] - 3s 581ms/step - loss: 3.3634 - acc: 0.6257 - val_loss: 3.4078 - val_acc: 0.5978
# Epoch 59/100
# 6/6 [==============================] - 3s 572ms/step - loss: 3.3192 - acc: 0.6321 - val_loss: 3.3075 - val_acc: 0.5947
# Epoch 60/100
# 6/6 [==============================] - 3s 567ms/step - loss: 3.2858 - acc: 0.6519 - val_loss: 3.4414 - val_acc: 0.6067
# Epoch 61/100
# 6/6 [==============================] - 3s 574ms/step - loss: 3.3465 - acc: 0.6400 - val_loss: 3.4260 - val_acc: 0.5979
# Epoch 62/100
# 6/6 [==============================] - 3s 568ms/step - loss: 3.3203 - acc: 0.6229 - val_loss: 3.4988 - val_acc: 0.6086
# Epoch 63/100
# 6/6 [==============================] - 3s 566ms/step - loss: 3.3310 - acc: 0.6187 - val_loss: 3.4015 - val_acc: 0.5929
# Epoch 64/100
# 6/6 [==============================] - 3s 567ms/step - loss: 3.2753 - acc: 0.6581 - val_loss: 3.4557 - val_acc: 0.5434
# Epoch 65/100
# 6/6 [==============================] - 3s 571ms/step - loss: 3.3299 - acc: 0.6276 - val_loss: 3.4316 - val_acc: 0.6355
# Epoch 66/100
# 6/6 [==============================] - 4s 585ms/step - loss: 3.3120 - acc: 0.6183 - val_loss: 3.4283 - val_acc: 0.6021
# Epoch 67/100
# 6/6 [==============================] - 3s 568ms/step - loss: 3.2055 - acc: 0.6759 - val_loss: 3.3791 - val_acc: 0.6063
# Epoch 68/100
# 6/6 [==============================] - 3s 581ms/step - loss: 3.2860 - acc: 0.6551 - val_loss: 3.3360 - val_acc: 0.6030
# Epoch 69/100
# 6/6 [==============================] - 3s 568ms/step - loss: 3.2701 - acc: 0.6312 - val_loss: 3.3935 - val_acc: 0.6158
# Epoch 70/100
# 6/6 [==============================] - 3s 565ms/step - loss: 3.2572 - acc: 0.6326 - val_loss: 3.5869 - val_acc: 0.5835
# Epoch 71/100
# 6/6 [==============================] - 3s 565ms/step - loss: 3.3446 - acc: 0.6324 - val_loss: 3.4672 - val_acc: 0.5948
# Epoch 72/100
# 6/6 [==============================] - 3s 571ms/step - loss: 3.3352 - acc: 0.6383 - val_loss: 3.5034 - val_acc: 0.6472
# Epoch 73/100
# 6/6 [==============================] - 3s 571ms/step - loss: 3.2797 - acc: 0.6487 - val_loss: 3.4142 - val_acc: 0.5734
# Epoch 74/100
# 6/6 [==============================] - 3s 568ms/step - loss: 3.2889 - acc: 0.6197 - val_loss: 3.4627 - val_acc: 0.5813
# Epoch 75/100
# 6/6 [==============================] - 3s 572ms/step - loss: 3.2381 - acc: 0.6149 - val_loss: 3.5180 - val_acc: 0.6152
# Epoch 76/100
# 6/6 [==============================] - 3s 566ms/step - loss: 3.2512 - acc: 0.6568 - val_loss: 3.4155 - val_acc: 0.6027
# Epoch 77/100
# 6/6 [==============================] - 3s 578ms/step - loss: 3.2394 - acc: 0.6436 - val_loss: 3.3899 - val_acc: 0.6283
# Epoch 78/100
# 6/6 [==============================] - 4s 584ms/step - loss: 3.1766 - acc: 0.6356 - val_loss: 3.4530 - val_acc: 0.5587
# Epoch 79/100
# 6/6 [==============================] - 3s 564ms/step - loss: 3.2265 - acc: 0.6638 - val_loss: 3.3168 - val_acc: 0.6317
# Epoch 80/100
# 6/6 [==============================] - 3s 571ms/step - loss: 3.2369 - acc: 0.6064 - val_loss: 3.4338 - val_acc: 0.5836
# Epoch 81/100
# 6/6 [==============================] - 3s 572ms/step - loss: 3.2237 - acc: 0.6486 - val_loss: 3.3822 - val_acc: 0.5971
# Epoch 82/100
# 6/6 [==============================] - 3s 571ms/step - loss: 3.2002 - acc: 0.6413 - val_loss: 3.5276 - val_acc: 0.5778
# Epoch 83/100
# 6/6 [==============================] - 3s 560ms/step - loss: 3.2442 - acc: 0.6478 - val_loss: 3.4135 - val_acc: 0.6006
# Epoch 84/100
# 6/6 [==============================] - 3s 564ms/step - loss: 3.2086 - acc: 0.6314 - val_loss: 3.3917 - val_acc: 0.6053
# Epoch 85/100
# 6/6 [==============================] - 3s 572ms/step - loss: 3.2013 - acc: 0.6275 - val_loss: 3.3542 - val_acc: 0.6044
# Epoch 86/100
# 6/6 [==============================] - 3s 570ms/step - loss: 3.1897 - acc: 0.6720 - val_loss: 3.4318 - val_acc: 0.5833
# Epoch 87/100
# 6/6 [==============================] - 3s 560ms/step - loss: 3.2259 - acc: 0.6043 - val_loss: 3.2948 - val_acc: 0.6355
# Epoch 88/100
# 6/6 [==============================] - 3s 560ms/step - loss: 3.1600 - acc: 0.6256 - val_loss: 3.4877 - val_acc: 0.6049
# Epoch 89/100
# 6/6 [==============================] - 3s 575ms/step - loss: 3.1966 - acc: 0.6445 - val_loss: 3.3819 - val_acc: 0.6270
# Epoch 90/100
# 6/6 [==============================] - 3s 573ms/step - loss: 3.1848 - acc: 0.6261 - val_loss: 3.5341 - val_acc: 0.5814
# Epoch 91/100
# 6/6 [==============================] - 3s 568ms/step - loss: 3.1426 - acc: 0.6672 - val_loss: 3.4344 - val_acc: 0.6064
# Epoch 92/100
# 6/6 [==============================] - 4s 585ms/step - loss: 3.1702 - acc: 0.6289 - val_loss: 3.4478 - val_acc: 0.5979
# Epoch 93/100
# 6/6 [==============================] - 3s 564ms/step - loss: 3.1589 - acc: 0.6459 - val_loss: 3.4310 - val_acc: 0.5840
# Epoch 94/100
# 6/6 [==============================] - 3s 561ms/step - loss: 3.1598 - acc: 0.6300 - val_loss: 3.5089 - val_acc: 0.6038
# Epoch 95/100
# 6/6 [==============================] - 3s 563ms/step - loss: 3.1123 - acc: 0.6195 - val_loss: 3.5207 - val_acc: 0.5744
# Epoch 96/100
# 6/6 [==============================] - 3s 572ms/step - loss: 3.1789 - acc: 0.6486 - val_loss: 3.5144 - val_acc: 0.5536
# Epoch 97/100
# 6/6 [==============================] - 3s 577ms/step - loss: 3.1663 - acc: 0.6452 - val_loss: 3.4535 - val_acc: 0.5713
# Epoch 98/100
# 6/6 [==============================] - 3s 571ms/step - loss: 3.1909 - acc: 0.6272 - val_loss: 3.4212 - val_acc: 0.6008
# Epoch 99/100
# 6/6 [==============================] - 3s 580ms/step - loss: 3.1417 - acc: 0.6523 - val_loss: 3.4263 - val_acc: 0.5935
# Epoch 100/100
# 6/6 [==============================] - 3s 570ms/step - loss: 3.1582 - acc: 0.6191 - val_loss: 3.5037 - val_acc: 0.5749
# Train time: 6m

# %%
plt.figure(figsize=(15,5))
plt.subplot(1,2,1)
plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.legend(['loss','val_loss'])
plt.grid()
plt.subplot(1,2,2)
plt.plot(hist.history['acc'])
plt.plot(hist.history['val_acc'])
plt.legend(['acc','val_acc'])
plt.grid()

# %%
history = []
history.append(hist.history['loss'])
history.append(hist.history['val_loss'])
history.append(hist.history['acc'])
history.append(hist.history['val_acc'])
history = np.array(history)
np.savetxt(model_name+"_"+dir_name+"_history.txt", history, delimiter=",")

# %%
model_json = model.to_json()
with open(model_name+"_"+dir_name+".json", "w") as json_file:
    json_file.write(model_json)
model.save_weights(model_name+"_"+dir_name+".h5")

# %%
from keras.models import model_from_json

# %%
json_file = open(model_name+"_"+dir_name+".json", "r")
loaded_model_json = json_file.read()
json_file.close()
loaded_model = model_from_json(loaded_model_json)
# load weights into new model
loaded_model.load_weights(model_name+"_"+dir_name+".h5")

# %%
# result on train images
X,Y = generator(batch_size, train_dir, H, W).__next__()
Yhat = model.predict(X)
j =1
plt.figure(figsize=(20,20))
for i in range(12):
    # original
    plt.subplot(6,8,j)
    j+=1
    img = XY2img(X[i],Y[i])
    plt.imshow(img)
    plt.axis('OFF')
    # grayscale
    plt.subplot(6,8,j)
    j+=1
    plt.imshow(X[i,:,:,0],'gray')
    plt.axis('OFF')
    # predict
    plt.subplot(6,8,j)
    j += 1
    img = XY2img(X[i],Yhat[i])
    plt.imshow(img)
    plt.axis('OFF')
    # predict
    plt.subplot(6,8,j)
    j += 1
    img = XY2imgf(X[i],Yhat[i])
    plt.imshow(img)
    plt.axis('OFF')

# %%
# result on test images
X,Y = generator(batch_size, test_dir, H, W).__next__()
Yhat = model.predict(X)
j =1
plt.figure(figsize=(20,20))
for i in range(12):
    # original
    plt.subplot(6,8,j)
    j+=1
    img = XY2img(X[i],Y[i])
    plt.imshow(img)
    plt.axis('OFF')
    # grayscale
    plt.subplot(6,8,j)
    j+=1
    plt.imshow(X[i,:,:,0],'gray')
    plt.axis('OFF')
    # predict
    plt.subplot(6,8,j)
    j += 1
    img = XY2img(X[i],Yhat[i])
    plt.imshow(img)
    plt.axis('OFF')
    # predict
    plt.subplot(6,8,j)
    j += 1
    img = XY2imgf(X[i],Yhat[i])
    plt.imshow(img)
    plt.axis('OFF')

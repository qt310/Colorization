# %%
from keras.layers import Conv2D, UpSampling2D, InputLayer, Conv2DTranspose
from keras.layers import Activation, Dense, Dropout, Flatten
from keras.layers.normalization import BatchNormalization
from keras.models import Sequential
from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img
from skimage.color import rgb2lab, lab2rgb, rgb2gray, xyz2lab
from skimage.io import imsave
import numpy as np
import os
import random
import tensorflow as tf
from time import time

import cv2

from scipy.misc import imresize
from skimage.transform import resize

import glob

import matplotlib.pyplot as plt
# %matplotlib inline

from keras.callbacks import EarlyStopping
from keras.utils import to_categorical
import random
from keras import optimizers
from scipy.ndimage import filters
# Out:
# /home/tking/.local/lib/python3.5/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
#define parameters:
dir_name = "oxford" # Variable
model_name = "6_M3_ab_cw_ft"# Variable

train_dir = r"../../images/"+dir_name+"/train/*.jpg"
test_dir = r"../../images/"+dir_name+"/test/*.jpg"
H = 64
W = 64
batch_size = 32

# %%
# select vaild images and put into train and test dir (only run once) 
# i = 0
# num_tr = 2000
# num_ts = 500
# for img in glob.glob(r"../../images/"+dir_name+"/*.jpg"):
#     try:
#         n= cv2.imread(img)#BGR
#         if  n is None or np.mean(n)>250 or np.mean(np.std(n,axis=2))<2:
#             os.remove(img)
#         else:
#             if i<num_tr:
#                 i+=1
#                 os.rename(img,r"../../images/"+dir_name+"/train/"+str(i)+".jpg")
#             elif i>=num_tr and i<num_tr+num_ts:
#                 i+=1
#                 os.rename(img,r"../../images/"+dir_name+"/test/"+str(i)+".jpg")
#             else:
#                 break
#     except:
#         pass
print('tr_size = ',len(glob.glob(train_dir)))
print('ts_size = ',len(glob.glob(test_dir)))
# Out:
# tr_size =  200
# ts_size =  50

# %%
def generator(batch_size, dir_path, H, W):
    while True:
        X = []
        Y = []
        img_batch = random.sample(glob.glob(dir_path), batch_size)
        for img in img_batch:
            # choose random index in features
            n= cv2.imread(img)#BGR
            m = imresize(n,(H,W,3))
            img_lab = cv2.cvtColor(m.astype(np.uint8), cv2.COLOR_BGR2LAB)
            L = img_lab[:,:,0].reshape(1,H,W,1)
            y = np.floor(img_lab[:,:,1:]/16)

            # to_categorical
            y0=y[:,:,0].flatten()
            y1=y[:,:,1].flatten()
            Yc2d0 = to_categorical(y0, num_classes = 16 )
            Yc3d0 = Yc2d0.reshape(H,W,16)
            Yc2d1 = to_categorical(y1, num_classes = 16 )
            Yc3d1 = Yc2d1.reshape(H,W,16)
            Yc3d = np.zeros((H,W,32))
            Yc3d[:,:,:16] = Yc3d0
            Yc3d[:,:,16:] = Yc3d1

            Y.append(Yc3d)
            X.append(L)
        X=np.array(X)
        Y=np.array(Y)
        X=np.reshape(X, (batch_size, H, W, 1))
        Y=np.reshape(Y, (batch_size, H, W, 32))
        yield X, Y

# %%
def XY2img(X,Y):
    H, W, _ = X.shape
    img_lab = np.zeros((H,W,3))
    img_lab[:,:,0] = X[:,:,0]
    img_lab[:,:,1] = np.argmax(Y[:,:,:16],axis=2)*16+8
    img_lab[:,:,2] = np.argmax(Y[:,:,16:],axis=2)*16+8
    img = cv2.cvtColor(img_lab.astype(np.uint8), cv2.COLOR_LAB2RGB)
    return img

# %%
def XY2imgf(X,Y):
    H, W, _ = X.shape
    img_lab = np.zeros((H,W,3))
    img_lab[:,:,0] = X[:,:,0]
    img_lab[:,:,1] = filters.gaussian_filter(np.argmax(Y[:,:,:16],axis=2)*16+8,5)
    img_lab[:,:,2] = filters.gaussian_filter(np.argmax(Y[:,:,16:],axis=2)*16+8,5)
    img = cv2.cvtColor(img_lab.astype(np.uint8), cv2.COLOR_LAB2RGB)
    return img

# %%
# show some images
plt.figure(figsize=(15,5))
X,Y = generator(batch_size, train_dir, H, W).__next__()    
for i in range(8):
    plt.subplot(1,8,i+1)
    img = XY2img(X[i],Y[i])
    plt.imshow(img)
    plt.axis('off')
# Out:
# /home/tking/.local/lib/python3.5/site-packages/ipykernel_launcher.py:9: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.
#   if __name__ == '__main__':

# %%
# read images to compute class_weight
Y = []
img_sample = random.sample(glob.glob(train_dir), 200)#save memory
for img in img_sample:
    n= cv2.imread(img)#BGR
    m = imresize(n,(H,W,3))
    img_lab = cv2.cvtColor(m.astype(np.uint8), cv2.COLOR_BGR2LAB)
    y = np.floor(img_lab[:,:,1:]/16)
    
    # to_categorical
    y0=y[:,:,0].flatten()
    y1=y[:,:,1].flatten()
    yc2d0 = to_categorical(y0, num_classes = 16 )
    yc3d0 = yc2d0.reshape(H,W,16)
    yc2d1 = to_categorical(y1, num_classes = 16 )
    yc3d1 = yc2d1.reshape(H,W,16)
    yc3d = np.zeros((H,W,32))
    yc3d[:,:,:16] = yc3d0
    yc3d[:,:,16:] = yc3d1
    Y.append(yc3d)
num = len(Y)
Y=np.array(Y)
Y=np.reshape(Y, (num, H, W, 32))
# Out:
# /home/tking/.local/lib/python3.5/site-packages/ipykernel_launcher.py:6: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.

# %%
# compute class_weight
from sklearn.utils import class_weight
Yflat16A = Y[:,:,:,:16].reshape(num*H*W,16)
YflatA = np.argmax(Yflat16A,axis=1)
YclassA = np.unique(YflatA)
class_weight_A = class_weight.compute_class_weight('balanced',
                                                 YclassA,
                                                 YflatA)
Yflat16B = Y[:,:,:,16:].reshape(num*H*W,16)
YflatB = np.argmax(Yflat16B,axis=1)
YclassB = np.unique(YflatB)
class_weight_B = class_weight.compute_class_weight('balanced',
                                                 YclassB,
                                                 YflatB)

class_weight = np.zeros(32)
for i in range(len(YclassA)):
    class_weight[YclassA[i]]=class_weight_A[i]
for i in range(len(YclassB)):
    class_weight[YclassB[i]+16]=class_weight_B[i]

plt.stem(class_weight)
plt.yscale('log')
plt.ylabel('class_weight')
plt.xlabel('classes')
# Out:
# Text(0.5,0,'classes')

# %%
# Building the neural network
import keras.backend as K
K.clear_session()
model = Sequential()
model.add(InputLayer(input_shape=(None, None, 1)))
model.add(Conv2D(8, (3, 3), activation='relu', padding='same', strides=2))
model.add(BatchNormalization(axis=-1))
model.add(Dropout(0.25))
model.add(Conv2D(8, (3, 3), activation='relu', padding='same'))
model.add(BatchNormalization(axis=-1))
model.add(Dropout(0.25))
model.add(Conv2D(16, (3, 3), activation='relu', padding='same'))
model.add(BatchNormalization(axis=-1))
model.add(Dropout(0.25))
model.add(Conv2D(16, (3, 3), activation='relu', padding='same', strides=2))
model.add(BatchNormalization(axis=-1))
model.add(Dropout(0.25))
model.add(Conv2D(32, (3, 3), activation='relu', padding='same'))
model.add(BatchNormalization(axis=-1))
model.add(Dropout(0.25))
model.add(Conv2D(32, (3, 3), activation='relu', padding='same', strides=2))
model.add(Conv2DTranspose(32, (2,2), strides=2, padding='same', activation='relu'))
model.add(BatchNormalization(axis=-1))
model.add(Dropout(0.25))
model.add(Conv2D(32, (3, 3), activation='relu', padding='same'))
model.add(Conv2DTranspose(32, (2,2), strides=2, padding='same', activation='relu'))
model.add(BatchNormalization(axis=-1))
model.add(Dropout(0.25))
model.add(Conv2D(16, (3, 3), activation='relu', padding='same'))
model.add(Conv2DTranspose(32, (2,2), strides=2, padding='same', activation='relu'))
model.add(BatchNormalization(axis=-1))
model.add(Dropout(0.25))
model.add(Conv2D(32, (3, 3), activation='sigmoid', padding='same'))#TODO
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, None, None, 1)     0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, None, None, 8)     80
# _________________________________________________________________
# batch_normalization_1 (Batch (None, None, None, 8)     32
# _________________________________________________________________
# dropout_1 (Dropout)          (None, None, None, 8)     0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, None, None, 8)     584
# _________________________________________________________________
# batch_normalization_2 (Batch (None, None, None, 8)     32
# _________________________________________________________________
# dropout_2 (Dropout)          (None, None, None, 8)     0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, None, None, 16)    1168
# _________________________________________________________________
# batch_normalization_3 (Batch (None, None, None, 16)    64
# _________________________________________________________________
# dropout_3 (Dropout)          (None, None, None, 16)    0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, None, None, 16)    2320
# _________________________________________________________________
# batch_normalization_4 (Batch (None, None, None, 16)    64
# _________________________________________________________________
# dropout_4 (Dropout)          (None, None, None, 16)    0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, None, None, 32)    4640
# _________________________________________________________________
# batch_normalization_5 (Batch (None, None, None, 32)    128
# _________________________________________________________________
# dropout_5 (Dropout)          (None, None, None, 32)    0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, None, None, 32)    9248
# _________________________________________________________________
# conv2d_transpose_1 (Conv2DTr (None, None, None, 32)    4128
# _________________________________________________________________
# batch_normalization_6 (Batch (None, None, None, 32)    128
# _________________________________________________________________
# dropout_6 (Dropout)          (None, None, None, 32)    0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, None, None, 32)    9248
# _________________________________________________________________
# conv2d_transpose_2 (Conv2DTr (None, None, None, 32)    4128
# _________________________________________________________________
# batch_normalization_7 (Batch (None, None, None, 32)    128
# _________________________________________________________________
# dropout_7 (Dropout)          (None, None, None, 32)    0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, None, None, 16)    4624
# _________________________________________________________________
# conv2d_transpose_3 (Conv2DTr (None, None, None, 32)    2080
# _________________________________________________________________
# batch_normalization_8 (Batch (None, None, None, 32)    128
# _________________________________________________________________
# dropout_8 (Dropout)          (None, None, None, 32)    0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, None, None, 32)    9248
# =================================================================
# Total params: 52,200
# Trainable params: 51,848
# Non-trainable params: 352
# _________________________________________________________________

# %%
# compile model
opt = optimizers.Adam(lr=0.001)
model.compile(optimizer=opt,
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %%
train_generator = generator(batch_size, train_dir, H, W)
test_generator = generator(batch_size, test_dir, H, W)
tr_size = len(glob.glob(train_dir))
ts_size = len(glob.glob(test_dir))
steps_per_epoch = tr_size// batch_size
validation_steps = ts_size // batch_size
print(tr_size,ts_size,steps_per_epoch,validation_steps)
# Out:
# 200 50 6 1

# %%
t0 = time()
hist = model.fit_generator(train_generator,
                            steps_per_epoch=steps_per_epoch,
                            epochs=100,
                            validation_data=test_generator,
                            validation_steps=validation_steps,
                            class_weight=class_weight,
                            verbose=1)
print('Train time: %.fm'%((time()-t0)/60))
# Out:
# Epoch 1/100
# /home/tking/.local/lib/python3.5/site-packages/ipykernel_launcher.py:9: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.
#   if __name__ == '__main__':
# 6/6 [==============================] - 5s 807ms/step - loss: 7.0506 - acc: 0.0225 - val_loss: 6.6325 - val_acc: 0.0040
# Epoch 2/100
# 6/6 [==============================] - 3s 573ms/step - loss: 6.8390 - acc: 0.0224 - val_loss: 6.3302 - val_acc: 0.0014
# Epoch 3/100
# 6/6 [==============================] - 3s 568ms/step - loss: 6.5851 - acc: 0.0133 - val_loss: 6.4334 - val_acc: 0.0016
# Epoch 4/100
# 6/6 [==============================] - 3s 563ms/step - loss: 6.1092 - acc: 0.0224 - val_loss: 6.7182 - val_acc: 0.0092
# Epoch 5/100
# 6/6 [==============================] - 3s 558ms/step - loss: 5.5698 - acc: 0.1873 - val_loss: 5.8185 - val_acc: 0.3801
# Epoch 6/100
# 6/6 [==============================] - 3s 567ms/step - loss: 5.1268 - acc: 0.3201 - val_loss: 5.6225 - val_acc: 0.2816
# Epoch 7/100
# 6/6 [==============================] - 3s 567ms/step - loss: 4.8043 - acc: 0.3884 - val_loss: 5.4420 - val_acc: 0.3340
# Epoch 8/100
# 6/6 [==============================] - 3s 556ms/step - loss: 4.6194 - acc: 0.4898 - val_loss: 5.2087 - val_acc: 0.3600
# Epoch 9/100
# 6/6 [==============================] - 3s 561ms/step - loss: 4.5265 - acc: 0.5352 - val_loss: 5.2881 - val_acc: 0.3103
# Epoch 10/100
# 6/6 [==============================] - 3s 564ms/step - loss: 4.3970 - acc: 0.5233 - val_loss: 5.0912 - val_acc: 0.3588
# Epoch 11/100
# 6/6 [==============================] - 3s 560ms/step - loss: 4.2940 - acc: 0.5545 - val_loss: 5.0179 - val_acc: 0.3776
# Epoch 12/100
# 6/6 [==============================] - 3s 563ms/step - loss: 4.2828 - acc: 0.5677 - val_loss: 5.1105 - val_acc: 0.3681
# Epoch 13/100
# 6/6 [==============================] - 3s 566ms/step - loss: 4.2192 - acc: 0.5635 - val_loss: 4.6533 - val_acc: 0.4190
# Epoch 14/100
# 6/6 [==============================] - 3s 557ms/step - loss: 4.1391 - acc: 0.5478 - val_loss: 4.5856 - val_acc: 0.4316
# Epoch 15/100
# 6/6 [==============================] - 3s 569ms/step - loss: 4.0991 - acc: 0.5656 - val_loss: 4.5339 - val_acc: 0.4495
# Epoch 16/100
# 6/6 [==============================] - 3s 559ms/step - loss: 4.0443 - acc: 0.5763 - val_loss: 4.6532 - val_acc: 0.4392
# Epoch 17/100
# 6/6 [==============================] - 3s 574ms/step - loss: 4.0195 - acc: 0.5991 - val_loss: 4.4911 - val_acc: 0.4647
# Epoch 18/100
# 6/6 [==============================] - 3s 560ms/step - loss: 4.0299 - acc: 0.5823 - val_loss: 4.3246 - val_acc: 0.4496
# Epoch 19/100
# 6/6 [==============================] - 3s 563ms/step - loss: 3.9801 - acc: 0.5893 - val_loss: 4.2948 - val_acc: 0.4624
# Epoch 20/100
# 6/6 [==============================] - 3s 559ms/step - loss: 3.9398 - acc: 0.6145 - val_loss: 4.2661 - val_acc: 0.4708
# Epoch 21/100
# 6/6 [==============================] - 3s 574ms/step - loss: 3.8752 - acc: 0.6109 - val_loss: 4.3926 - val_acc: 0.4976
# Epoch 22/100
# 6/6 [==============================] - 3s 565ms/step - loss: 3.9351 - acc: 0.5815 - val_loss: 4.1430 - val_acc: 0.5256
# Epoch 23/100
# 6/6 [==============================] - 3s 557ms/step - loss: 3.9025 - acc: 0.5943 - val_loss: 4.0369 - val_acc: 0.5384
# Epoch 24/100
# 6/6 [==============================] - 3s 564ms/step - loss: 3.8341 - acc: 0.6210 - val_loss: 4.1483 - val_acc: 0.5269
# Epoch 25/100
# 6/6 [==============================] - 3s 568ms/step - loss: 3.8849 - acc: 0.6117 - val_loss: 4.0029 - val_acc: 0.5260
# Epoch 26/100
# 6/6 [==============================] - 3s 559ms/step - loss: 3.8794 - acc: 0.5944 - val_loss: 3.8210 - val_acc: 0.5578
# Epoch 27/100
# 6/6 [==============================] - 3s 554ms/step - loss: 3.8664 - acc: 0.6208 - val_loss: 3.7416 - val_acc: 0.5698
# Epoch 28/100
# 6/6 [==============================] - 3s 560ms/step - loss: 3.8203 - acc: 0.5981 - val_loss: 3.8144 - val_acc: 0.5865
# Epoch 29/100
# 6/6 [==============================] - 3s 563ms/step - loss: 3.8362 - acc: 0.6202 - val_loss: 3.7108 - val_acc: 0.5451
# Epoch 30/100
# 6/6 [==============================] - 3s 568ms/step - loss: 3.8085 - acc: 0.6258 - val_loss: 3.8193 - val_acc: 0.5862
# Epoch 31/100
# 6/6 [==============================] - 3s 567ms/step - loss: 3.8412 - acc: 0.5915 - val_loss: 3.7313 - val_acc: 0.5154
# Epoch 32/100
# 6/6 [==============================] - 3s 559ms/step - loss: 3.8063 - acc: 0.6281 - val_loss: 3.8812 - val_acc: 0.6013
# Epoch 33/100
# 6/6 [==============================] - 3s 571ms/step - loss: 3.7489 - acc: 0.6260 - val_loss: 3.7499 - val_acc: 0.5593
# Epoch 34/100
# 6/6 [==============================] - 3s 560ms/step - loss: 3.7499 - acc: 0.6180 - val_loss: 3.8302 - val_acc: 0.5335
# Epoch 35/100
# 6/6 [==============================] - 3s 579ms/step - loss: 3.7570 - acc: 0.6092 - val_loss: 3.9415 - val_acc: 0.5564
# Epoch 36/100
# 6/6 [==============================] - 3s 563ms/step - loss: 3.7544 - acc: 0.6096 - val_loss: 3.9238 - val_acc: 0.5503
# Epoch 37/100
# 6/6 [==============================] - 3s 564ms/step - loss: 3.7550 - acc: 0.6153 - val_loss: 3.9269 - val_acc: 0.5621
# Epoch 38/100
# 6/6 [==============================] - 3s 572ms/step - loss: 3.7145 - acc: 0.6316 - val_loss: 3.8296 - val_acc: 0.5400
# Epoch 39/100
# 6/6 [==============================] - 3s 558ms/step - loss: 3.7369 - acc: 0.6085 - val_loss: 3.8327 - val_acc: 0.5347
# Epoch 40/100
# 6/6 [==============================] - 3s 572ms/step - loss: 3.7301 - acc: 0.6368 - val_loss: 3.7153 - val_acc: 0.5641
# Epoch 41/100
# 6/6 [==============================] - 3s 560ms/step - loss: 3.7519 - acc: 0.6389 - val_loss: 3.7546 - val_acc: 0.5915
# Epoch 42/100
# 6/6 [==============================] - 3s 565ms/step - loss: 3.6880 - acc: 0.6258 - val_loss: 3.6814 - val_acc: 0.5664
# Epoch 43/100
# 6/6 [==============================] - 3s 559ms/step - loss: 3.6791 - acc: 0.6364 - val_loss: 3.6507 - val_acc: 0.6180
# Epoch 44/100
# 6/6 [==============================] - 3s 569ms/step - loss: 3.6868 - acc: 0.6319 - val_loss: 3.8245 - val_acc: 0.5592
# Epoch 45/100
# 6/6 [==============================] - 3s 570ms/step - loss: 3.6955 - acc: 0.6344 - val_loss: 3.7967 - val_acc: 0.5656
# Epoch 46/100
# 6/6 [==============================] - 3s 571ms/step - loss: 3.6770 - acc: 0.6272 - val_loss: 3.8080 - val_acc: 0.5636
# Epoch 47/100
# 6/6 [==============================] - 4s 587ms/step - loss: 3.6961 - acc: 0.6004 - val_loss: 3.7855 - val_acc: 0.5916
# Epoch 48/100
# 6/6 [==============================] - 3s 569ms/step - loss: 3.6564 - acc: 0.6096 - val_loss: 3.7461 - val_acc: 0.5914
# Epoch 49/100
# 6/6 [==============================] - 3s 562ms/step - loss: 3.6126 - acc: 0.5895 - val_loss: 3.7094 - val_acc: 0.6054
# Epoch 50/100
# 6/6 [==============================] - 3s 563ms/step - loss: 3.5558 - acc: 0.6123 - val_loss: 3.7083 - val_acc: 0.5922
# Epoch 51/100
# 6/6 [==============================] - 3s 566ms/step - loss: 3.5706 - acc: 0.5217 - val_loss: 3.6548 - val_acc: 0.5718
# Epoch 52/100
# 6/6 [==============================] - 3s 562ms/step - loss: 3.5743 - acc: 0.5911 - val_loss: 3.7656 - val_acc: 0.6323
# Epoch 53/100
# 6/6 [==============================] - 3s 568ms/step - loss: 3.5213 - acc: 0.5867 - val_loss: 3.7263 - val_acc: 0.5788
# Epoch 54/100
# 6/6 [==============================] - 3s 560ms/step - loss: 3.5622 - acc: 0.5953 - val_loss: 3.6993 - val_acc: 0.5743
# Epoch 55/100
# 6/6 [==============================] - 3s 555ms/step - loss: 3.5141 - acc: 0.5862 - val_loss: 3.8067 - val_acc: 0.5663
# Epoch 56/100
# 6/6 [==============================] - 3s 567ms/step - loss: 3.4588 - acc: 0.5733 - val_loss: 3.8176 - val_acc: 0.6095
# Epoch 57/100
# 6/6 [==============================] - 3s 561ms/step - loss: 3.5245 - acc: 0.5405 - val_loss: 3.8549 - val_acc: 0.5968
# Epoch 58/100
# 6/6 [==============================] - 3s 562ms/step - loss: 3.4730 - acc: 0.5223 - val_loss: 3.5762 - val_acc: 0.5675
# Epoch 59/100
# 6/6 [==============================] - 3s 561ms/step - loss: 3.4499 - acc: 0.5366 - val_loss: 3.6026 - val_acc: 0.6587
# Epoch 60/100
# 6/6 [==============================] - 3s 568ms/step - loss: 3.4759 - acc: 0.5877 - val_loss: 3.5366 - val_acc: 0.5973
# Epoch 61/100
# 6/6 [==============================] - 3s 568ms/step - loss: 3.4342 - acc: 0.6021 - val_loss: 3.6676 - val_acc: 0.6165
# Epoch 62/100
# 6/6 [==============================] - 3s 573ms/step - loss: 3.4962 - acc: 0.5541 - val_loss: 3.5684 - val_acc: 0.5773
# Epoch 63/100
# 6/6 [==============================] - 3s 564ms/step - loss: 3.4415 - acc: 0.6077 - val_loss: 3.6288 - val_acc: 0.5931
# Epoch 64/100
# 6/6 [==============================] - 3s 578ms/step - loss: 3.4823 - acc: 0.5680 - val_loss: 3.5520 - val_acc: 0.5917
# Epoch 65/100
# 6/6 [==============================] - 3s 563ms/step - loss: 3.4182 - acc: 0.5654 - val_loss: 3.6489 - val_acc: 0.6202
# Epoch 66/100
# 6/6 [==============================] - 3s 563ms/step - loss: 3.4799 - acc: 0.5434 - val_loss: 3.6401 - val_acc: 0.6103
# Epoch 67/100
# 6/6 [==============================] - 3s 570ms/step - loss: 3.4022 - acc: 0.5800 - val_loss: 3.6460 - val_acc: 0.6302
# Epoch 68/100
# 6/6 [==============================] - 3s 570ms/step - loss: 3.4524 - acc: 0.5566 - val_loss: 3.5095 - val_acc: 0.6050
# Epoch 69/100
# 6/6 [==============================] - 3s 565ms/step - loss: 3.4481 - acc: 0.5355 - val_loss: 3.5399 - val_acc: 0.5863
# Epoch 70/100
# 6/6 [==============================] - 3s 563ms/step - loss: 3.5034 - acc: 0.5697 - val_loss: 3.6171 - val_acc: 0.5958
# Epoch 71/100
# 6/6 [==============================] - 3s 580ms/step - loss: 3.4207 - acc: 0.5825 - val_loss: 3.5406 - val_acc: 0.6171
# Epoch 72/100
# 6/6 [==============================] - 3s 562ms/step - loss: 3.4041 - acc: 0.5623 - val_loss: 3.4379 - val_acc: 0.5768
# Epoch 73/100
# 6/6 [==============================] - 3s 560ms/step - loss: 3.4418 - acc: 0.5512 - val_loss: 3.3959 - val_acc: 0.6252
# Epoch 74/100
# 6/6 [==============================] - 3s 563ms/step - loss: 3.3746 - acc: 0.5764 - val_loss: 3.5261 - val_acc: 0.6292
# Epoch 75/100
# 6/6 [==============================] - 3s 570ms/step - loss: 3.4282 - acc: 0.5660 - val_loss: 3.6070 - val_acc: 0.5746
# Epoch 76/100
# 6/6 [==============================] - 3s 579ms/step - loss: 3.3620 - acc: 0.5438 - val_loss: 3.7393 - val_acc: 0.5833
# Epoch 77/100
# 6/6 [==============================] - 3s 569ms/step - loss: 3.3984 - acc: 0.5479 - val_loss: 3.5307 - val_acc: 0.5488
# Epoch 78/100
# 6/6 [==============================] - 3s 565ms/step - loss: 3.4037 - acc: 0.5820 - val_loss: 3.4947 - val_acc: 0.6134
# Epoch 79/100
# 6/6 [==============================] - 3s 565ms/step - loss: 3.4339 - acc: 0.5377 - val_loss: 3.5512 - val_acc: 0.5763
# Epoch 80/100
# 6/6 [==============================] - 3s 562ms/step - loss: 3.3866 - acc: 0.5362 - val_loss: 3.4937 - val_acc: 0.6329
# Epoch 81/100
# 6/6 [==============================] - 3s 560ms/step - loss: 3.3909 - acc: 0.5602 - val_loss: 3.6128 - val_acc: 0.5760
# Epoch 82/100
# 6/6 [==============================] - 3s 562ms/step - loss: 3.4132 - acc: 0.5607 - val_loss: 3.5805 - val_acc: 0.5728
# Epoch 83/100
# 6/6 [==============================] - 3s 554ms/step - loss: 3.4274 - acc: 0.5796 - val_loss: 3.5416 - val_acc: 0.6136
# Epoch 84/100
# 6/6 [==============================] - 3s 563ms/step - loss: 3.3673 - acc: 0.5929 - val_loss: 3.4821 - val_acc: 0.5870
# Epoch 85/100
# 6/6 [==============================] - 3s 560ms/step - loss: 3.3728 - acc: 0.5315 - val_loss: 3.5170 - val_acc: 0.6123
# Epoch 86/100
# 6/6 [==============================] - 3s 560ms/step - loss: 3.3381 - acc: 0.5550 - val_loss: 3.5428 - val_acc: 0.5775
# Epoch 87/100
# 6/6 [==============================] - 3s 566ms/step - loss: 3.3977 - acc: 0.6124 - val_loss: 3.6650 - val_acc: 0.6140
# Epoch 88/100
# 6/6 [==============================] - 3s 565ms/step - loss: 3.3516 - acc: 0.5524 - val_loss: 3.5877 - val_acc: 0.5713
# Epoch 89/100
# 6/6 [==============================] - 3s 549ms/step - loss: 3.3679 - acc: 0.5153 - val_loss: 3.5620 - val_acc: 0.5759
# Epoch 90/100
# 6/6 [==============================] - 3s 561ms/step - loss: 3.3223 - acc: 0.5542 - val_loss: 3.5587 - val_acc: 0.5706
# Epoch 91/100
# 6/6 [==============================] - 3s 560ms/step - loss: 3.3512 - acc: 0.6147 - val_loss: 3.6772 - val_acc: 0.6115
# Epoch 92/100
# 6/6 [==============================] - 3s 570ms/step - loss: 3.3957 - acc: 0.5643 - val_loss: 3.5093 - val_acc: 0.6234
# Epoch 93/100
# 6/6 [==============================] - 3s 566ms/step - loss: 3.3892 - acc: 0.5178 - val_loss: 3.7162 - val_acc: 0.5554
# Epoch 94/100
# 6/6 [==============================] - 3s 569ms/step - loss: 3.3048 - acc: 0.5430 - val_loss: 3.5635 - val_acc: 0.6078
# Epoch 95/100
# 6/6 [==============================] - 3s 557ms/step - loss: 3.3751 - acc: 0.5159 - val_loss: 3.4877 - val_acc: 0.6388
# Epoch 96/100
# 6/6 [==============================] - 3s 556ms/step - loss: 3.3596 - acc: 0.5014 - val_loss: 3.4749 - val_acc: 0.6068
# Epoch 97/100
# 6/6 [==============================] - 3s 559ms/step - loss: 3.3124 - acc: 0.5847 - val_loss: 3.4434 - val_acc: 0.6048
# Epoch 98/100
# 6/6 [==============================] - 3s 562ms/step - loss: 3.3465 - acc: 0.5730 - val_loss: 3.4440 - val_acc: 0.6234
# Epoch 99/100
# 6/6 [==============================] - 3s 559ms/step - loss: 3.3442 - acc: 0.5004 - val_loss: 3.5022 - val_acc: 0.5996
# Epoch 100/100
# 6/6 [==============================] - 3s 560ms/step - loss: 3.3447 - acc: 0.5009 - val_loss: 3.4139 - val_acc: 0.6272
# Train time: 6m

# %%
plt.figure(figsize=(15,5))
plt.subplot(1,2,1)
plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.legend(['loss','val_loss'])
plt.grid()
plt.subplot(1,2,2)
plt.plot(hist.history['acc'])
plt.plot(hist.history['val_acc'])
plt.legend(['acc','val_acc'])
plt.grid()

# %%
history = []
history.append(hist.history['loss'])
history.append(hist.history['val_loss'])
history.append(hist.history['acc'])
history.append(hist.history['val_acc'])
history = np.array(history)
np.savetxt(model_name+"_"+dir_name+"_history.txt", history, delimiter=",")

# %%
model_json = model.to_json()
with open(model_name+"_"+dir_name+".json", "w") as json_file:
    json_file.write(model_json)
model.save_weights(model_name+"_"+dir_name+".h5")

# %%
from keras.models import model_from_json

# %%
json_file = open(model_name+"_"+dir_name+".json", "r")
loaded_model_json = json_file.read()
json_file.close()
loaded_model = model_from_json(loaded_model_json)
# load weights into new model
loaded_model.load_weights(model_name+"_"+dir_name+".h5")

# %%
# result on train images
X,Y = generator(batch_size, train_dir, H, W).__next__()
Yhat = model.predict(X)
j =1
plt.figure(figsize=(20,20))
for i in range(12):
    # original
    plt.subplot(6,8,j)
    j+=1
    img = XY2img(X[i],Y[i])
    plt.imshow(img)
    plt.axis('OFF')
    # grayscale
    plt.subplot(6,8,j)
    j+=1
    plt.imshow(X[i,:,:,0],'gray')
    plt.axis('OFF')
    # predict
    plt.subplot(6,8,j)
    j += 1
    img = XY2img(X[i],Yhat[i])
    plt.imshow(img)
    plt.axis('OFF')
    # predict
    plt.subplot(6,8,j)
    j += 1
    img = XY2imgf(X[i],Yhat[i])
    plt.imshow(img)
    plt.axis('OFF')
# Out:
# /home/tking/.local/lib/python3.5/site-packages/ipykernel_launcher.py:9: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.
#   if __name__ == '__main__':

# %%
# result on test images
X,Y = generator(batch_size, test_dir, H, W).__next__()
Yhat = model.predict(X)
j =1
plt.figure(figsize=(20,20))
for i in range(12):
    # original
    plt.subplot(6,8,j)
    j+=1
    img = XY2img(X[i],Y[i])
    plt.imshow(img)
    plt.axis('OFF')
    # grayscale
    plt.subplot(6,8,j)
    j+=1
    plt.imshow(X[i,:,:,0],'gray')
    plt.axis('OFF')
    # predict
    plt.subplot(6,8,j)
    j += 1
    img = XY2img(X[i],Yhat[i])
    plt.imshow(img)
    plt.axis('OFF')
    # predict
    plt.subplot(6,8,j)
    j += 1
    img = XY2imgf(X[i],Yhat[i])
    plt.imshow(img)
    plt.axis('OFF')
# Out:
# /home/tking/.local/lib/python3.5/site-packages/ipykernel_launcher.py:9: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.
#   if __name__ == '__main__':
